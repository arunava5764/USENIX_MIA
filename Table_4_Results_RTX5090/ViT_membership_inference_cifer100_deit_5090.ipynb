# %% [markdown]
# ## Table 4: DeiT-Base model's results on CIFAR-100 dataset using RTX 5090 GPU

# %% [markdown]
# ### Section 1: Loading Dataset

# %%
import numpy as np
import pandas as pd

# %%
deit_base_data=[]
deit_base_data_test=[]

for i in range(1,101):
    temp1=[]
    for j in range(10):
        path='/home/t1000/Desktop/GPU_Traces/mem_csv_deit_base_cifar-100_5090/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    deit_base_data.append(temp1)


for i in range(1,31):
    temp1=[]
    for j in range(10):
        path='/home/t1000/Desktop/GPU_Traces/mem_csv_deit_base_cifar-100_5090_test/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    deit_base_data_test.append(temp1)

print(deit_base_data[0][1].columns)
print(deit_base_data_test[0][1].columns)
# Out:
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'syslts__t_tag_requests.avg.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.max.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.min.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.sum.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.avg.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.max.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.min.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.sum.pct_of_peak_sustained_elapsed',
#        'thread_inst_executed', 'thread_inst_executed_true'],
#       dtype='object', length=2062)
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'syslts__t_tag_requests.avg.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.max.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.min.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.sum.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.avg.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.max.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.min.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.sum.pct_of_peak_sustained_elapsed',
#        'thread_inst_executed', 'thread_inst_executed_true'],
#       dtype='object', length=2062)

# %% [markdown]
# ### Section 2: Pre-processing Dataset

# %%
for i in range(100):
    for j in range(10):
        deit_base_data[i][j]=deit_base_data[i][j].drop(['ID'], axis=1)
        if 0 in deit_base_data[i][j].index:
            deit_base_data[i][j] = deit_base_data[i][j].drop(index=0)

for i in range(30):
    for j in range(10):
        deit_base_data_test[i][j]=deit_base_data_test[i][j].drop(['ID'], axis=1)
        if 0 in deit_base_data_test[i][j].index:
            deit_base_data_test[i][j] = deit_base_data_test[i][j].drop(index=0)

# %%
deit_base_data_test[0][0]['Kernel Name'].unique
# Out:
# <bound method Series.unique of 1     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 2     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 3     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 4     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 5     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 6     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 7     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 8     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 9     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 10    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 11    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 12    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# Name: Kernel Name, dtype: object>

# %% [markdown]
# ### Section 3: Metric-based Data filtering and pre-processing

# %%
# Import additional libraries for visualization and random sampling
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import random
kernel_name=['fmha_cutlassF_f32_aligned_64x64_rf_sm80']
ltx_cols=[col for col in deit_base_data[0][1].columns if 
          col.startswith('smsp__branch_targets_threads_divergent') 
                  or col.startswith('smsp__average_warps_issue_stalled_branch_resolving_per_issue_active') 
                  or col.startswith('smsp__average_warps_issue_stalled_imc_miss_per_issue_active')
]
for col in ltx_cols:
    for i in range(100):
        for j in range(10):
            if deit_base_data[i][j][col].dtype == 'object': 
                deit_base_data[i][j][col] = pd.to_numeric(deit_base_data[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
    for i in range(30):
        for j in range(10):
            if deit_base_data_test[i][j][col].dtype == 'object':  
                deit_base_data_test[i][j][col] = pd.to_numeric(deit_base_data_test[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
                

print(ltx_cols)
# Out:
# /home/t1000/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ['smsp__average_warps_issue_stalled_branch_resolving_per_issue_active.ratio', 'smsp__branch_targets_threads_divergent']

# %% [markdown]
# print(len(all_class_data))

# %%
deit_base_data[0][0].shape
# Out:
# (12, 2061)

# %% [markdown]
# ### Section 4: Generating classifier model's training data and validation data by considering only the filtered Metrics.

# %%
col = [col for col in deit_base_data[0][1].columns if 
    col.startswith('smsp__branch_targets_threads_divergent') 
        or col.startswith('smsp__average_warps_issue_stalled_branch_resolving_per_issue_active') 
        or col.startswith('smsp__average_warps_issue_stalled_imc_miss_per_issue_active')# 
]

for i in range(10):
    for j in range(10):
        for c in col:
            deit_base_data[i][j][c]=pd.to_numeric(deit_base_data[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')
            
for i in range(30):
    for j in range(10):
        for c in col:
            deit_base_data_test[i][j][c]=pd.to_numeric(deit_base_data_test[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')


deit_base_data_df=[[[] for i in range(10)] for j in range(100)]
deit_base_data_test_df=[[[] for i in range(10)] for j in range(30)]
for i in range(len(deit_base_data)):
    for j in range(len(deit_base_data[i])):
        df2 = deit_base_data[i][j]
        selected_cols = [c for c in col if c in df2.columns]
        deit_base_data_df[i][j] = deit_base_data[i][j][selected_cols].copy()

for i in range(len(deit_base_data_test)):
    for j in range(len(deit_base_data_test[i])):
        df2 = deit_base_data_test[i][j]
        selected_cols = [c for c in col if c in df2.columns]
        deit_base_data_test_df[i][j] = deit_base_data_test[i][j][selected_cols].copy()

# %%
print(col)
# Out:
# ['smsp__average_warps_issue_stalled_branch_resolving_per_issue_active.ratio', 'smsp__branch_targets_threads_divergent']

# %%
deit_base_data_test_df[0][0].shape
# Out:
# (12, 2)

# %% [markdown]
# ### Dataset re-arrangement and providing label for training and test samples for both shadow and target model. Also, selecting appropiate range of FMHA kernel instances for achieving maximum attack success rate.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=[]
y_train=[]
X_test=[]
y_test=[]

for i in range(100):
    for j in range(10):
        r = deit_base_data_df[i][j]  # shape: (12, 2)
        j_col = np.full((r.shape[0], 1), j)  # shape: (12, 1)
        r_with_class = np.concatenate([r, j_col], axis=1)  # shape: (12, 3)
        X_train.append(r_with_class)

        if i < 50:
            y_train.append(1)
        else:
            y_train.append(0)
for i in range(30):
    for j in range(10):
        r = deit_base_data_test_df[i][j]  # shape: (12, 2)
        j_col = np.full((r.shape[0], 1), j)
        r_with_class = np.concatenate([r, j_col], axis=1)
        X_test.append(r_with_class)

        if i < 15:
            y_test.append(1)
        else:
            y_test.append(0)


X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train[:,0:12, :]
X_test = X_test[:, 0:12, :]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1000, 12, 3) (1000,)
# (300, 12, 3) (300,)

# %%
print(X_train.dtype)
print(X_train[0, 0, :10])
# Out:
# float64
# [4.60559987e-02 3.08608000e+05 0.00000000e+00]

# %%
# Ensure all elements are float32
X_train = X_train.astype(np.float32)

# %%
import numpy as np
print(np.unique(y_train, return_counts=True))
print(np.unique(y_test, return_counts=True))
# Out:
# (array([0, 1]), array([500, 500]))
# (array([0, 1]), array([150, 150]))

# %% [markdown]
# ### Attack Classifier training

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout, BatchNormalization
import numpy as np
# np.random.seed(42) 
from sklearn.model_selection import train_test_split

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  
def reset_random_seeds():
   os.environ['PYTHONHASHSEED']=str(42)
   tf.random.set_seed(42)
   np.random.seed(42)
   random.seed(42)


reset_random_seeds()


import tensorflow as tf

# Your input data shape: (samples, sequence_length, feature_dim)
num_samples = X_train.shape[0]
sequence_length = X_train.shape[1]
feature_dim = X_train.shape[2]


# Define the model
# Stacked BiLSTM Layers
model = Sequential()
model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=(sequence_length, feature_dim)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(32, return_sequences=False)))
model.add(Dropout(0.2))


# Fully connected hidden layer
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
features_train = X_train[:, :, :-1]  
class_train = X_train[:, :, -1:]     
mean = features_train.mean(axis=(0, 1), keepdims=True)
std = features_train.std(axis=(0, 1), keepdims=True)

features_train = (features_train - mean) / (std + 1e-8)

X_train = np.concatenate([features_train, class_train], axis=-1)

# Summary
model.summary()
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)
# Train
history = model.fit(
    X_train_split, y_train_split,
    epochs=300,
    batch_size=45,
    validation_data=(X_val_split, y_val_split)
)
# Out:
# 2026-08-18 16:42:29.978019: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-18 16:42:30.006533: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-18 16:42:30.726350: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-18 16:42:30.832999: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-08-18 16:42:30.833018: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# 2026-08-18 16:42:30.833021: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# 2026-08-18 16:42:30.833023: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2026-08-18 16:42:30.833025: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: vhj4ybwysf5e7ppbc5tbh6f2ez
# 2026-08-18 16:42:30.833027: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] hostname: vhj4ybwysf5e7ppbc5tbh6f2ez
# 2026-08-18 16:42:30.833084: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] libcuda reported version is: 580.95.5
# 2026-08-18 16:42:30.833094: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:194] kernel reported version is: 580.95.5
# 2026-08-18 16:42:30.833095: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:284] kernel version seems to match DSO: 580.95.5
# /home/t1000/.local/lib/python3.10/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 12, 128)        │        34,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 64)             │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,257 (313.50 KB)
#  Trainable params: 80,257 (313.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.5400 - loss: 0.6953 - val_accuracy: 0.4950 - val_loss: 0.6981
# Epoch 2/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5025 - loss: 0.6963 - val_accuracy: 0.4700 - val_loss: 0.6929
# Epoch 3/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5025 - loss: 0.6926 - val_accuracy: 0.5000 - val_loss: 0.6947
# Epoch 4/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5025 - loss: 0.6963 - val_accuracy: 0.5000 - val_loss: 0.6948
# Epoch 5/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5387 - loss: 0.6878 - val_accuracy: 0.5100 - val_loss: 0.6958
# Epoch 6/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5175 - loss: 0.6906 - val_accuracy: 0.4900 - val_loss: 0.6943
# Epoch 7/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5200 - loss: 0.6900 - val_accuracy: 0.5150 - val_loss: 0.6931
# Epoch 8/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5575 - loss: 0.6853 - val_accuracy: 0.4950 - val_loss: 0.6887
# Epoch 9/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5325 - loss: 0.6858 - val_accuracy: 0.4650 - val_loss: 0.6837
# Epoch 10/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5350 - loss: 0.6756 - val_accuracy: 0.5150 - val_loss: 0.6759
# Epoch 11/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5612 - loss: 0.6632 - val_accuracy: 0.5400 - val_loss: 0.6645
# Epoch 12/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5775 - loss: 0.6460 - val_accuracy: 0.5350 - val_loss: 0.6584
# Epoch 13/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5537 - loss: 0.6536 - val_accuracy: 0.4900 - val_loss: 0.6398
# Epoch 14/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5838 - loss: 0.6409 - val_accuracy: 0.5600 - val_loss: 0.6417
# Epoch 15/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5925 - loss: 0.6314 - val_accuracy: 0.6050 - val_loss: 0.6306
# Epoch 16/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6025 - loss: 0.6066 - val_accuracy: 0.5250 - val_loss: 0.6127
# Epoch 17/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6450 - loss: 0.6044 - val_accuracy: 0.5500 - val_loss: 0.6607
# Epoch 18/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5725 - loss: 0.6275 - val_accuracy: 0.5400 - val_loss: 0.6112
# Epoch 19/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6575 - loss: 0.5865 - val_accuracy: 0.5950 - val_loss: 0.6073
# Epoch 20/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6225 - loss: 0.5801 - val_accuracy: 0.5650 - val_loss: 0.5970
# Epoch 21/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5938 - loss: 0.6393 - val_accuracy: 0.5400 - val_loss: 0.6970
# Epoch 22/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5437 - loss: 0.6547 - val_accuracy: 0.5000 - val_loss: 0.6666
# Epoch 23/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5738 - loss: 0.6430 - val_accuracy: 0.5950 - val_loss: 0.6602
# Epoch 24/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5612 - loss: 0.6599 - val_accuracy: 0.6200 - val_loss: 0.6645
# Epoch 25/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5638 - loss: 0.6449 - val_accuracy: 0.6050 - val_loss: 0.6532
# Epoch 26/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5962 - loss: 0.6226 - val_accuracy: 0.5950 - val_loss: 0.6438
# Epoch 27/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6000 - loss: 0.6209 - val_accuracy: 0.5400 - val_loss: 0.6333
# Epoch 28/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6150 - loss: 0.6126 - val_accuracy: 0.5450 - val_loss: 0.6301
# Epoch 29/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6062 - loss: 0.6146 - val_accuracy: 0.5900 - val_loss: 0.6334
# Epoch 30/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6300 - loss: 0.5969 - val_accuracy: 0.5350 - val_loss: 0.5998
# Epoch 31/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6475 - loss: 0.5815 - val_accuracy: 0.5750 - val_loss: 0.5975
# Epoch 32/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6425 - loss: 0.5829 - val_accuracy: 0.6300 - val_loss: 0.6746
# Epoch 33/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6388 - loss: 0.6057 - val_accuracy: 0.5500 - val_loss: 0.6078
# Epoch 34/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6400 - loss: 0.5824 - val_accuracy: 0.5950 - val_loss: 0.5754
# Epoch 35/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6500 - loss: 0.5644 - val_accuracy: 0.6600 - val_loss: 0.5416
# Epoch 36/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6562 - loss: 0.5546 - val_accuracy: 0.6100 - val_loss: 0.5538
# Epoch 37/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6513 - loss: 0.5429 - val_accuracy: 0.6900 - val_loss: 0.5234
# Epoch 38/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6500 - loss: 0.5417 - val_accuracy: 0.6300 - val_loss: 0.5179
# Epoch 39/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6600 - loss: 0.5530 - val_accuracy: 0.6200 - val_loss: 0.5619
# Epoch 40/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6413 - loss: 0.5485 - val_accuracy: 0.6450 - val_loss: 0.5417
# Epoch 41/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6637 - loss: 0.5368 - val_accuracy: 0.6250 - val_loss: 0.5194
# Epoch 42/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6575 - loss: 0.5365 - val_accuracy: 0.5950 - val_loss: 0.5942
# Epoch 43/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6600 - loss: 0.5509 - val_accuracy: 0.5600 - val_loss: 0.5308
# Epoch 44/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6600 - loss: 0.5324 - val_accuracy: 0.6900 - val_loss: 0.5066
# Epoch 45/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6963 - loss: 0.5160 - val_accuracy: 0.6250 - val_loss: 0.4936
# Epoch 46/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6812 - loss: 0.4956 - val_accuracy: 0.7100 - val_loss: 0.4764
# Epoch 47/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7225 - loss: 0.4779 - val_accuracy: 0.7100 - val_loss: 0.4784
# Epoch 48/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7350 - loss: 0.4594 - val_accuracy: 0.7150 - val_loss: 0.4776
# Epoch 49/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7350 - loss: 0.4508 - val_accuracy: 0.6800 - val_loss: 0.4706
# Epoch 50/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7100 - loss: 0.4950 - val_accuracy: 0.6900 - val_loss: 0.5150
# Epoch 51/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7075 - loss: 0.4879 - val_accuracy: 0.6600 - val_loss: 0.4894
# Epoch 52/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7000 - loss: 0.4819 - val_accuracy: 0.6850 - val_loss: 0.4790
# Epoch 53/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7237 - loss: 0.4570 - val_accuracy: 0.6650 - val_loss: 0.4207
# Epoch 54/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7287 - loss: 0.4356 - val_accuracy: 0.7300 - val_loss: 0.4353
# Epoch 55/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7563 - loss: 0.4336 - val_accuracy: 0.6800 - val_loss: 0.5354
# Epoch 56/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6625 - loss: 0.5324 - val_accuracy: 0.7100 - val_loss: 0.4954
# Epoch 57/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6212 - loss: 0.5635 - val_accuracy: 0.5800 - val_loss: 0.5428
# Epoch 58/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6750 - loss: 0.5183 - val_accuracy: 0.6250 - val_loss: 0.5178
# Epoch 59/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6650 - loss: 0.5110 - val_accuracy: 0.6550 - val_loss: 0.5091
# Epoch 60/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6862 - loss: 0.4981 - val_accuracy: 0.6700 - val_loss: 0.5043
# Epoch 61/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6675 - loss: 0.4941 - val_accuracy: 0.6550 - val_loss: 0.5019
# Epoch 62/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6612 - loss: 0.5916 - val_accuracy: 0.5500 - val_loss: 0.5529
# Epoch 63/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6963 - loss: 0.5013 - val_accuracy: 0.7000 - val_loss: 0.5277
# Epoch 64/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7038 - loss: 0.4733 - val_accuracy: 0.7100 - val_loss: 0.4740
# Epoch 65/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7225 - loss: 0.4581 - val_accuracy: 0.7350 - val_loss: 0.4462
# Epoch 66/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7138 - loss: 0.4384 - val_accuracy: 0.7450 - val_loss: 0.4405
# Epoch 67/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7400 - loss: 0.4252 - val_accuracy: 0.7200 - val_loss: 0.4315
# Epoch 68/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7375 - loss: 0.4309 - val_accuracy: 0.7350 - val_loss: 0.4352
# Epoch 69/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7550 - loss: 0.4325 - val_accuracy: 0.7650 - val_loss: 0.4133
# Epoch 70/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7250 - loss: 0.4856 - val_accuracy: 0.7050 - val_loss: 0.4905
# Epoch 71/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7287 - loss: 0.4849 - val_accuracy: 0.7300 - val_loss: 0.4268
# Epoch 72/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7375 - loss: 0.4716 - val_accuracy: 0.7050 - val_loss: 0.6065
# Epoch 73/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7250 - loss: 0.5356 - val_accuracy: 0.7300 - val_loss: 0.4486
# Epoch 74/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7275 - loss: 0.4345 - val_accuracy: 0.6800 - val_loss: 0.4276
# Epoch 75/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7625 - loss: 0.3995 - val_accuracy: 0.7550 - val_loss: 0.4024
# Epoch 76/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7650 - loss: 0.3876 - val_accuracy: 0.6750 - val_loss: 0.3990
# Epoch 77/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7600 - loss: 0.4063 - val_accuracy: 0.7300 - val_loss: 0.4156
# Epoch 78/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7613 - loss: 0.3878 - val_accuracy: 0.7000 - val_loss: 0.4033
# Epoch 79/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7625 - loss: 0.3795 - val_accuracy: 0.7550 - val_loss: 0.3770
# Epoch 80/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7688 - loss: 0.3754 - val_accuracy: 0.7000 - val_loss: 0.4007
# Epoch 81/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7513 - loss: 0.4130 - val_accuracy: 0.7000 - val_loss: 0.6303
# Epoch 82/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7088 - loss: 0.5111 - val_accuracy: 0.6450 - val_loss: 0.5206
# Epoch 83/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6825 - loss: 0.4952 - val_accuracy: 0.7050 - val_loss: 0.4698
# Epoch 84/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7150 - loss: 0.4648 - val_accuracy: 0.7200 - val_loss: 0.4457
# Epoch 85/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7325 - loss: 0.4247 - val_accuracy: 0.7150 - val_loss: 0.4306
# Epoch 86/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7350 - loss: 0.4191 - val_accuracy: 0.7350 - val_loss: 0.4292
# Epoch 87/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7450 - loss: 0.4078 - val_accuracy: 0.7300 - val_loss: 0.4063
# Epoch 88/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7412 - loss: 0.4113 - val_accuracy: 0.8000 - val_loss: 0.4258
# Epoch 89/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7650 - loss: 0.3978 - val_accuracy: 0.7400 - val_loss: 0.4323
# Epoch 90/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7638 - loss: 0.4062 - val_accuracy: 0.7650 - val_loss: 0.3917
# Epoch 91/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7613 - loss: 0.4099 - val_accuracy: 0.7550 - val_loss: 0.4285
# Epoch 92/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7525 - loss: 0.4270 - val_accuracy: 0.7550 - val_loss: 0.4062
# Epoch 93/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7825 - loss: 0.3847 - val_accuracy: 0.7600 - val_loss: 0.4020
# Epoch 94/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7663 - loss: 0.3820 - val_accuracy: 0.7200 - val_loss: 0.4118
# Epoch 95/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7275 - loss: 0.4141 - val_accuracy: 0.7000 - val_loss: 0.5013
# Epoch 96/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7575 - loss: 0.4108 - val_accuracy: 0.7750 - val_loss: 0.3745
# Epoch 97/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7763 - loss: 0.3654 - val_accuracy: 0.7600 - val_loss: 0.3737
# Epoch 98/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7588 - loss: 0.3498 - val_accuracy: 0.7050 - val_loss: 0.3549
# Epoch 99/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8000 - loss: 0.3355 - val_accuracy: 0.7350 - val_loss: 0.3464
# Epoch 100/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7425 - loss: 0.3634 - val_accuracy: 0.6950 - val_loss: 0.4052
# Epoch 101/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7212 - loss: 0.4870 - val_accuracy: 0.6900 - val_loss: 0.5123
# Epoch 102/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7462 - loss: 0.4542 - val_accuracy: 0.7200 - val_loss: 0.4459
# Epoch 103/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7600 - loss: 0.3860 - val_accuracy: 0.7400 - val_loss: 0.3643
# Epoch 104/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7775 - loss: 0.3449 - val_accuracy: 0.7200 - val_loss: 0.4191
# Epoch 105/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7763 - loss: 0.3468 - val_accuracy: 0.7650 - val_loss: 0.3329
# Epoch 106/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7788 - loss: 0.3525 - val_accuracy: 0.7450 - val_loss: 0.3464
# Epoch 107/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7850 - loss: 0.3321 - val_accuracy: 0.7650 - val_loss: 0.3257
# Epoch 108/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7987 - loss: 0.3145 - val_accuracy: 0.7500 - val_loss: 0.3205
# Epoch 109/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8100 - loss: 0.3132 - val_accuracy: 0.7700 - val_loss: 0.3243
# Epoch 110/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8175 - loss: 0.3110 - val_accuracy: 0.7500 - val_loss: 0.3485
# Epoch 111/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7825 - loss: 0.3352 - val_accuracy: 0.7850 - val_loss: 0.3449
# Epoch 112/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7625 - loss: 0.3668 - val_accuracy: 0.7850 - val_loss: 0.4147
# Epoch 113/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7563 - loss: 0.3830 - val_accuracy: 0.7950 - val_loss: 0.3543
# Epoch 114/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7850 - loss: 0.3608 - val_accuracy: 0.7650 - val_loss: 0.3552
# Epoch 115/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7887 - loss: 0.3498 - val_accuracy: 0.7750 - val_loss: 0.3278
# Epoch 116/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7962 - loss: 0.3185 - val_accuracy: 0.7750 - val_loss: 0.3253
# Epoch 117/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7987 - loss: 0.3095 - val_accuracy: 0.7850 - val_loss: 0.3342
# Epoch 118/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8125 - loss: 0.3038 - val_accuracy: 0.7850 - val_loss: 0.3067
# Epoch 119/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8012 - loss: 0.3026 - val_accuracy: 0.7700 - val_loss: 0.4008
# Epoch 120/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8025 - loss: 0.3020 - val_accuracy: 0.7750 - val_loss: 0.3000
# Epoch 121/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7937 - loss: 0.2947 - val_accuracy: 0.7700 - val_loss: 0.3398
# Epoch 122/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8012 - loss: 0.3453 - val_accuracy: 0.7950 - val_loss: 0.3595
# Epoch 123/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7513 - loss: 0.4854 - val_accuracy: 0.6400 - val_loss: 0.5193
# Epoch 124/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6988 - loss: 0.5025 - val_accuracy: 0.7100 - val_loss: 0.5284
# Epoch 125/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7225 - loss: 0.4747 - val_accuracy: 0.7450 - val_loss: 0.4678
# Epoch 126/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7250 - loss: 0.4413 - val_accuracy: 0.7150 - val_loss: 0.4426
# Epoch 127/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7425 - loss: 0.4149 - val_accuracy: 0.7300 - val_loss: 0.4205
# Epoch 128/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7563 - loss: 0.4100 - val_accuracy: 0.7900 - val_loss: 0.4122
# Epoch 129/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7475 - loss: 0.4261 - val_accuracy: 0.7300 - val_loss: 0.5005
# Epoch 130/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7513 - loss: 0.4587 - val_accuracy: 0.8000 - val_loss: 0.3880
# Epoch 131/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7650 - loss: 0.3925 - val_accuracy: 0.7800 - val_loss: 0.3896
# Epoch 132/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7538 - loss: 0.3992 - val_accuracy: 0.7600 - val_loss: 0.3863
# Epoch 133/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7462 - loss: 0.4066 - val_accuracy: 0.7800 - val_loss: 0.3755
# Epoch 134/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7638 - loss: 0.3814 - val_accuracy: 0.7800 - val_loss: 0.3663
# Epoch 135/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7650 - loss: 0.3820 - val_accuracy: 0.7900 - val_loss: 0.3571
# Epoch 136/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7862 - loss: 0.3599 - val_accuracy: 0.7750 - val_loss: 0.3551
# Epoch 137/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7987 - loss: 0.3437 - val_accuracy: 0.7550 - val_loss: 0.3688
# Epoch 138/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7713 - loss: 0.3911 - val_accuracy: 0.7550 - val_loss: 0.3744
# Epoch 139/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7750 - loss: 0.3709 - val_accuracy: 0.8100 - val_loss: 0.3615
# Epoch 140/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7663 - loss: 0.3854 - val_accuracy: 0.7600 - val_loss: 0.3549
# Epoch 141/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7700 - loss: 0.3483 - val_accuracy: 0.7700 - val_loss: 0.3408
# Epoch 142/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7837 - loss: 0.3558 - val_accuracy: 0.7750 - val_loss: 0.3395
# Epoch 143/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7850 - loss: 0.3482 - val_accuracy: 0.7900 - val_loss: 0.3418
# Epoch 144/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7225 - loss: 0.4198 - val_accuracy: 0.7000 - val_loss: 0.4962
# Epoch 145/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7075 - loss: 0.4664 - val_accuracy: 0.7300 - val_loss: 0.5588
# Epoch 146/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6625 - loss: 0.4838 - val_accuracy: 0.7050 - val_loss: 0.5342
# Epoch 147/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6938 - loss: 0.4624 - val_accuracy: 0.7400 - val_loss: 0.4080
# Epoch 148/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7075 - loss: 0.4344 - val_accuracy: 0.7400 - val_loss: 0.4055
# Epoch 149/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7212 - loss: 0.4100 - val_accuracy: 0.7500 - val_loss: 0.3892
# Epoch 150/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7113 - loss: 0.3982 - val_accuracy: 0.7300 - val_loss: 0.3849
# Epoch 151/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7287 - loss: 0.3931 - val_accuracy: 0.7450 - val_loss: 0.3849
# Epoch 152/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7400 - loss: 0.3881 - val_accuracy: 0.7450 - val_loss: 0.3697
# Epoch 153/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7312 - loss: 0.3860 - val_accuracy: 0.7750 - val_loss: 0.3650
# Epoch 154/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7412 - loss: 0.3829 - val_accuracy: 0.7450 - val_loss: 0.3896
# Epoch 155/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7250 - loss: 0.4007 - val_accuracy: 0.7150 - val_loss: 0.3963
# Epoch 156/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7337 - loss: 0.3965 - val_accuracy: 0.7200 - val_loss: 0.4009
# Epoch 157/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7350 - loss: 0.4002 - val_accuracy: 0.7300 - val_loss: 0.3768
# Epoch 158/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7337 - loss: 0.3901 - val_accuracy: 0.7200 - val_loss: 0.3723
# Epoch 159/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7375 - loss: 0.3865 - val_accuracy: 0.7650 - val_loss: 0.3728
# Epoch 160/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7400 - loss: 0.3916 - val_accuracy: 0.7200 - val_loss: 0.3798
# Epoch 161/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7350 - loss: 0.3862 - val_accuracy: 0.7650 - val_loss: 0.3652
# Epoch 162/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7437 - loss: 0.3829 - val_accuracy: 0.7350 - val_loss: 0.3776
# Epoch 163/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7437 - loss: 0.3718 - val_accuracy: 0.7650 - val_loss: 0.3615
# Epoch 164/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7525 - loss: 0.3750 - val_accuracy: 0.7650 - val_loss: 0.3629
# Epoch 165/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7337 - loss: 0.3837 - val_accuracy: 0.7650 - val_loss: 0.3559
# Epoch 166/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7487 - loss: 0.3728 - val_accuracy: 0.7700 - val_loss: 0.3483
# Epoch 167/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7475 - loss: 0.3724 - val_accuracy: 0.7700 - val_loss: 0.3568
# Epoch 168/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7538 - loss: 0.3784 - val_accuracy: 0.7600 - val_loss: 0.3760
# Epoch 169/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7088 - loss: 0.4569 - val_accuracy: 0.6750 - val_loss: 0.5132
# Epoch 170/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6963 - loss: 0.4942 - val_accuracy: 0.7150 - val_loss: 0.4489
# Epoch 171/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7175 - loss: 0.4321 - val_accuracy: 0.7600 - val_loss: 0.3815
# Epoch 172/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7200 - loss: 0.4066 - val_accuracy: 0.7350 - val_loss: 0.3837
# Epoch 173/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7312 - loss: 0.4006 - val_accuracy: 0.7650 - val_loss: 0.3573
# Epoch 174/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7475 - loss: 0.3792 - val_accuracy: 0.7750 - val_loss: 0.3551
# Epoch 175/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7563 - loss: 0.3675 - val_accuracy: 0.7850 - val_loss: 0.3504
# Epoch 176/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7588 - loss: 0.3654 - val_accuracy: 0.7700 - val_loss: 0.3535
# Epoch 177/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7663 - loss: 0.3623 - val_accuracy: 0.7550 - val_loss: 0.3477
# Epoch 178/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7375 - loss: 0.3691 - val_accuracy: 0.7650 - val_loss: 0.3457
# Epoch 179/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7563 - loss: 0.3596 - val_accuracy: 0.7750 - val_loss: 0.3402
# Epoch 180/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7663 - loss: 0.3549 - val_accuracy: 0.7700 - val_loss: 0.3454
# Epoch 181/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7487 - loss: 0.3696 - val_accuracy: 0.7650 - val_loss: 0.3450
# Epoch 182/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7625 - loss: 0.3599 - val_accuracy: 0.7400 - val_loss: 0.4158
# Epoch 183/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7613 - loss: 0.3683 - val_accuracy: 0.7550 - val_loss: 0.5078
# Epoch 184/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7700 - loss: 0.3788 - val_accuracy: 0.7500 - val_loss: 0.3778
# Epoch 185/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7763 - loss: 0.3758 - val_accuracy: 0.7450 - val_loss: 0.3624
# Epoch 186/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7663 - loss: 0.3781 - val_accuracy: 0.7400 - val_loss: 0.3873
# Epoch 187/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7650 - loss: 0.3691 - val_accuracy: 0.7650 - val_loss: 0.3609
# Epoch 188/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8025 - loss: 0.3353 - val_accuracy: 0.7800 - val_loss: 0.3214
# Epoch 189/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8138 - loss: 0.3041 - val_accuracy: 0.8100 - val_loss: 0.3277
# Epoch 190/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8175 - loss: 0.3078 - val_accuracy: 0.8150 - val_loss: 0.2950
# Epoch 191/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8250 - loss: 0.2916 - val_accuracy: 0.8050 - val_loss: 0.3113
# Epoch 192/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8238 - loss: 0.3070 - val_accuracy: 0.7900 - val_loss: 0.3163
# Epoch 193/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8138 - loss: 0.3140 - val_accuracy: 0.8150 - val_loss: 0.3016
# Epoch 194/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8338 - loss: 0.2888 - val_accuracy: 0.8150 - val_loss: 0.3053
# Epoch 195/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8238 - loss: 0.2878 - val_accuracy: 0.8150 - val_loss: 0.2925
# Epoch 196/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8250 - loss: 0.3032 - val_accuracy: 0.7600 - val_loss: 0.3914
# Epoch 197/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8112 - loss: 0.3420 - val_accuracy: 0.7800 - val_loss: 0.3276
# Epoch 198/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7862 - loss: 0.3378 - val_accuracy: 0.8000 - val_loss: 0.3130
# Epoch 199/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8350 - loss: 0.2960 - val_accuracy: 0.8150 - val_loss: 0.3027
# Epoch 200/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8200 - loss: 0.2937 - val_accuracy: 0.8150 - val_loss: 0.2904
# Epoch 201/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8313 - loss: 0.2725 - val_accuracy: 0.8150 - val_loss: 0.2960
# Epoch 202/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8350 - loss: 0.2695 - val_accuracy: 0.8150 - val_loss: 0.2870
# Epoch 203/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8388 - loss: 0.2670 - val_accuracy: 0.8150 - val_loss: 0.2789
# Epoch 204/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7850 - loss: 0.3732 - val_accuracy: 0.7350 - val_loss: 0.4562
# Epoch 205/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7100 - loss: 0.5013 - val_accuracy: 0.7050 - val_loss: 0.3749
# Epoch 206/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7450 - loss: 0.3700 - val_accuracy: 0.7150 - val_loss: 0.3863
# Epoch 207/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7825 - loss: 0.3555 - val_accuracy: 0.7300 - val_loss: 0.3663
# Epoch 208/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7900 - loss: 0.3323 - val_accuracy: 0.8150 - val_loss: 0.3343
# Epoch 209/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8250 - loss: 0.3115 - val_accuracy: 0.8150 - val_loss: 0.3123
# Epoch 210/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8150 - loss: 0.3044 - val_accuracy: 0.8150 - val_loss: 0.3026
# Epoch 211/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8313 - loss: 0.2913 - val_accuracy: 0.8150 - val_loss: 0.2975
# Epoch 212/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8288 - loss: 0.2837 - val_accuracy: 0.8150 - val_loss: 0.2971
# Epoch 213/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8250 - loss: 0.2868 - val_accuracy: 0.8350 - val_loss: 0.2877
# Epoch 214/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8425 - loss: 0.2745 - val_accuracy: 0.8150 - val_loss: 0.3050
# Epoch 215/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8138 - loss: 0.2907 - val_accuracy: 0.8400 - val_loss: 0.2828
# Epoch 216/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8125 - loss: 0.3076 - val_accuracy: 0.7450 - val_loss: 0.4057
# Epoch 217/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7925 - loss: 0.3138 - val_accuracy: 0.7650 - val_loss: 0.3071
# Epoch 218/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8288 - loss: 0.2809 - val_accuracy: 0.8150 - val_loss: 0.2915
# Epoch 219/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8325 - loss: 0.2640 - val_accuracy: 0.7750 - val_loss: 0.2854
# Epoch 220/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8112 - loss: 0.2738 - val_accuracy: 0.8200 - val_loss: 0.2891
# Epoch 221/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8163 - loss: 0.3175 - val_accuracy: 0.6950 - val_loss: 0.4196
# Epoch 222/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7738 - loss: 0.4676 - val_accuracy: 0.6900 - val_loss: 0.3864
# Epoch 223/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7925 - loss: 0.3855 - val_accuracy: 0.7650 - val_loss: 0.3233
# Epoch 224/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8213 - loss: 0.3098 - val_accuracy: 0.8050 - val_loss: 0.3126
# Epoch 225/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8188 - loss: 0.2964 - val_accuracy: 0.8050 - val_loss: 0.3065
# Epoch 226/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8238 - loss: 0.2841 - val_accuracy: 0.7750 - val_loss: 0.3098
# Epoch 227/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8338 - loss: 0.2722 - val_accuracy: 0.8050 - val_loss: 0.2936
# Epoch 228/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8313 - loss: 0.2596 - val_accuracy: 0.8000 - val_loss: 0.2699
# Epoch 229/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8350 - loss: 0.2522 - val_accuracy: 0.7800 - val_loss: 0.2857
# Epoch 230/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8150 - loss: 0.2582 - val_accuracy: 0.8250 - val_loss: 0.2621
# Epoch 231/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8175 - loss: 0.2630 - val_accuracy: 0.7950 - val_loss: 0.2685
# Epoch 232/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8250 - loss: 0.2574 - val_accuracy: 0.8250 - val_loss: 0.4143
# Epoch 233/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8275 - loss: 0.2822 - val_accuracy: 0.8000 - val_loss: 0.3471
# Epoch 234/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8350 - loss: 0.2630 - val_accuracy: 0.8100 - val_loss: 0.2633
# Epoch 235/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8313 - loss: 0.2566 - val_accuracy: 0.7600 - val_loss: 0.2769
# Epoch 236/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8363 - loss: 0.2578 - val_accuracy: 0.8150 - val_loss: 0.2720
# Epoch 237/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8363 - loss: 0.2430 - val_accuracy: 0.8150 - val_loss: 0.2712
# Epoch 238/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8338 - loss: 0.2413 - val_accuracy: 0.8300 - val_loss: 0.2634
# Epoch 239/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8275 - loss: 0.2408 - val_accuracy: 0.8400 - val_loss: 0.2481
# Epoch 240/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8263 - loss: 0.2395 - val_accuracy: 0.8400 - val_loss: 0.2428
# Epoch 241/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8462 - loss: 0.2466 - val_accuracy: 0.8150 - val_loss: 0.2627
# Epoch 242/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8288 - loss: 0.2547 - val_accuracy: 0.8250 - val_loss: 0.2784
# Epoch 243/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8062 - loss: 0.3100 - val_accuracy: 0.7450 - val_loss: 0.7259
# Epoch 244/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7788 - loss: 0.3995 - val_accuracy: 0.7900 - val_loss: 0.5478
# Epoch 245/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8125 - loss: 0.3161 - val_accuracy: 0.8250 - val_loss: 0.2696
# Epoch 246/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8525 - loss: 0.2358 - val_accuracy: 0.8200 - val_loss: 0.2474
# Epoch 247/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8575 - loss: 0.2304 - val_accuracy: 0.8300 - val_loss: 0.2534
# Epoch 248/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8525 - loss: 0.2309 - val_accuracy: 0.8050 - val_loss: 0.2535
# Epoch 249/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8600 - loss: 0.2257 - val_accuracy: 0.8250 - val_loss: 0.2262
# Epoch 250/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8587 - loss: 0.2132 - val_accuracy: 0.8450 - val_loss: 0.2485
# Epoch 251/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8612 - loss: 0.2322 - val_accuracy: 0.8950 - val_loss: 0.2199
# Epoch 252/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8712 - loss: 0.2080 - val_accuracy: 0.8750 - val_loss: 0.2558
# Epoch 253/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8475 - loss: 0.2847 - val_accuracy: 0.7900 - val_loss: 0.3200
# Epoch 254/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8288 - loss: 0.2769 - val_accuracy: 0.8200 - val_loss: 0.2601
# Epoch 255/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8575 - loss: 0.2612 - val_accuracy: 0.8700 - val_loss: 0.2804
# Epoch 256/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8462 - loss: 0.2452 - val_accuracy: 0.8550 - val_loss: 0.2345
# Epoch 257/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8662 - loss: 0.2199 - val_accuracy: 0.8450 - val_loss: 0.2334
# Epoch 258/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8525 - loss: 0.2167 - val_accuracy: 0.8550 - val_loss: 0.2217
# Epoch 259/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8600 - loss: 0.2104 - val_accuracy: 0.8750 - val_loss: 0.2352
# Epoch 260/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8637 - loss: 0.2121 - val_accuracy: 0.8800 - val_loss: 0.2127
# Epoch 261/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8775 - loss: 0.1972 - val_accuracy: 0.8900 - val_loss: 0.2281
# Epoch 262/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8637 - loss: 0.2370 - val_accuracy: 0.8500 - val_loss: 0.2557
# Epoch 263/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8575 - loss: 0.2683 - val_accuracy: 0.8100 - val_loss: 0.3564
# Epoch 264/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8612 - loss: 0.2571 - val_accuracy: 0.8800 - val_loss: 0.2857
# Epoch 265/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8712 - loss: 0.2154 - val_accuracy: 0.8950 - val_loss: 0.2069
# Epoch 266/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8900 - loss: 0.1979 - val_accuracy: 0.8800 - val_loss: 0.2060
# Epoch 267/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9087 - loss: 0.1906 - val_accuracy: 0.8550 - val_loss: 0.1977
# Epoch 268/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8888 - loss: 0.1846 - val_accuracy: 0.8550 - val_loss: 0.2115
# Epoch 269/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8950 - loss: 0.1931 - val_accuracy: 0.8500 - val_loss: 0.2217
# Epoch 270/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8737 - loss: 0.2076 - val_accuracy: 0.8800 - val_loss: 0.2084
# Epoch 271/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8825 - loss: 0.1941 - val_accuracy: 0.8250 - val_loss: 0.2135
# Epoch 272/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8825 - loss: 0.2159 - val_accuracy: 0.8600 - val_loss: 0.2382
# Epoch 273/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8462 - loss: 0.2760 - val_accuracy: 0.8200 - val_loss: 0.2578
# Epoch 274/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8600 - loss: 0.2339 - val_accuracy: 0.8350 - val_loss: 0.2332
# Epoch 275/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8763 - loss: 0.2099 - val_accuracy: 0.8750 - val_loss: 0.2377
# Epoch 276/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8925 - loss: 0.2085 - val_accuracy: 0.8300 - val_loss: 0.2454
# Epoch 277/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8813 - loss: 0.1843 - val_accuracy: 0.8900 - val_loss: 0.1799
# Epoch 278/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9100 - loss: 0.1667 - val_accuracy: 0.8900 - val_loss: 0.1716
# Epoch 279/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9225 - loss: 0.1549 - val_accuracy: 0.8950 - val_loss: 0.1720
# Epoch 280/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9087 - loss: 0.1709 - val_accuracy: 0.8900 - val_loss: 0.1852
# Epoch 281/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8975 - loss: 0.1758 - val_accuracy: 0.8500 - val_loss: 0.2073
# Epoch 282/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8900 - loss: 0.1856 - val_accuracy: 0.8800 - val_loss: 0.2534
# Epoch 283/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8938 - loss: 0.2052 - val_accuracy: 0.8900 - val_loss: 0.1877
# Epoch 284/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9175 - loss: 0.1720 - val_accuracy: 0.9300 - val_loss: 0.1530
# Epoch 285/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9150 - loss: 0.1588 - val_accuracy: 0.8950 - val_loss: 0.3239
# Epoch 286/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8662 - loss: 0.2686 - val_accuracy: 0.8400 - val_loss: 0.3226
# Epoch 287/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8350 - loss: 0.3300 - val_accuracy: 0.8350 - val_loss: 0.3384
# Epoch 288/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8450 - loss: 0.3043 - val_accuracy: 0.8650 - val_loss: 0.2602
# Epoch 289/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8825 - loss: 0.2362 - val_accuracy: 0.8600 - val_loss: 0.2285
# Epoch 290/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8112 - loss: 0.4406 - val_accuracy: 0.7700 - val_loss: 0.4739
# Epoch 291/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8288 - loss: 0.3233 - val_accuracy: 0.8350 - val_loss: 0.3157
# Epoch 292/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8325 - loss: 0.3019 - val_accuracy: 0.8500 - val_loss: 0.2815
# Epoch 293/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8788 - loss: 0.2419 - val_accuracy: 0.8650 - val_loss: 0.2393
# Epoch 294/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8650 - loss: 0.2375 - val_accuracy: 0.8250 - val_loss: 0.2608
# Epoch 295/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8788 - loss: 0.2305 - val_accuracy: 0.8750 - val_loss: 0.2837
# Epoch 296/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8600 - loss: 0.2591 - val_accuracy: 0.8350 - val_loss: 0.2702
# Epoch 297/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8450 - loss: 0.2744 - val_accuracy: 0.8500 - val_loss: 0.2533
# Epoch 298/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8662 - loss: 0.2456 - val_accuracy: 0.8950 - val_loss: 0.2131
# Epoch 299/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9013 - loss: 0.2133 - val_accuracy: 0.9100 - val_loss: 0.2142
# Epoch 300/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8875 - loss: 0.2079 - val_accuracy: 0.9500 - val_loss: 0.1761

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Membership Inference Attack on Target Model Data

# %%
# Predict
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

features_train = X_test[:, :, :-1]  
class_train = X_test[:, :, -1:]     


mean = features_train.mean(axis=(0, 1), keepdims=True)
std = features_train.std(axis=(0, 1), keepdims=True)

features_train = (features_train - mean) / (std + 1e-8)
X_test = np.concatenate([features_train, class_train], axis=-1)
predictions = model.predict(X_test)

# # Convert probabilities to binary labels
predicted_labels = (predictions > 0.5).astype(int)

# Accuracy
acc = accuracy_score(y_test, predicted_labels)
print(f"Test Accuracy: {acc:.4f}")

# Confusion matrix
cm = confusion_matrix(y_test, predicted_labels)
print("Confusion Matrix:\n", cm)

# Plot
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Test Set", "Training Set"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Test Accuracy: 0.9500
# Confusion Matrix:
#  [[138  12]
#  [  3 147]]

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_auc_score,
    roc_curve,
    f1_score
)
import matplotlib.pyplot as plt
import numpy as np

# Binary predictions using threshold 0.5
predicted_labels = (predictions >= 0.5).astype(int)

# F1 Score
f1 = f1_score(y_test, predicted_labels)
print(f"F1 Score: {f1:.4f}")

# AUC Score
auc_score = roc_auc_score(y_test, predictions)
print(f"AUC Score: {auc_score:.4f}")

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, predictions)

# Plot ROC Curve
plt.figure()
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.4f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # Random chance line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# F1 Score: 0.9515
# AUC Score: 0.9921
