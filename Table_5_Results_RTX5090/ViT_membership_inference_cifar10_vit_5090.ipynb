# %% [markdown]
# ## Table 4: ViT-Base model's results on CIFAR-10 dataset using RTX 5090 GPU

# %% [markdown]
# ### Section 1: Loading Dataset

# %%
import numpy as np
import pandas as pd

# %%
vit_base_data=[]
vit_base_data_test=[]

for i in range(1,101):
    temp1=[]
    for j in range(10):
        path='./mem_csv_vit_base_cifar10_5090_3/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    vit_base_data.append(temp1)

for i in range(1,31):
    temp1=[]
    for j in range(10):
        path='./mem_csv_vit_base_cifar10_5090_test5/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    vit_base_data_test.append(temp1)

print(vit_base_data[0][1].columns)
print(vit_base_data_test[0][1].columns)
# Out:
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'syslts__t_tag_requests.avg.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.max.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.min.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.sum.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.avg.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.max.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.min.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.sum.pct_of_peak_sustained_elapsed',
#        'thread_inst_executed', 'thread_inst_executed_true'],
#       dtype='object', length=2062)
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'syslts__t_tag_requests.avg.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.max.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.min.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.sum.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.avg.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.max.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.min.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.sum.pct_of_peak_sustained_elapsed',
#        'thread_inst_executed', 'thread_inst_executed_true'],
#       dtype='object', length=2062)

# %% [markdown]
# ### Section 2: Pre-processing Dataset

# %%
for i in range(100):
    for j in range(10):
        vit_base_data[i][j]=vit_base_data[i][j].drop(['ID'], axis=1)
        if 0 in vit_base_data[i][j].index:
            vit_base_data[i][j] = vit_base_data[i][j].drop(index=0)

for i in range(30):
    for j in range(10):
        vit_base_data_test[i][j]=vit_base_data_test[i][j].drop(['ID'], axis=1)
        if 0 in vit_base_data_test[i][j].index:
            vit_base_data_test[i][j] = vit_base_data_test[i][j].drop(index=0)

# %%
vit_base_data_test[0][0]['Kernel Name'].unique
# Out:
# <bound method Series.unique of 1     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 2     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 3     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 4     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 5     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 6     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 7     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 8     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 9     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 10    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 11    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 12    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# Name: Kernel Name, dtype: object>

# %% [markdown]
# ### Section 3: Metric-based Data filtering and pre-processing

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import random


kernel_name=['fmha_cutlassF_f32_aligned_64x64_rf_sm80(AttentionKernel<bfloat16_t, Sm80, 1, 64, 64, 64, 1, 1>::Params)']
ltx_cols=[col for col in vit_base_data[0][1].columns if 
    col.startswith('smsp__inst_issued')
            or col.startswith('smsp__average_warps_issue_stalled_imc_miss_per_issue_active') 
            or col.startswith('smsp__average_warps_issue_stalled_wait_per_issue_active.ratio') 
             or col.startswith('smsp__sass_thread_inst_executed_op_fadd_pred_on.min')
]
for col in ltx_cols:
    for i in range(100):
        for j in range(10):
            if vit_base_data[i][j][col].dtype == 'object':  # likely string
                vit_base_data[i][j][col] = pd.to_numeric(vit_base_data[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')

    for i in range(30):
        for j in range(10):
            if vit_base_data_test[i][j][col].dtype == 'object':  # likely string
                vit_base_data_test[i][j][col] = pd.to_numeric(vit_base_data_test[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
                
# Optional: update the DataFrame back
print(ltx_cols)
# Out:
# /home/t1000/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ['smsp__average_warps_issue_stalled_wait_per_issue_active.ratio', 'smsp__inst_issued.avg', 'smsp__inst_issued.max', 'smsp__inst_issued.min', 'smsp__inst_issued.sum', 'smsp__sass_thread_inst_executed_op_fadd_pred_on.min.per_cycle_elapsed']

# %% [markdown]
# print(len(all_class_data))

# %% [markdown]
# ### Section 4: Generating classifier model's training data and validation data by considering only the filtered Metrics.

# %%
col = [col for col in vit_base_data[0][1].columns if 
       col.startswith('smsp__inst_issued')
        or col.startswith('smsp__average_warps_issue_stalled_imc_miss_per_issue_active') 
        or col.startswith('smsp__average_warps_issue_stalled_wait_per_issue_active.ratio') 
         or col.startswith('smsp__inst_executed.sum')
]

for i in range(100):
    for j in range(10):
        for c in col:
            vit_base_data[i][j][c]=pd.to_numeric(vit_base_data[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')
           
for i in range(30):
    for j in range(10):
        for c in col:
            vit_base_data_test[i][j][c]=pd.to_numeric(vit_base_data_test[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')



# Loop through each DataFrame and keep only the selected columns (if they exist)
vit_base_data_df=[[[] for i in range(10)] for j in range(100)]
vit_base_data_test_df=[[[] for i in range(10)] for j in range(30)]

for i in range(len(vit_base_data)):
    for j in range(len(vit_base_data[i])):
        df2 = vit_base_data[i][j]
        # Keep only the columns that exist in the current DataFrame
        selected_cols = [c for c in col if c in df2.columns]
        vit_base_data_df[i][j] = vit_base_data[i][j][selected_cols].copy()

for i in range(len(vit_base_data_test)):
    for j in range(len(vit_base_data_test[i])):
        df2 = vit_base_data_test[i][j]
        # Keep only the columns that exist in the current DataFrame
        selected_cols = [c for c in col if c in df2.columns]
        vit_base_data_test_df[i][j] = vit_base_data_test[i][j][selected_cols].copy()

# %%
print(col)
# Out:
# ['smsp__average_warps_issue_stalled_wait_per_issue_active.ratio', 'smsp__inst_executed.sum', 'smsp__inst_issued.avg', 'smsp__inst_issued.max', 'smsp__inst_issued.min', 'smsp__inst_issued.sum']

# %%
vit_base_data_test_df[0][0].shape
# Out:
# (12, 6)

# %% [markdown]
# ### Dataset re-arrangement and providing label for training and test samples for both shadow and target model. Also, selecting appropiate range of FMHA kernel instances for achieving maximum attack success rate.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=[]
y_train=[]
X_test=[]
y_test=[]

for i in range(100):
    for j in range(10):
        r = vit_base_data_df[i][j]  # shape: (12, 2)
        X_train.append(r)

        if i < 50:
            y_train.append(1)
        else:
            y_train.append(0)

for i in range(30):
    for j in range(10):
        r = vit_base_data_test_df[i][j]  # shape: (12, 2)

        X_test.append(r)

        if i < 15:
            y_test.append(1)
        else:
            y_test.append(0)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train[:, 0:12, :]
X_test = X_test[:, 0:12, :]
    
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1000, 12, 6) (1000,)
# (300, 12, 6) (300,)

# %%
import numpy as np
print(np.unique(y_train, return_counts=True))
print(np.unique(y_test, return_counts=True))
print(type(X_train[0][0][0]))
# Out:
# (array([0, 1]), array([500, 500]))
# (array([0, 1]), array([150, 150]))
# <class 'numpy.float32'>

# %% [markdown]
# ### Attack Classifier training

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout, BatchNormalization
import numpy as np
from sklearn.model_selection import train_test_split

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  
def reset_random_seeds():
   os.environ['PYTHONHASHSEED']=str(42)
   tf.random.set_seed(42)
   np.random.seed(42)
   random.seed(42)


reset_random_seeds()
import tensorflow as tf

# Your input data shape: (samples, sequence_length, feature_dim)
num_samples = X_train.shape[0]
sequence_length = X_train.shape[1]
feature_dim = X_train.shape[2]

# Define the model
# Stacked BiLSTM Layers
model = Sequential()
model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=(sequence_length, feature_dim)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(32, return_sequences=False)))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))


# Compile
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

mean = X_train.mean(axis=(0, 1), keepdims=True)
std = X_train.std(axis=(0, 1), keepdims=True)
X_train = (X_train - mean) / (std + 1e-8)
# Summary
model.summary()
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)
# Train
history = model.fit(
    X_train_split, y_train_split,
    epochs=90,
    batch_size=45,
    validation_data=(X_val_split, y_val_split)
)
# Out:
# 2026-08-24 13:58:25.604572: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-24 13:58:25.632437: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-24 13:58:26.486897: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-24 13:58:26.598897: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-08-24 13:58:26.598917: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# 2026-08-24 13:58:26.598920: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# 2026-08-24 13:58:26.598923: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2026-08-24 13:58:26.598926: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: vhj4ybwysf5e7ppbc5tbh6f2ez
# 2026-08-24 13:58:26.598927: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] hostname: vhj4ybwysf5e7ppbc5tbh6f2ez
# 2026-08-24 13:58:26.598974: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] libcuda reported version is: 580.95.5
# 2026-08-24 13:58:26.598986: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:194] kernel reported version is: 580.95.5
# 2026-08-24 13:58:26.598987: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:284] kernel version seems to match DSO: 580.95.5
# /home/t1000/.local/lib/python3.10/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 12, 128)        │        36,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 64)             │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81,793 (319.50 KB)
#  Trainable params: 81,793 (319.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.5863 - loss: 0.6810 - val_accuracy: 0.5950 - val_loss: 0.6745
# Epoch 2/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5875 - loss: 0.6713 - val_accuracy: 0.5950 - val_loss: 0.6758
# Epoch 3/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5925 - loss: 0.6696 - val_accuracy: 0.5900 - val_loss: 0.6753
# Epoch 4/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5825 - loss: 0.6674 - val_accuracy: 0.5900 - val_loss: 0.6763
# Epoch 5/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5900 - loss: 0.6681 - val_accuracy: 0.5900 - val_loss: 0.6737
# Epoch 6/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5813 - loss: 0.6669 - val_accuracy: 0.5850 - val_loss: 0.6735
# Epoch 7/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5850 - loss: 0.6664 - val_accuracy: 0.5900 - val_loss: 0.6735
# Epoch 8/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5863 - loss: 0.6657 - val_accuracy: 0.5850 - val_loss: 0.6732
# Epoch 9/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5950 - loss: 0.6645 - val_accuracy: 0.5850 - val_loss: 0.6713
# Epoch 10/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5825 - loss: 0.6634 - val_accuracy: 0.5800 - val_loss: 0.6716
# Epoch 11/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5838 - loss: 0.6638 - val_accuracy: 0.5800 - val_loss: 0.6718
# Epoch 12/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5975 - loss: 0.6636 - val_accuracy: 0.5850 - val_loss: 0.6717
# Epoch 13/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5938 - loss: 0.6617 - val_accuracy: 0.6000 - val_loss: 0.6722
# Epoch 14/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5900 - loss: 0.6600 - val_accuracy: 0.6350 - val_loss: 0.6694
# Epoch 15/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5850 - loss: 0.6634 - val_accuracy: 0.6000 - val_loss: 0.6625
# Epoch 16/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5788 - loss: 0.6574 - val_accuracy: 0.6250 - val_loss: 0.6664
# Epoch 17/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6025 - loss: 0.6538 - val_accuracy: 0.6250 - val_loss: 0.6621
# Epoch 18/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6037 - loss: 0.6545 - val_accuracy: 0.6250 - val_loss: 0.6554
# Epoch 19/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5875 - loss: 0.6496 - val_accuracy: 0.6300 - val_loss: 0.6519
# Epoch 20/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6000 - loss: 0.6463 - val_accuracy: 0.6350 - val_loss: 0.6413
# Epoch 21/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5900 - loss: 0.6507 - val_accuracy: 0.6200 - val_loss: 0.6433
# Epoch 22/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6050 - loss: 0.6332 - val_accuracy: 0.6450 - val_loss: 0.6292
# Epoch 23/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6212 - loss: 0.6331 - val_accuracy: 0.6650 - val_loss: 0.6186
# Epoch 24/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6288 - loss: 0.6188 - val_accuracy: 0.6500 - val_loss: 0.6096
# Epoch 25/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6162 - loss: 0.6283 - val_accuracy: 0.6250 - val_loss: 0.6115
# Epoch 26/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6425 - loss: 0.6140 - val_accuracy: 0.6800 - val_loss: 0.5943
# Epoch 27/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6475 - loss: 0.5973 - val_accuracy: 0.6600 - val_loss: 0.5881
# Epoch 28/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6438 - loss: 0.5953 - val_accuracy: 0.6600 - val_loss: 0.5909
# Epoch 29/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6612 - loss: 0.5865 - val_accuracy: 0.6800 - val_loss: 0.5718
# Epoch 30/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6562 - loss: 0.5824 - val_accuracy: 0.6850 - val_loss: 0.5521
# Epoch 31/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6850 - loss: 0.5599 - val_accuracy: 0.7100 - val_loss: 0.5370
# Epoch 32/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6750 - loss: 0.5560 - val_accuracy: 0.7100 - val_loss: 0.5224
# Epoch 33/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6913 - loss: 0.5425 - val_accuracy: 0.7250 - val_loss: 0.5157
# Epoch 34/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6812 - loss: 0.5429 - val_accuracy: 0.7700 - val_loss: 0.4980
# Epoch 35/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7000 - loss: 0.5159 - val_accuracy: 0.7150 - val_loss: 0.5073
# Epoch 36/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7013 - loss: 0.5157 - val_accuracy: 0.7400 - val_loss: 0.4985
# Epoch 37/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7100 - loss: 0.5117 - val_accuracy: 0.7400 - val_loss: 0.4922
# Epoch 38/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6888 - loss: 0.5355 - val_accuracy: 0.7250 - val_loss: 0.5116
# Epoch 39/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6988 - loss: 0.4959 - val_accuracy: 0.7500 - val_loss: 0.4558
# Epoch 40/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7337 - loss: 0.4729 - val_accuracy: 0.7650 - val_loss: 0.4539
# Epoch 41/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7350 - loss: 0.4616 - val_accuracy: 0.7350 - val_loss: 0.4635
# Epoch 42/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7362 - loss: 0.4627 - val_accuracy: 0.7750 - val_loss: 0.4295
# Epoch 43/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7563 - loss: 0.4379 - val_accuracy: 0.7600 - val_loss: 0.4552
# Epoch 44/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7500 - loss: 0.4446 - val_accuracy: 0.7950 - val_loss: 0.4184
# Epoch 45/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7538 - loss: 0.4406 - val_accuracy: 0.7450 - val_loss: 0.4592
# Epoch 46/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7575 - loss: 0.4468 - val_accuracy: 0.7900 - val_loss: 0.4182
# Epoch 47/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7613 - loss: 0.4274 - val_accuracy: 0.7850 - val_loss: 0.3953
# Epoch 48/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7650 - loss: 0.4057 - val_accuracy: 0.7750 - val_loss: 0.3985
# Epoch 49/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7688 - loss: 0.4212 - val_accuracy: 0.8150 - val_loss: 0.3905
# Epoch 50/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7800 - loss: 0.3928 - val_accuracy: 0.7250 - val_loss: 0.4238
# Epoch 51/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7800 - loss: 0.3876 - val_accuracy: 0.7850 - val_loss: 0.3891
# Epoch 52/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8125 - loss: 0.3903 - val_accuracy: 0.7950 - val_loss: 0.3917
# Epoch 53/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7812 - loss: 0.3913 - val_accuracy: 0.7600 - val_loss: 0.4304
# Epoch 54/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7500 - loss: 0.4167 - val_accuracy: 0.7800 - val_loss: 0.3950
# Epoch 55/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7837 - loss: 0.4163 - val_accuracy: 0.8000 - val_loss: 0.4031
# Epoch 56/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7825 - loss: 0.4081 - val_accuracy: 0.7450 - val_loss: 0.4312
# Epoch 57/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7950 - loss: 0.3915 - val_accuracy: 0.7850 - val_loss: 0.3788
# Epoch 58/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8037 - loss: 0.3769 - val_accuracy: 0.8050 - val_loss: 0.3642
# Epoch 59/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7763 - loss: 0.4242 - val_accuracy: 0.7800 - val_loss: 0.4649
# Epoch 60/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7375 - loss: 0.4614 - val_accuracy: 0.7050 - val_loss: 0.5425
# Epoch 61/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7713 - loss: 0.4001 - val_accuracy: 0.8250 - val_loss: 0.3549
# Epoch 62/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8100 - loss: 0.3554 - val_accuracy: 0.8500 - val_loss: 0.3272
# Epoch 63/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8263 - loss: 0.3527 - val_accuracy: 0.8650 - val_loss: 0.3094
# Epoch 64/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8338 - loss: 0.3272 - val_accuracy: 0.8750 - val_loss: 0.3131
# Epoch 65/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8250 - loss: 0.3506 - val_accuracy: 0.8750 - val_loss: 0.2873
# Epoch 66/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7962 - loss: 0.3682 - val_accuracy: 0.8350 - val_loss: 0.3314
# Epoch 67/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8250 - loss: 0.3343 - val_accuracy: 0.8850 - val_loss: 0.3103
# Epoch 68/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8562 - loss: 0.3164 - val_accuracy: 0.8900 - val_loss: 0.2928
# Epoch 69/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8413 - loss: 0.3255 - val_accuracy: 0.8750 - val_loss: 0.3135
# Epoch 70/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8650 - loss: 0.3083 - val_accuracy: 0.8600 - val_loss: 0.2941
# Epoch 71/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8450 - loss: 0.3071 - val_accuracy: 0.8900 - val_loss: 0.2773
# Epoch 72/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8637 - loss: 0.2790 - val_accuracy: 0.8600 - val_loss: 0.2806
# Epoch 73/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8700 - loss: 0.2723 - val_accuracy: 0.9000 - val_loss: 0.2329
# Epoch 74/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9075 - loss: 0.2406 - val_accuracy: 0.9000 - val_loss: 0.2327
# Epoch 75/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8875 - loss: 0.2495 - val_accuracy: 0.8700 - val_loss: 0.2490
# Epoch 76/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8763 - loss: 0.2512 - val_accuracy: 0.8800 - val_loss: 0.2523
# Epoch 77/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9050 - loss: 0.2248 - val_accuracy: 0.8900 - val_loss: 0.2045
# Epoch 78/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8975 - loss: 0.2333 - val_accuracy: 0.9150 - val_loss: 0.1722
# Epoch 79/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9137 - loss: 0.2063 - val_accuracy: 0.9100 - val_loss: 0.1715
# Epoch 80/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9125 - loss: 0.2018 - val_accuracy: 0.9350 - val_loss: 0.1506
# Epoch 81/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9087 - loss: 0.2065 - val_accuracy: 0.9300 - val_loss: 0.1484
# Epoch 82/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9312 - loss: 0.1736 - val_accuracy: 0.9300 - val_loss: 0.1681
# Epoch 83/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9162 - loss: 0.1968 - val_accuracy: 0.9600 - val_loss: 0.1387
# Epoch 84/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9050 - loss: 0.2242 - val_accuracy: 0.9400 - val_loss: 0.1434
# Epoch 85/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9175 - loss: 0.1884 - val_accuracy: 0.9400 - val_loss: 0.1287
# Epoch 86/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9262 - loss: 0.1638 - val_accuracy: 0.9650 - val_loss: 0.1154
# Epoch 87/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9075 - loss: 0.1934 - val_accuracy: 0.9100 - val_loss: 0.2264
# Epoch 88/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9187 - loss: 0.1947 - val_accuracy: 0.9450 - val_loss: 0.1322
# Epoch 89/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9225 - loss: 0.1942 - val_accuracy: 0.9400 - val_loss: 0.1546
# Epoch 90/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9212 - loss: 0.1861 - val_accuracy: 0.9050 - val_loss: 0.2061

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Membership Inference Attack on Target Model Data

# %%
# Predict
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

mean = X_test.mean(axis=(0, 1), keepdims=True)
std = X_test.std(axis=(0, 1), keepdims=True)
X_test = (X_test - mean) / (std + 1e-8)

# Predict probabilities
predictions = model.predict(X_test)

# # Convert probabilities to binary labels
predicted_labels = (predictions > 0.5).astype(int)

# Accuracy
acc = accuracy_score(y_test, predicted_labels)
print(f"Test Accuracy: {acc:.4f}")

# Confusion matrix
cm = confusion_matrix(y_test, predicted_labels)
print("Confusion Matrix:\n", cm)

# Plot
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Test Set","Training Set"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Test Accuracy: 0.9533
# Confusion Matrix:
#  [[146   4]
#  [ 10 140]]

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_auc_score,
    roc_curve,
    f1_score
)
import matplotlib.pyplot as plt
import numpy as np

# Binary predictions using threshold 0.5
predicted_labels = (predictions >= 0.5).astype(int)

# F1 Score
f1 = f1_score(y_test, predicted_labels)
print(f"F1 Score: {f1:.4f}")

# AUC Score
auc_score = roc_auc_score(y_test, predictions)
print(f"AUC Score: {auc_score:.4f}")

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, predictions)

# Plot ROC Curve
plt.figure()
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.4f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # Random chance line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# F1 Score: 0.9524
# AUC Score: 0.9929
