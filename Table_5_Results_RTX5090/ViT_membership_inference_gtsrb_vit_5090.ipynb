# %% [markdown]
# ## Table 4: ViT-Base model's results on GTSRB dataset using RTX 5090 GPU

# %% [markdown]
# ### Section 1: Loading Dataset

# %%
import numpy as np
import pandas as pd

# %%
vit_base_data=[]
vit_base_data_test=[]

for i in range(1,101):
    temp1=[]
    for j in range(10):
        path='./mem_csv_vit_base_gtsrb_5090/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    vit_base_data.append(temp1)
 
for i in range(1,31):
    temp1=[]
    for j in range(10):
        path='./mem_csv_vit_base_gtsrb_5090_test/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    vit_base_data_test.append(temp1)


print(vit_base_data[0][1].columns)
print(vit_base_data_test[0][1].columns)
# Out:
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'syslts__t_tag_requests.avg.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.max.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.min.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.sum.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.avg.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.max.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.min.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.sum.pct_of_peak_sustained_elapsed',
#        'thread_inst_executed', 'thread_inst_executed_true'],
#       dtype='object', length=2062)
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'syslts__t_tag_requests.avg.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.max.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.min.pct_of_peak_sustained_elapsed',
#        'syslts__t_tag_requests.sum.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.avg.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.max.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.min.pct_of_peak_sustained_elapsed',
#        'syslts__xbar2syslts_cycles_active.sum.pct_of_peak_sustained_elapsed',
#        'thread_inst_executed', 'thread_inst_executed_true'],
#       dtype='object', length=2062)

# %% [markdown]
# ### Section 2: Pre-processing Dataset

# %%
for i in range(100):
    for j in range(10):
        vit_base_data[i][j]=vit_base_data[i][j].drop(['ID'], axis=1)
        if 0 in vit_base_data[i][j].index:
            vit_base_data[i][j] = vit_base_data[i][j].drop(index=0)

for i in range(30):
    for j in range(10):
        vit_base_data_test[i][j]=vit_base_data_test[i][j].drop(['ID'], axis=1)
        if 0 in vit_base_data_test[i][j].index:
            vit_base_data_test[i][j] = vit_base_data_test[i][j].drop(index=0)

# %%
vit_base_data_test[0][0]['Kernel Name'].unique
# Out:
# <bound method Series.unique of 1     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 2     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 3     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 4     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 5     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 6     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 7     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 8     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 9     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 10    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 11    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 12    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# Name: Kernel Name, dtype: object>

# %% [markdown]
# ### Section 3: Metric-based Data filtering and pre-processing

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import random

kernel_name=['fmha_cutlassF_f32_aligned_64x64_rf_sm80']
ltx_cols=[col for col in vit_base_data[0][1].columns if 
    col.startswith('l1tex__data_bank_conflicts_pipe_lsu_mem_shared_op_ld.sum') 
            or col.startswith('smsp__average_warps_issue_stalled_misc_per_issue_active.ratio') 
            or col.startswith('smsp__average_warps_issue_stalled_no_instruction_per_issue_active.ratio') 
            or col.startswith('sm__inst_executed_pipe_cbu_pred_on_any')
]

for col in ltx_cols:
    for i in range(100):
        for j in range(10):
            if vit_base_data[i][j][col].dtype == 'object':  # likely string
                vit_base_data[i][j][col] = pd.to_numeric(vit_base_data[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
            
    for i in range(30):
        for j in range(10):
            if vit_base_data_test[i][j][col].dtype == 'object':  # likely string
                vit_base_data_test[i][j][col] = pd.to_numeric(vit_base_data_test[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
# Optional: update the DataFrame back
print(ltx_cols)
# Out:
# /home/t1000/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ['l1tex__data_bank_conflicts_pipe_lsu_mem_shared_op_ld.sum', 'sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.max.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.min.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.sum.pct_of_peak_sustained_elapsed', 'smsp__average_warps_issue_stalled_misc_per_issue_active.ratio', 'smsp__average_warps_issue_stalled_no_instruction_per_issue_active.ratio']

# %% [markdown]
# print(len(all_class_data))

# %%
# all_class_data[0][1]['thread_inst_executed_true']
vit_base_data[0][0].shape
# Out:
# (12, 2061)

# %% [markdown]
# ### Section 4: Generating classifier model's training data and validation data by considering only the filtered Metrics.

# %%
col = [col for col in vit_base_data[0][1].columns if 
      col.startswith('l1tex__data_bank_conflicts_pipe_lsu_mem_shared_op_ld.sum') 
        or col.startswith('smsp__average_warps_issue_stalled_misc_per_issue_active.ratio') 
        or col.startswith('smsp__average_warps_issue_stalled_no_instruction_per_issue_active.ratio') 
        or col.startswith('sm__inst_executed_pipe_cbu_pred_on_any')
]

for i in range(10):
    for j in range(10):
        for c in col:
            vit_base_data[i][j][c]=pd.to_numeric(vit_base_data[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')
           
for i in range(30):
    for j in range(10):
        for c in col:
            vit_base_data_test[i][j][c]=pd.to_numeric(vit_base_data_test[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')



# Loop through each DataFrame and keep only the selected columns (if they exist)
vit_base_data_df=[[[] for i in range(10)] for j in range(100)]
vit_base_data_test_df=[[[] for i in range(10)] for j in range(30)]

for i in range(len(vit_base_data)):
    for j in range(len(vit_base_data[i])):
        df2 = vit_base_data[i][j]
        # Keep only the columns that exist in the current DataFrame
        selected_cols = [c for c in col if c in df2.columns]
        vit_base_data_df[i][j] = vit_base_data[i][j][selected_cols].copy()

for i in range(len(vit_base_data_test)):
    for j in range(len(vit_base_data_test[i])):
        df2 = vit_base_data_test[i][j]
        # Keep only the columns that exist in the current DataFrame
        selected_cols = [c for c in col if c in df2.columns]
        vit_base_data_test_df[i][j] = df2[selected_cols].copy()

# %%
print(col)
# Out:
# ['l1tex__data_bank_conflicts_pipe_lsu_mem_shared_op_ld.sum', 'sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.max.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.min.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.sum.pct_of_peak_sustained_elapsed', 'smsp__average_warps_issue_stalled_misc_per_issue_active.ratio', 'smsp__average_warps_issue_stalled_no_instruction_per_issue_active.ratio']

# %%
vit_base_data_test_df[0][0].shape
# Out:
# (12, 7)

# %% [markdown]
# ### Dataset re-arrangement and providing label for training and test samples for both shadow and target model. Also, selecting appropiate range of FMHA kernel instances for achieving maximum attack success rate.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=[]
y_train=[]
X_test=[]
y_test=[]

for i in range(100):
    for j in range(10):
        r = vit_base_data_df[i][j]  # shape: (12, 2)
        X_train.append(r)

        if i < 50:
            y_train.append(1)
        else:
            y_train.append(0)


for i in range(30):
    for j in range(10):
        r = vit_base_data_test_df[i][j]  # shape: (12, 2)
        X_test.append(r)

        if i < 15:
            y_test.append(1)
        else:
            y_test.append(0)


X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train[:,0:8, :]
X_test = X_test[:, 0:8, :]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1000, 8, 7) (1000,)
# (300, 8, 7) (300,)

# %%
print(X_train.dtype)
print(X_train[0, 0, :10])  # print a few sample feature values
# Out:
# float64
# [5.76600400e+06 5.99636972e-01 6.21972978e-01 5.84390998e-01
#  5.99636972e-01 2.84900004e-03 6.79010004e-02]

# %%
X_train = X_train.astype(np.float32)

# %%
import numpy as np
print(np.unique(y_train, return_counts=True))
print(np.unique(y_test, return_counts=True))
# Out:
# (array([0, 1]), array([500, 500]))
# (array([0, 1]), array([150, 150]))

# %%
from tensorflow.keras.utils import to_categorical
# Out:
# 2026-08-24 16:16:09.825316: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-24 16:16:09.852164: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-24 16:16:10.549229: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# ### Attack Classifier training

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout, BatchNormalization
import numpy as np
# np.random.seed(42) 
from sklearn.model_selection import train_test_split

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1" 
def reset_random_seeds():
   os.environ['PYTHONHASHSEED']=str(42)
   tf.random.set_seed(42)
   np.random.seed(42)
   random.seed(42)
reset_random_seeds()
import tensorflow as tf

# Your input data shape: (samples, sequence_length, feature_dim)
num_samples = X_train.shape[0]
sequence_length = X_train.shape[1]
feature_dim = X_train.shape[2]

# Define the model
# Stacked BiLSTM Layers
model = Sequential()
model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=(sequence_length, feature_dim)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(32, return_sequences=False)))
model.add(Dropout(0.2))

# Fully connected hidden layer
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))


# Compile
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
mean = X_train.mean(axis=(0, 1), keepdims=True)
std = X_train.std(axis=(0, 1), keepdims=True)
X_train = (X_train - mean) / (std + 1e-8)


# Summary
model.summary()
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)
# Train
history = model.fit(
    X_train_split, y_train_split,
    epochs=200,
    batch_size=45,
    validation_data=(X_val_split, y_val_split)
)
# Out:
# 2026-08-24 16:16:10.793432: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-08-24 16:16:10.793449: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# 2026-08-24 16:16:10.793452: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# 2026-08-24 16:16:10.793454: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2026-08-24 16:16:10.793456: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: vhj4ybwysf5e7ppbc5tbh6f2ez
# 2026-08-24 16:16:10.793458: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] hostname: vhj4ybwysf5e7ppbc5tbh6f2ez
# 2026-08-24 16:16:10.793520: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] libcuda reported version is: 580.95.5
# 2026-08-24 16:16:10.793530: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:194] kernel reported version is: 580.95.5
# 2026-08-24 16:16:10.793531: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:284] kernel version seems to match DSO: 580.95.5
# /home/t1000/.local/lib/python3.10/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 8, 128)         │        36,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 64)             │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 82,305 (321.50 KB)
#  Trainable params: 82,305 (321.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.5512 - loss: 0.6847 - val_accuracy: 0.5300 - val_loss: 0.6916
# Epoch 2/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6212 - loss: 0.6702 - val_accuracy: 0.5400 - val_loss: 0.6971
# Epoch 3/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6137 - loss: 0.6575 - val_accuracy: 0.5300 - val_loss: 0.6953
# Epoch 4/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6075 - loss: 0.6505 - val_accuracy: 0.5200 - val_loss: 0.6876
# Epoch 5/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6225 - loss: 0.6479 - val_accuracy: 0.5600 - val_loss: 0.6865
# Epoch 6/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6263 - loss: 0.6416 - val_accuracy: 0.5500 - val_loss: 0.6831
# Epoch 7/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6225 - loss: 0.6377 - val_accuracy: 0.5300 - val_loss: 0.6782
# Epoch 8/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6463 - loss: 0.6335 - val_accuracy: 0.5400 - val_loss: 0.6712
# Epoch 9/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6225 - loss: 0.6372 - val_accuracy: 0.5450 - val_loss: 0.6650
# Epoch 10/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6237 - loss: 0.6214 - val_accuracy: 0.5450 - val_loss: 0.6659
# Epoch 11/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6450 - loss: 0.6137 - val_accuracy: 0.6000 - val_loss: 0.6651
# Epoch 12/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6400 - loss: 0.6077 - val_accuracy: 0.6150 - val_loss: 0.6542
# Epoch 13/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6675 - loss: 0.5920 - val_accuracy: 0.6100 - val_loss: 0.6433
# Epoch 14/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6812 - loss: 0.5967 - val_accuracy: 0.6200 - val_loss: 0.6501
# Epoch 15/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6612 - loss: 0.5818 - val_accuracy: 0.6200 - val_loss: 0.6462
# Epoch 16/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6812 - loss: 0.5809 - val_accuracy: 0.6150 - val_loss: 0.6307
# Epoch 17/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6562 - loss: 0.5800 - val_accuracy: 0.6600 - val_loss: 0.6119
# Epoch 18/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6600 - loss: 0.5722 - val_accuracy: 0.6700 - val_loss: 0.6100
# Epoch 19/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6775 - loss: 0.5646 - val_accuracy: 0.6850 - val_loss: 0.5979
# Epoch 20/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6700 - loss: 0.5617 - val_accuracy: 0.6850 - val_loss: 0.6173
# Epoch 21/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7000 - loss: 0.5501 - val_accuracy: 0.6850 - val_loss: 0.5886
# Epoch 22/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7063 - loss: 0.5367 - val_accuracy: 0.6750 - val_loss: 0.6009
# Epoch 23/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7250 - loss: 0.5163 - val_accuracy: 0.7000 - val_loss: 0.5878
# Epoch 24/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7375 - loss: 0.5107 - val_accuracy: 0.7050 - val_loss: 0.5835
# Epoch 25/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9725 - loss: 0.0938 - val_accuracy: 0.9300 - val_loss: 0.1702
# Epoch 90/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9875 - loss: 0.0526 - val_accuracy: 0.9650 - val_loss: 0.1194
# Epoch 91/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9812 - loss: 0.0462 - val_accuracy: 0.9700 - val_loss: 0.0834
# Epoch 92/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9887 - loss: 0.0400 - val_accuracy: 0.9500 - val_loss: 0.1944
# Epoch 93/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9812 - loss: 0.0478 - val_accuracy: 0.9700 - val_loss: 0.1329
# Epoch 94/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9862 - loss: 0.0549 - val_accuracy: 0.9450 - val_loss: 0.1521
# Epoch 95/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9925 - loss: 0.0276 - val_accuracy: 0.9750 - val_loss: 0.0900
# Epoch 96/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - loss: 0.0217 - val_accuracy: 0.9650 - val_loss: 0.0910
# Epoch 97/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9887 - loss: 0.0396 - val_accuracy: 0.9700 - val_loss: 0.1173
# Epoch 98/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9900 - loss: 0.0288 - val_accuracy: 0.9600 - val_loss: 0.1154
# Epoch 99/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9862 - loss: 0.0420 - val_accuracy: 0.9650 - val_loss: 0.1043
# Epoch 100/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9825 - loss: 0.0487 - val_accuracy: 0.9250 - val_loss: 0.2356
# Epoch 101/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9538 - loss: 0.1067 - val_accuracy: 0.9650 - val_loss: 0.1281
# Epoch 102/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9762 - loss: 0.0808 - val_accuracy: 0.9400 - val_loss: 0.2277
# Epoch 103/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9812 - loss: 0.0539 - val_accuracy: 0.9750 - val_loss: 0.1232
# Epoch 104/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9862 - loss: 0.0439 - val_accuracy: 0.9400 - val_loss: 0.1765
# Epoch 105/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9850 - loss: 0.0502 - val_accuracy: 0.9450 - val_loss: 0.1941
# Epoch 106/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9825 - loss: 0.0437 - val_accuracy: 0.9700 - val_loss: 0.1172
# Epoch 107/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9837 - loss: 0.0382 - val_accuracy: 0.9600 - val_loss: 0.1345
# Epoch 108/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9900 - loss: 0.0358 - val_accuracy: 0.9650 - val_loss: 0.1528
# Epoch 109/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0239 - val_accuracy: 0.9750 - val_loss: 0.1377
# Epoch 110/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0165 - val_accuracy: 0.9700 - val_loss: 0.1012
# Epoch 111/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - loss: 0.0177 - val_accuracy: 0.9800 - val_loss: 0.1027
# Epoch 112/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9937 - loss: 0.0211 - val_accuracy: 0.9700 - val_loss: 0.1450
# Epoch 113/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0155 - val_accuracy: 0.9750 - val_loss: 0.1096
# Epoch 114/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9925 - loss: 0.0174 - val_accuracy: 0.9800 - val_loss: 0.0642
# Epoch 115/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0114 - val_accuracy: 0.9850 - val_loss: 0.0998
# Epoch 116/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0104 - val_accuracy: 0.9800 - val_loss: 0.0813
# Epoch 117/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9812 - loss: 0.0451 - val_accuracy: 0.9650 - val_loss: 0.2001
# Epoch 118/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9862 - loss: 0.0301 - val_accuracy: 0.9600 - val_loss: 0.1320
# Epoch 119/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9937 - loss: 0.0151 - val_accuracy: 0.9650 - val_loss: 0.1388
# Epoch 120/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9937 - loss: 0.0149 - val_accuracy: 0.9750 - val_loss: 0.0982
# Epoch 121/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9962 - loss: 0.0171 - val_accuracy: 0.9750 - val_loss: 0.1098
# Epoch 122/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9912 - loss: 0.0334 - val_accuracy: 0.9450 - val_loss: 0.2178
# Epoch 123/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9912 - loss: 0.0169 - val_accuracy: 0.9900 - val_loss: 0.0667
# Epoch 124/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9962 - loss: 0.0118 - val_accuracy: 0.9800 - val_loss: 0.0802
# Epoch 125/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0071 - val_accuracy: 0.9850 - val_loss: 0.0643
# Epoch 126/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0064 - val_accuracy: 0.9800 - val_loss: 0.0892
# Epoch 127/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0071 - val_accuracy: 0.9750 - val_loss: 0.1485
# Epoch 128/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9975 - loss: 0.0069 - val_accuracy: 0.9800 - val_loss: 0.1414
# Epoch 129/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0106 - val_accuracy: 0.9650 - val_loss: 0.1422
# Epoch 130/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9837 - loss: 0.0615 - val_accuracy: 0.9450 - val_loss: 0.2622
# Epoch 131/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9812 - loss: 0.0533 - val_accuracy: 0.9550 - val_loss: 0.2120
# Epoch 132/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9862 - loss: 0.0446 - val_accuracy: 0.9650 - val_loss: 0.1527
# Epoch 133/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9837 - loss: 0.0576 - val_accuracy: 0.9750 - val_loss: 0.0937
# Epoch 134/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9887 - loss: 0.0385 - val_accuracy: 0.9550 - val_loss: 0.1701
# Epoch 135/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0200 - val_accuracy: 0.9800 - val_loss: 0.0803
# Epoch 136/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.9850 - val_loss: 0.0716
# Epoch 137/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9962 - loss: 0.0139 - val_accuracy: 0.9700 - val_loss: 0.0961
# Epoch 138/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9975 - loss: 0.0103 - val_accuracy: 0.9850 - val_loss: 0.0939
# Epoch 139/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0072 - val_accuracy: 0.9650 - val_loss: 0.1256
# Epoch 140/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9937 - loss: 0.0241 - val_accuracy: 0.9850 - val_loss: 0.1405
# Epoch 141/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9800 - loss: 0.0661 - val_accuracy: 0.9600 - val_loss: 0.1500
# Epoch 142/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9762 - loss: 0.0881 - val_accuracy: 0.9850 - val_loss: 0.0988
# Epoch 143/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9900 - loss: 0.0316 - val_accuracy: 0.9550 - val_loss: 0.1824
# Epoch 144/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9887 - loss: 0.0375 - val_accuracy: 0.9650 - val_loss: 0.1051
# Epoch 145/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9737 - loss: 0.0898 - val_accuracy: 0.8900 - val_loss: 0.2898
# Epoch 146/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9737 - loss: 0.0703 - val_accuracy: 0.9600 - val_loss: 0.1424
# Epoch 147/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9912 - loss: 0.0318 - val_accuracy: 0.9700 - val_loss: 0.1169
# Epoch 148/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9775 - loss: 0.0694 - val_accuracy: 0.9400 - val_loss: 0.2647
# Epoch 149/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9688 - loss: 0.0872 - val_accuracy: 0.9700 - val_loss: 0.1295
# Epoch 150/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0219 - val_accuracy: 0.9700 - val_loss: 0.1314
# Epoch 151/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0089 - val_accuracy: 0.9850 - val_loss: 0.0902
# Epoch 152/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0142 - val_accuracy: 0.9800 - val_loss: 0.0974
# Epoch 153/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0095 - val_accuracy: 0.9650 - val_loss: 0.1678
# Epoch 154/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9937 - loss: 0.0145 - val_accuracy: 0.9700 - val_loss: 0.1535
# Epoch 155/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0172 - val_accuracy: 0.9750 - val_loss: 0.1230
# Epoch 156/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9912 - loss: 0.0262 - val_accuracy: 0.9650 - val_loss: 0.0544
# Epoch 157/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9875 - loss: 0.0334 - val_accuracy: 0.9750 - val_loss: 0.1203
# Epoch 158/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9900 - loss: 0.0283 - val_accuracy: 0.9850 - val_loss: 0.0652
# Epoch 159/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0143 - val_accuracy: 0.9700 - val_loss: 0.0869
# Epoch 160/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9800 - val_loss: 0.0680
# Epoch 161/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0054 - val_accuracy: 0.9800 - val_loss: 0.0586
# Epoch 162/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9975 - loss: 0.0060 - val_accuracy: 0.9800 - val_loss: 0.0760
# Epoch 163/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9850 - val_loss: 0.0690
# Epoch 164/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9850 - val_loss: 0.0593
# Epoch 165/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0063 - val_accuracy: 0.9800 - val_loss: 0.0831
# Epoch 166/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9975 - loss: 0.0077 - val_accuracy: 0.9550 - val_loss: 0.1622
# Epoch 167/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9962 - loss: 0.0147 - val_accuracy: 0.9750 - val_loss: 0.0923
# Epoch 168/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0060 - val_accuracy: 0.9700 - val_loss: 0.1104
# Epoch 169/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9900 - loss: 0.0180 - val_accuracy: 0.9750 - val_loss: 0.0894
# Epoch 170/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9937 - loss: 0.0219 - val_accuracy: 0.9750 - val_loss: 0.0977
# Epoch 171/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0105 - val_accuracy: 0.9850 - val_loss: 0.0734
# Epoch 172/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9925 - loss: 0.0449 - val_accuracy: 0.9600 - val_loss: 0.1986
# Epoch 173/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9875 - loss: 0.0364 - val_accuracy: 0.9850 - val_loss: 0.1130
# Epoch 174/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0197 - val_accuracy: 0.9850 - val_loss: 0.1059
# Epoch 175/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9975 - loss: 0.0106 - val_accuracy: 0.9750 - val_loss: 0.1227
# Epoch 176/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9800 - val_loss: 0.1046
# Epoch 177/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0057 - val_accuracy: 0.9800 - val_loss: 0.1116
# Epoch 178/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9850 - val_loss: 0.1112
# Epoch 179/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9850 - val_loss: 0.1015
# Epoch 180/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9850 - val_loss: 0.1031
# Epoch 181/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0035 - val_accuracy: 0.9850 - val_loss: 0.0940
# Epoch 182/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9850 - val_loss: 0.0969
# Epoch 183/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9850 - val_loss: 0.1032
# Epoch 184/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9962 - loss: 0.0053 - val_accuracy: 0.9750 - val_loss: 0.0990
# Epoch 185/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9937 - loss: 0.0241 - val_accuracy: 0.9750 - val_loss: 0.0608
# Epoch 186/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0129 - val_accuracy: 0.9700 - val_loss: 0.1476
# Epoch 187/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9962 - loss: 0.0073 - val_accuracy: 0.9800 - val_loss: 0.0870
# Epoch 188/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9800 - val_loss: 0.0728
# Epoch 189/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9750 - val_loss: 0.1015
# Epoch 190/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9800 - val_loss: 0.0955
# Epoch 191/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9800 - val_loss: 0.0918
# Epoch 192/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9850 - val_loss: 0.0877
# Epoch 193/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9900 - val_loss: 0.0762
# Epoch 194/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0057 - val_accuracy: 0.9850 - val_loss: 0.0912
# Epoch 195/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9900 - loss: 0.0499 - val_accuracy: 0.9800 - val_loss: 0.0926
# Epoch 196/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9925 - loss: 0.0329 - val_accuracy: 0.9850 - val_loss: 0.0983
# Epoch 197/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9837 - loss: 0.0482 - val_accuracy: 0.9650 - val_loss: 0.1105
# Epoch 198/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9588 - loss: 0.1316 - val_accuracy: 0.8650 - val_loss: 0.5531
# Epoch 199/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9325 - loss: 0.2753 - val_accuracy: 0.9200 - val_loss: 0.2804
# Epoch 200/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9550 - loss: 0.1178 - val_accuracy: 0.9350 - val_loss: 0.1503

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Membership Inference Attack on Target Model Data

# %%
# Predict
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

mean = X_test.mean(axis=(0, 1), keepdims=True)
std = X_test.std(axis=(0, 1), keepdims=True)
X_test = (X_test - mean) / (std + 1e-8)

# Predict probabilities
predictions = model.predict(X_test)

# # Convert probabilities to binary labels
predicted_labels = (predictions > 0.5).astype(int)

# Accuracy
acc = accuracy_score(y_test, predicted_labels)
print(f"Test Accuracy: {acc:.4f}")

# Confusion matrix
cm = confusion_matrix(y_test, predicted_labels)
print("Confusion Matrix:\n", cm)

# Plot
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Test Set", "Training Set"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Test Accuracy: 0.9400
# Confusion Matrix:
#  [[139  11]
#  [  7 143]]

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_auc_score,
    roc_curve,
    f1_score
)
import matplotlib.pyplot as plt
import numpy as np

# Binary predictions using threshold 0.5
predicted_labels = (predictions >= 0.5).astype(int)

# F1 Score
f1 = f1_score(y_test, predicted_labels)
print(f"F1 Score: {f1:.4f}")

# AUC Score
auc_score = roc_auc_score(y_test, predictions)
print(f"AUC Score: {auc_score:.4f}")

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, predictions)

# Plot ROC Curve
plt.figure()
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.4f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # Random chance line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# F1 Score: 0.9408
# AUC Score: 0.9788
