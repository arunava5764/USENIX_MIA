# %% [markdown]
# ## Table 2: ViT-Base model's class leakage results on CIFAR10 dataset using RTX 4500 Ada GPU

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Section 1: Loading Dataset

# %%
all_class_data=[]
for i in range(1,501):
    temp=[]
    for j in range(10):
        path='./mem_csv_vit_base_cifar10_class/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp.append(data)
    all_class_data.append(temp)
    
print(all_class_data[0][1].columns)
# Out:
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'smsp__warps_active.min.peak_sustained',
#        'smsp__warps_active.min.per_cycle_active',
#        'smsp__warps_active.sum.peak_sustained',
#        'smsp__warps_active.sum.per_cycle_active',
#        'smsp__warps_eligible.avg.per_cycle_active',
#        'smsp__warps_eligible.max.per_cycle_active',
#        'smsp__warps_eligible.min.per_cycle_active',
#        'smsp__warps_eligible.sum.per_cycle_active', 'thread_inst_executed',
#        'thread_inst_executed_true'],
#       dtype='object', length=1220)

# %% [markdown]
# ### Section 2: Pre-processing Dataset

# %%
for i in range(500):
    for j in range(10):
        all_class_data[i][j]=all_class_data[i][j].drop(['ID'], axis=1)
        if 0 in all_class_data[i][j].index:
            all_class_data[i][j] = all_class_data[i][j].drop(index=0)

# %%
print(all_class_data[0][1].columns)
# Out:
# Index(['Process ID', 'Process Name', 'Host Name', 'Kernel Name', 'Context',
#        'Stream', 'Block Size', 'Grid Size', 'Device', 'CC',
#        ...
#        'smsp__warps_active.min.peak_sustained',
#        'smsp__warps_active.min.per_cycle_active',
#        'smsp__warps_active.sum.peak_sustained',
#        'smsp__warps_active.sum.per_cycle_active',
#        'smsp__warps_eligible.avg.per_cycle_active',
#        'smsp__warps_eligible.max.per_cycle_active',
#        'smsp__warps_eligible.min.per_cycle_active',
#        'smsp__warps_eligible.sum.per_cycle_active', 'thread_inst_executed',
#        'thread_inst_executed_true'],
#       dtype='object', length=1219)

# %% [markdown]
# ### Section 3: Metric-based Data filtering and pre-processing

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib


kernel_name=['fmha_cutlassF_f32_aligned_64x64_rf_sm80']
ltx_cols = [col for col in all_class_data[0][1].columns if col.startswith('thread_inst_executed')]# or col.startswith('gpu__') or col.startswith('sm__')]
for col in ltx_cols:
    for i in range(500):
        for j in range(10):
            if all_class_data[i][j][col].dtype == 'object':  # likely string
                all_class_data[i][j][col] = pd.to_numeric(all_class_data[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')

# %% [markdown]
# print(len(all_class_data))

# %% [markdown]
# ### Section 4: Generating classifier model's training data and validation data by considering only the filtered Metrics.

# %%
col = [col for col in all_class_data[0][1].columns if 
        col.startswith('smsp__branch_targets_threads_divergent') 
        or col.startswith('smsp__inst_executed.sum') 
        or col.startswith('smsp__inst_executed_op_shared_atom') 
         or col.startswith('smsp__sass_thread_inst_executed_op_fadd_pred_on.min') #
        or col.startswith('smsp__sass_thread_inst_executed_op_ffma_pred_on.min') #
        or col.startswith('smsp__sass_thread_inst_executed_op_fmul_pred_on.min') #
    or col.startswith('dram__bytes_write.sum')
]

col.append('thread_inst_executed')

for i in range(500):
    for j in range(10):
        for c in col:
            all_class_data[i][j][c]=pd.to_numeric(all_class_data[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')

# Loop through each DataFrame and keep only the selected columns (if they exist)
df=[[[] for i in range(10)] for j in range(500)]
for i in range(len(all_class_data)):
    for j in range(len(all_class_data[i])):
        df2 = all_class_data[i][j]
        # Keep only the columns that exist in the current DataFrame
        selected_cols = [c for c in col if c in df2.columns]
        df[i][j] = df2[selected_cols].copy()

# %% [markdown]
# ### Dataset re-arrangement

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X=[]
y=[]
for i in range(500):
    for j in range(10):
        t=scaler.fit_transform(df[i][j])
        # t=df[i][j]
        X.append(t)
        y.append(j)
X = np.array(X)
y = np.array(y)
print(X.shape, y.shape)
# Out:
# (5000, 12, 11) (5000,)

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
inp_ch= X.shape[2]
# Out:
# cuda:0

# %% [markdown]
# ### Attack Classifier training and 5-fold cross validation

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class CNNTimeSeriesClassifier(nn.Module):
    def __init__(self, num_classes=10):
        super(CNNTimeSeriesClassifier, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=inp_ch, out_channels=32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm1d(32)
        self.conv2 = nn.Conv1d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm1d(64)
        self.pool = nn.AdaptiveMaxPool1d(1)
        self.fc = nn.Linear(64, num_classes)

    def forward(self, x):
        # Input shape: (batch_size, 12, 6)
        x = x.permute(0, 2, 1)  # Convert to (batch_size, 6, 12)
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)  # (batch_size, 64, 1)
        x = x.squeeze(-1)  # (batch_size, 64)
        x = self.fc(x)  # (batch_size, num_classes)
        return x

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
from torch.optim.lr_scheduler import ReduceLROnPlateau



X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.long)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
print(X_train.shape, y_train.shape)
# Move to DataLoader if needed
batch_size = 32
train_dataset = torch.utils.data.TensorDataset(X_train, y_train)
val_dataset = torch.utils.data.TensorDataset(X_val, y_val)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size)
# Out:
# torch.Size([4000, 12, 11]) torch.Size([4000])
# Epoch 01 | Loss: 281.8968 | Train Acc: 18.32% | Val Acc: 27.90%
# Epoch 02 | Loss: 243.4729 | Train Acc: 35.17% | Val Acc: 43.60%
# Epoch 03 | Loss: 208.8141 | Train Acc: 47.77% | Val Acc: 52.60%
# Epoch 04 | Loss: 179.1345 | Train Acc: 55.43% | Val Acc: 58.70%
# Epoch 05 | Loss: 158.7067 | Train Acc: 60.00% | Val Acc: 61.30%
# Epoch 06 | Loss: 144.1319 | Train Acc: 63.35% | Val Acc: 64.80%
# Epoch 07 | Loss: 131.6070 | Train Acc: 67.00% | Val Acc: 68.40%
# Epoch 08 | Loss: 121.9370 | Train Acc: 69.42% | Val Acc: 69.80%
# Epoch 09 | Loss: 112.9923 | Train Acc: 71.70% | Val Acc: 73.40%
# Epoch 10 | Loss: 105.8737 | Train Acc: 73.83% | Val Acc: 73.00%
# Epoch 11 | Loss: 99.6790 | Train Acc: 75.58% | Val Acc: 73.90%
# Epoch 12 | Loss: 94.6311 | Train Acc: 76.68% | Val Acc: 75.10%
# Epoch 13 | Loss: 89.4972 | Train Acc: 78.60% | Val Acc: 75.40%
# Epoch 48 | Loss: 15.3862 | Train Acc: 98.28% | Val Acc: 93.40%
# Epoch 49 | Loss: 14.9244 | Train Acc: 98.22% | Val Acc: 94.20%
# Epoch 50 | Loss: 13.5554 | Train Acc: 98.80% | Val Acc: 93.70%
# Epoch 51 | Loss: 14.0691 | Train Acc: 98.52% | Val Acc: 94.70%
# Epoch 52 | Loss: 13.0555 | Train Acc: 98.70% | Val Acc: 94.50%
# Epoch 53 | Loss: 12.8466 | Train Acc: 98.58% | Val Acc: 94.60%
# Epoch 54 | Loss: 11.8680 | Train Acc: 98.70% | Val Acc: 94.40%
# Epoch 55 | Loss: 10.7057 | Train Acc: 99.20% | Val Acc: 95.80%
# Epoch 56 | Loss: 10.0549 | Train Acc: 99.20% | Val Acc: 94.70%
# Epoch 57 | Loss: 10.1606 | Train Acc: 99.28% | Val Acc: 95.00%
# Epoch 58 | Loss: 9.6429 | Train Acc: 99.25% | Val Acc: 95.50%
# Epoch 59 | Loss: 9.4154 | Train Acc: 99.25% | Val Acc: 93.80%
# Epoch 60 | Loss: 8.9193 | Train Acc: 99.25% | Val Acc: 95.30%
# Epoch 61 | Loss: 8.1971 | Train Acc: 99.62% | Val Acc: 95.10%
# Epoch 62 | Loss: 7.6965 | Train Acc: 99.52% | Val Acc: 95.70%
# Epoch 63 | Loss: 7.5179 | Train Acc: 99.42% | Val Acc: 94.90%
# Epoch 64 | Loss: 7.4835 | Train Acc: 99.60% | Val Acc: 95.30%
# Epoch 65 | Loss: 7.2146 | Train Acc: 99.40% | Val Acc: 96.40%
# Epoch 66 | Loss: 6.1460 | Train Acc: 99.85% | Val Acc: 95.70%
# Epoch 67 | Loss: 6.2096 | Train Acc: 99.83% | Val Acc: 96.70%
# Epoch 68 | Loss: 6.0497 | Train Acc: 99.65% | Val Acc: 96.10%
# Epoch 69 | Loss: 5.8845 | Train Acc: 99.75% | Val Acc: 96.10%
# Epoch 70 | Loss: 5.7569 | Train Acc: 99.85% | Val Acc: 96.30%
# Epoch 71 | Loss: 5.2818 | Train Acc: 99.80% | Val Acc: 96.70%
# Epoch 72 | Loss: 5.2818 | Train Acc: 99.72% | Val Acc: 97.30%
# Epoch 73 | Loss: 4.9496 | Train Acc: 99.70% | Val Acc: 96.20%
# Epoch 74 | Loss: 4.6893 | Train Acc: 99.85% | Val Acc: 96.80%
# Epoch 75 | Loss: 4.5256 | Train Acc: 99.90% | Val Acc: 96.90%
# Epoch 76 | Loss: 4.3216 | Train Acc: 99.85% | Val Acc: 97.20%
# Epoch 77 | Loss: 4.3541 | Train Acc: 99.83% | Val Acc: 97.00%
# Epoch 78 | Loss: 4.2973 | Train Acc: 99.85% | Val Acc: 97.80%
# Epoch 79 | Loss: 3.5592 | Train Acc: 99.98% | Val Acc: 97.30%
# Epoch 80 | Loss: 3.4684 | Train Acc: 99.90% | Val Acc: 97.70%
#
# Confusion Matrix (Validation):
# Accuracy: 97.70%

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
import random

random.seed(10)

# Configuration
k_folds = 5
num_epochs = 85
batch_size = 32
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Assuming X and y are torch tensors
# X = X.cpu().numpy()  # Convert to numpy for sklearn
# y = y.cpu().numpy()

skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

fold_results = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    print(f"\n--- Fold {fold} ---")

    # Create data for current fold
    X_train_fold = X[train_idx].clone().detach().float()
    y_train_fold = y[train_idx].clone().detach().long()
    X_val_fold = X[val_idx].clone().detach().float()
    y_val_fold = y[val_idx].clone().detach().long()

    train_dataset = TensorDataset(X_train_fold, y_train_fold)
    val_dataset = TensorDataset(X_val_fold, y_val_fold)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # New model instance per fold
    model = CNNTimeSeriesClassifier().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)#, verbose=True)

    for epoch in range(1, num_epochs + 1):
        model.train()
        total_loss = 0
        y_true_train, y_pred_train = [], []

        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            out = model(xb)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            y_pred_train.extend(torch.argmax(out, dim=1).cpu().numpy())
            y_true_train.extend(yb.cpu().numpy())

        train_acc = accuracy_score(y_true_train, y_pred_train)

        # Validation
        model.eval()
        y_true_val, y_pred_val = [], []
        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                out = model(xb)
                y_pred_val.extend(torch.argmax(out, dim=1).cpu().numpy())
                y_true_val.extend(yb.cpu().numpy())

        val_acc = accuracy_score(y_true_val, y_pred_val)
        
        print(f"Fold {fold} | Epoch {epoch:02d} | Loss: {total_loss:.4f} "
              f"| Train Acc: {train_acc*100:.2f}% | Val Acc: {val_acc*100:.2f}%")

    # Store final accuracy for this fold
    fold_results.append(val_acc)

# Summary
print("\n=== K-Fold Cross Validation Results ===")
print(f"Accuracies for each fold: {[f'{acc*100:.2f}%' for acc in fold_results]}")
print(f"Average Accuracy: {np.mean(fold_results)*100:.2f}%")
# Out:
# --- Fold 1 ---
# Fold 1 | Epoch 01 | Loss: 279.3152 | Train Acc: 16.90% | Val Acc: 24.70%
# Fold 1 | Epoch 02 | Loss: 247.8422 | Train Acc: 32.35% | Val Acc: 36.90%
# Fold 1 | Epoch 03 | Loss: 219.5329 | Train Acc: 43.15% | Val Acc: 43.20%
# Fold 1 | Epoch 04 | Loss: 195.8567 | Train Acc: 48.15% | Val Acc: 51.10%
# Fold 1 | Epoch 05 | Loss: 174.7064 | Train Acc: 54.87% | Val Acc: 56.00%
# Fold 1 | Epoch 06 | Loss: 156.3905 | Train Acc: 59.88% | Val Acc: 58.90%
# Fold 1 | Epoch 07 | Loss: 142.8692 | Train Acc: 63.52% | Val Acc: 63.80%
# Fold 1 | Epoch 08 | Loss: 131.0946 | Train Acc: 67.27% | Val Acc: 66.40%
# Fold 1 | Epoch 09 | Loss: 120.8467 | Train Acc: 69.67% | Val Acc: 68.50%
# Fold 1 | Epoch 10 | Loss: 112.6324 | Train Acc: 71.58% | Val Acc: 70.20%
# Fold 1 | Epoch 11 | Loss: 106.4981 | Train Acc: 73.38% | Val Acc: 71.00%
# Fold 1 | Epoch 12 | Loss: 99.9005 | Train Acc: 74.83% | Val Acc: 70.00%
# Fold 1 | Epoch 13 | Loss: 94.7228 | Train Acc: 76.80% | Val Acc: 72.40%
# Fold 4 | Epoch 54 | Loss: 11.3370 | Train Acc: 99.17% | Val Acc: 94.40%
# Fold 4 | Epoch 55 | Loss: 11.3269 | Train Acc: 99.30% | Val Acc: 95.00%
# Fold 4 | Epoch 56 | Loss: 10.4662 | Train Acc: 99.35% | Val Acc: 94.80%
# Fold 4 | Epoch 57 | Loss: 10.4750 | Train Acc: 99.12% | Val Acc: 95.10%
# Fold 4 | Epoch 58 | Loss: 9.6840 | Train Acc: 99.35% | Val Acc: 95.60%
# Fold 4 | Epoch 59 | Loss: 9.1297 | Train Acc: 99.42% | Val Acc: 95.90%
# Fold 4 | Epoch 60 | Loss: 8.7684 | Train Acc: 99.52% | Val Acc: 95.90%
# Fold 4 | Epoch 61 | Loss: 8.4553 | Train Acc: 99.58% | Val Acc: 95.70%
# Fold 4 | Epoch 62 | Loss: 8.0361 | Train Acc: 99.60% | Val Acc: 95.10%
# Fold 4 | Epoch 63 | Loss: 7.3284 | Train Acc: 99.62% | Val Acc: 96.00%
# Fold 4 | Epoch 64 | Loss: 7.0086 | Train Acc: 99.75% | Val Acc: 96.50%
# Fold 4 | Epoch 65 | Loss: 7.2049 | Train Acc: 99.83% | Val Acc: 96.00%
# Fold 4 | Epoch 66 | Loss: 6.4040 | Train Acc: 99.83% | Val Acc: 97.10%
# Fold 4 | Epoch 67 | Loss: 6.7215 | Train Acc: 99.62% | Val Acc: 97.00%
# Fold 4 | Epoch 68 | Loss: 6.0567 | Train Acc: 99.75% | Val Acc: 96.30%
# Fold 4 | Epoch 69 | Loss: 6.2206 | Train Acc: 99.72% | Val Acc: 97.20%
# Fold 4 | Epoch 70 | Loss: 5.4076 | Train Acc: 99.80% | Val Acc: 96.70%
# Fold 4 | Epoch 71 | Loss: 5.1587 | Train Acc: 99.80% | Val Acc: 97.30%
# Fold 4 | Epoch 72 | Loss: 5.6030 | Train Acc: 99.67% | Val Acc: 96.20%
# Fold 4 | Epoch 73 | Loss: 4.8683 | Train Acc: 99.85% | Val Acc: 96.30%
# Fold 4 | Epoch 74 | Loss: 4.9645 | Train Acc: 99.67% | Val Acc: 96.50%
# Fold 4 | Epoch 75 | Loss: 4.5314 | Train Acc: 99.78% | Val Acc: 96.90%
# Fold 4 | Epoch 76 | Loss: 4.3943 | Train Acc: 99.80% | Val Acc: 96.90%
# Fold 4 | Epoch 77 | Loss: 3.9980 | Train Acc: 99.85% | Val Acc: 97.20%
# Fold 4 | Epoch 78 | Loss: 3.6203 | Train Acc: 99.92% | Val Acc: 97.30%
# Fold 4 | Epoch 79 | Loss: 3.5398 | Train Acc: 99.92% | Val Acc: 97.30%
# Fold 4 | Epoch 80 | Loss: 3.2774 | Train Acc: 99.95% | Val Acc: 96.90%
# Fold 4 | Epoch 81 | Loss: 3.2847 | Train Acc: 99.92% | Val Acc: 97.50%
# Fold 4 | Epoch 82 | Loss: 3.4641 | Train Acc: 99.85% | Val Acc: 97.40%
# Fold 4 | Epoch 83 | Loss: 2.9465 | Train Acc: 99.98% | Val Acc: 97.60%
# Fold 5 | Epoch 58 | Loss: 10.3689 | Train Acc: 99.02% | Val Acc: 94.70%
# Fold 5 | Epoch 59 | Loss: 9.4870 | Train Acc: 99.20% | Val Acc: 94.20%
# Fold 5 | Epoch 60 | Loss: 8.8034 | Train Acc: 99.28% | Val Acc: 93.50%
# Fold 5 | Epoch 61 | Loss: 8.6411 | Train Acc: 99.38% | Val Acc: 94.00%
# Fold 5 | Epoch 62 | Loss: 8.5770 | Train Acc: 99.48% | Val Acc: 93.10%
# Fold 5 | Epoch 63 | Loss: 7.2997 | Train Acc: 99.60% | Val Acc: 94.30%
# Fold 5 | Epoch 64 | Loss: 7.0281 | Train Acc: 99.72% | Val Acc: 95.00%
# Fold 5 | Epoch 65 | Loss: 6.6576 | Train Acc: 99.72% | Val Acc: 93.70%
# Fold 5 | Epoch 66 | Loss: 6.5644 | Train Acc: 99.67% | Val Acc: 95.30%
# Fold 5 | Epoch 67 | Loss: 6.7256 | Train Acc: 99.72% | Val Acc: 95.40%
# Fold 5 | Epoch 68 | Loss: 5.8256 | Train Acc: 99.65% | Val Acc: 95.90%
# Fold 5 | Epoch 69 | Loss: 5.9887 | Train Acc: 99.65% | Val Acc: 94.70%
# Fold 5 | Epoch 70 | Loss: 5.6377 | Train Acc: 99.83% | Val Acc: 95.70%
# Fold 5 | Epoch 71 | Loss: 4.8758 | Train Acc: 99.95% | Val Acc: 95.50%
# Fold 5 | Epoch 72 | Loss: 5.3460 | Train Acc: 99.83% | Val Acc: 96.00%
# Fold 5 | Epoch 73 | Loss: 4.9340 | Train Acc: 99.83% | Val Acc: 95.50%
# Fold 5 | Epoch 74 | Loss: 4.7132 | Train Acc: 99.78% | Val Acc: 96.10%
# Fold 5 | Epoch 75 | Loss: 4.4907 | Train Acc: 99.88% | Val Acc: 96.60%
# Fold 5 | Epoch 76 | Loss: 4.4563 | Train Acc: 99.80% | Val Acc: 95.40%
# Fold 5 | Epoch 77 | Loss: 4.8812 | Train Acc: 99.70% | Val Acc: 96.00%
# Fold 5 | Epoch 78 | Loss: 3.9159 | Train Acc: 99.83% | Val Acc: 96.30%
# Fold 5 | Epoch 79 | Loss: 3.6118 | Train Acc: 99.90% | Val Acc: 96.10%
# Fold 5 | Epoch 80 | Loss: 3.4121 | Train Acc: 99.90% | Val Acc: 96.00%
# Fold 5 | Epoch 81 | Loss: 3.2822 | Train Acc: 99.90% | Val Acc: 95.30%
# Fold 5 | Epoch 82 | Loss: 2.9366 | Train Acc: 100.00% | Val Acc: 97.00%
# Fold 5 | Epoch 83 | Loss: 3.1567 | Train Acc: 99.88% | Val Acc: 96.70%
# Fold 5 | Epoch 84 | Loss: 3.4210 | Train Acc: 99.88% | Val Acc: 96.60%
# Fold 5 | Epoch 85 | Loss: 2.9283 | Train Acc: 99.92% | Val Acc: 97.10%
#
# === K-Fold Cross Validation Results ===
# Accuracies for each fold: ['97.30%', '97.30%', '97.00%', '98.00%', '97.10%']
# Average Accuracy: 97.34%
