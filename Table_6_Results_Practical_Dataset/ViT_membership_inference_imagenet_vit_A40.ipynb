# %% [markdown]
# ## Table 6: ViT-Base model's results on Imagenet dataset using A40 GPU

# %% [markdown]
# ### Section 1: Loading Dataset

# %%
import numpy as np
import pandas as pd

# %%
vit_base_data=[]
vit_base_data_test=[]


for i in range(1,101):
    temp1=[]
    for j in range(10):
        path='mem_csv_vit_base_imagenet_a30/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    vit_base_data.append(temp1)
    
for i in range(1,31):
    temp1=[]
    for j in range(10):
        path='/home/t1000/Desktop/GPU_Traces/mem_csv_vit_base_imagenet_test_a30/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    vit_base_data_test.append(temp1)


print(vit_base_data[0][1].columns)
print(vit_base_data_test[0][1].columns)
# Out:
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'smsp__warps_active.min.peak_sustained',
#        'smsp__warps_active.min.per_cycle_active',
#        'smsp__warps_active.sum.peak_sustained',
#        'smsp__warps_active.sum.per_cycle_active',
#        'smsp__warps_eligible.avg.per_cycle_active',
#        'smsp__warps_eligible.max.per_cycle_active',
#        'smsp__warps_eligible.min.per_cycle_active',
#        'smsp__warps_eligible.sum.per_cycle_active', 'thread_inst_executed',
#        'thread_inst_executed_true'],
#       dtype='object', length=1244)
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'smsp__warps_active.min.peak_sustained',
#        'smsp__warps_active.min.per_cycle_active',
#        'smsp__warps_active.sum.peak_sustained',
#        'smsp__warps_active.sum.per_cycle_active',
#        'smsp__warps_eligible.avg.per_cycle_active',
#        'smsp__warps_eligible.max.per_cycle_active',
#        'smsp__warps_eligible.min.per_cycle_active',
#        'smsp__warps_eligible.sum.per_cycle_active', 'thread_inst_executed',
#        'thread_inst_executed_true'],
#       dtype='object', length=1244)

# %% [markdown]
# ### Section 2: Pre-processing Dataset

# %%
for i in range(100):
    for j in range(10):
        vit_base_data[i][j]=vit_base_data[i][j].drop(['ID'], axis=1)
        if 0 in vit_base_data[i][j].index:
            vit_base_data[i][j] = vit_base_data[i][j].drop(index=0)

for i in range(30):
    for j in range(10):
        vit_base_data_test[i][j]=vit_base_data_test[i][j].drop(['ID'], axis=1)
        if 0 in vit_base_data_test[i][j].index:
            vit_base_data_test[i][j] = vit_base_data_test[i][j].drop(index=0)

# %%
vit_base_data_test[0][0]['Kernel Name'].unique
# Out:
# <bound method Series.unique of 1     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 2     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 3     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 4     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 5     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 6     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 7     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 8     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 9     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 10    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 11    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 12    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# Name: Kernel Name, dtype: object>

# %% [markdown]
# ### Section 3: Metric-based Data filtering and pre-processing

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import random


kernel_name=['fmha_cutlassF_f32_aligned_64x64_rf_sm80(AttentionKernel<bfloat16_t, Sm80, 1, 64, 64, 64, 1, 1>::Params)']
ltx_cols=[col for col in vit_base_data[0][1].columns if 
    col in ['smsp__branch_targets_threads_divergent', 
            'smsp__inst_executed.sum', 
            'smsp__inst_executed_op_branch.avg', 
            'smsp__inst_executed_op_branch.max', 
            'smsp__inst_executed_op_branch.min', 
            'smsp__inst_executed_op_branch.sum', 
            'smsp__inst_executed_op_shared_atom.sum', 
            'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 
            'smsp__sass_branch_targets_threads_divergent.avg', 
            'smsp__sass_branch_targets_threads_divergent.max', 
            'smsp__sass_branch_targets_threads_divergent.min', 
            'smsp__sass_branch_targets_threads_divergent.sum']
]

for col in ltx_cols:
    for i in range(100):
        for j in range(10):
            if vit_base_data[i][j][col].dtype == 'object':  # likely string
                vit_base_data[i][j][col] = pd.to_numeric(vit_base_data[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
            
    for i in range(30):
        for j in range(10):
            if vit_base_data_test[i][j][col].dtype == 'object':  # likely string
                vit_base_data_test[i][j][col] = pd.to_numeric(vit_base_data_test[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
                
# Optional: update the DataFrame back
print(ltx_cols)
# Out:
# /home/t1000/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ['smsp__branch_targets_threads_divergent', 'smsp__inst_executed.sum', 'smsp__inst_executed_op_branch.avg', 'smsp__inst_executed_op_branch.max', 'smsp__inst_executed_op_branch.min', 'smsp__inst_executed_op_branch.sum', 'smsp__inst_executed_op_shared_atom.sum', 'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 'smsp__sass_branch_targets_threads_divergent.avg', 'smsp__sass_branch_targets_threads_divergent.max', 'smsp__sass_branch_targets_threads_divergent.min', 'smsp__sass_branch_targets_threads_divergent.sum']

# %% [markdown]
# print(len(all_class_data))

# %%
vit_base_data_test[0][0]['thread_inst_executed']
# Out:
# 1     11355130624
# 2     11353788544
# 3     11353972224
# 4     11354229888
# 5     11354131712
# 6     11354466688
# 7     11354834816
# 8     11356011520
# 9     11355898112
# 10    11356433664
# 11    11356616320
# 12    11357022976
# Name: thread_inst_executed, dtype: object

# %% [markdown]
# ### Section 4: Generating classifier model's training data and validation data by considering only the filtered Metrics.

# %%
col = [col for col in vit_base_data[0][1].columns if 
    col in ['smsp__branch_targets_threads_divergent', 
            'smsp__inst_executed.sum', 
            'smsp__inst_executed_op_branch.avg', 
            'smsp__inst_executed_op_branch.max', 
            'smsp__inst_executed_op_branch.min', 
            'smsp__inst_executed_op_branch.sum', 
            'smsp__inst_executed_op_shared_atom.sum', 
            'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 
            'smsp__sass_branch_targets_threads_divergent.avg', 
            'smsp__sass_branch_targets_threads_divergent.max', 
            'smsp__sass_branch_targets_threads_divergent.min', 
            'smsp__sass_branch_targets_threads_divergent.sum']]


for i in range(100):
    for j in range(10):
        for c in col:
            vit_base_data[i][j][c]=pd.to_numeric(vit_base_data[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')

for i in range(30):
    for j in range(10):
        for c in col:
            vit_base_data_test[i][j][c]=pd.to_numeric(vit_base_data_test[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')



vit_base_data_df=[[[] for i in range(10)] for j in range(100)]
vit_base_data_test_df=[[[] for i in range(10)] for j in range(30)]

for i in range(len(vit_base_data)):
    for j in range(len(vit_base_data[i])):
        df2 = vit_base_data[i][j]
        # Keep only the columns that exist in the current DataFrame
        selected_cols = [c for c in col if c in df2.columns]
        vit_base_data_df[i][j] = vit_base_data[i][j][selected_cols].copy()

for i in range(len(vit_base_data_test)):
    for j in range(len(vit_base_data_test[i])):
        df2 = vit_base_data_test[i][j]
        # Keep only the columns that exist in the current DataFrame
        selected_cols = [c for c in col if c in df2.columns]
        vit_base_data_test_df[i][j] = vit_base_data_test[i][j][selected_cols].copy()

# %%
print(col)
# Out:
# ['smsp__branch_targets_threads_divergent', 'smsp__inst_executed.sum', 'smsp__inst_executed_op_branch.avg', 'smsp__inst_executed_op_branch.max', 'smsp__inst_executed_op_branch.min', 'smsp__inst_executed_op_branch.sum', 'smsp__inst_executed_op_shared_atom.sum', 'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 'smsp__sass_branch_targets_threads_divergent.avg', 'smsp__sass_branch_targets_threads_divergent.max', 'smsp__sass_branch_targets_threads_divergent.min', 'smsp__sass_branch_targets_threads_divergent.sum']

# %%
vit_base_data_test_df[0][0].shape
# Out:
# (12, 12)

# %% [markdown]
# ### Dataset re-arrangement and providing label for training and test samples for both shadow and target model. Also, selecting appropiate rnage of FMHA kernel instances for achieving maximum attack success rate.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=[]
y_train=[]
X_test=[]
y_test=[]

for i in range(100):
    for j in range(10):
        r = vit_base_data_df[i][j]  # shape: (12, 2)
        j_col = np.full((r.shape[0], 1), j)  # shape: (12, 1)
        r_with_class = np.concatenate([r, j_col], axis=1)  # shape: (12, 3)
        X_train.append(r_with_class)

        if i < 50:
            y_train.append(1)
        else:
            y_train.append(0)

for i in range(30):
    for j in range(10):
        r = vit_base_data_test_df[i][j]  # shape: (12, 2)
        j_col = np.full((r.shape[0], 1), j)
        r_with_class = np.concatenate([r, j_col], axis=1)
        X_test.append(r_with_class)

        if i < 15:
            y_test.append(1)
        else:
            y_test.append(0)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train[:, 0:12, :]
X_test = X_test[:, 0:12, :]
    
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1000, 12, 13) (1000,)
# (300, 12, 13) (300,)

# %%
import numpy as np
print(np.unique(y_train, return_counts=True))
print(np.unique(y_test, return_counts=True))
print(type(X_train[0][0][0]))
# Out:
# (array([0, 1]), array([500, 500]))
# (array([0, 1]), array([150, 150]))
# <class 'numpy.float64'>

# %% [markdown]
# ### Attack Classifier training

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout, BatchNormalization
import numpy as np
from sklearn.model_selection import train_test_split

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  
def reset_random_seeds():
   os.environ['PYTHONHASHSEED']=str(42)
   tf.random.set_seed(42)
   np.random.seed(42)
   random.seed(42)

reset_random_seeds()
import tensorflow as tf

# Your input data shape: (samples, sequence_length, feature_dim)
num_samples = X_train.shape[0]
sequence_length = X_train.shape[1]
feature_dim = X_train.shape[2]

# Define the model/
# Stacked BiLSTM Layers
model = Sequential()
model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=(sequence_length, feature_dim)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(32, return_sequences=False)))
model.add(Dropout(0.2))

# Fully connected hidden layer
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='sigmoid'))


# Compile
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

features_train = X_train[:, :, :-1]  
class_train = X_train[:, :, -1:]  
mean = features_train.mean(axis=(0, 1), keepdims=True)
std = features_train.std(axis=(0, 1), keepdims=True)
features_train = (features_train - mean) / (std + 1e-8)
X_train = np.concatenate([features_train, class_train], axis=-1)

# Summary
model.summary()
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)
# Train
history = model.fit(
    X_train_split, y_train_split,
    epochs=90,
    batch_size=45,
    validation_data=(X_val_split, y_val_split)
)
# Out:
# 2026-08-21 10:28:21.791396: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-21 10:28:21.818680: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-21 10:28:22.637249: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-21 10:28:22.741095: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-08-21 10:28:22.741113: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# 2026-08-21 10:28:22.741116: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# 2026-08-21 10:28:22.741118: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2026-08-21 10:28:22.741121: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: vhj4ybwysf5e7ppbc5tbh6f2ez
# 2026-08-21 10:28:22.741123: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] hostname: vhj4ybwysf5e7ppbc5tbh6f2ez
# 2026-08-21 10:28:22.741187: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] libcuda reported version is: 580.95.5
# 2026-08-21 10:28:22.741197: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:194] kernel reported version is: 580.95.5
# 2026-08-21 10:28:22.741198: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:284] kernel version seems to match DSO: 580.95.5
# /home/t1000/.local/lib/python3.10/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 12, 128)        │        39,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 64)             │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 85,377 (333.50 KB)
#  Trainable params: 85,377 (333.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.5000 - loss: 0.6973 - val_accuracy: 0.4650 - val_loss: 0.6956
# Epoch 2/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5038 - loss: 0.6931 - val_accuracy: 0.5500 - val_loss: 0.6874
# Epoch 3/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5462 - loss: 0.6826 - val_accuracy: 0.5050 - val_loss: 0.6853
# Epoch 4/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5375 - loss: 0.6844 - val_accuracy: 0.5000 - val_loss: 0.6815
# Epoch 5/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5850 - loss: 0.6723 - val_accuracy: 0.5300 - val_loss: 0.6748
# Epoch 6/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5713 - loss: 0.6645 - val_accuracy: 0.5500 - val_loss: 0.6561
# Epoch 7/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6012 - loss: 0.6459 - val_accuracy: 0.6300 - val_loss: 0.6130
# Epoch 8/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6125 - loss: 0.6115 - val_accuracy: 0.6300 - val_loss: 0.5803
# Epoch 9/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6400 - loss: 0.5834 - val_accuracy: 0.6800 - val_loss: 0.5674
# Epoch 10/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6725 - loss: 0.5747 - val_accuracy: 0.6800 - val_loss: 0.5340
# Epoch 11/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6988 - loss: 0.5483 - val_accuracy: 0.7100 - val_loss: 0.5239
# Epoch 12/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6950 - loss: 0.5383 - val_accuracy: 0.7300 - val_loss: 0.5195
# Epoch 13/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6862 - loss: 0.5494 - val_accuracy: 0.6500 - val_loss: 0.5645
# Epoch 14/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6737 - loss: 0.5597 - val_accuracy: 0.6750 - val_loss: 0.5437
# Epoch 15/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7200 - loss: 0.5188 - val_accuracy: 0.7250 - val_loss: 0.4874
# Epoch 16/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7113 - loss: 0.4948 - val_accuracy: 0.7500 - val_loss: 0.4652
# Epoch 17/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7287 - loss: 0.4830 - val_accuracy: 0.7850 - val_loss: 0.4411
# Epoch 18/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7287 - loss: 0.4979 - val_accuracy: 0.8150 - val_loss: 0.4587
# Epoch 19/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7275 - loss: 0.4871 - val_accuracy: 0.7950 - val_loss: 0.4677
# Epoch 20/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7688 - loss: 0.4515 - val_accuracy: 0.8300 - val_loss: 0.4256
# Epoch 21/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7788 - loss: 0.4438 - val_accuracy: 0.8300 - val_loss: 0.4209
# Epoch 22/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7850 - loss: 0.3867 - val_accuracy: 0.8400 - val_loss: 0.3755
# Epoch 23/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8313 - loss: 0.3827 - val_accuracy: 0.8400 - val_loss: 0.4059
# Epoch 24/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8100 - loss: 0.4008 - val_accuracy: 0.8800 - val_loss: 0.3411
# Epoch 25/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8438 - loss: 0.3499 - val_accuracy: 0.8900 - val_loss: 0.3064
# Epoch 26/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8350 - loss: 0.3798 - val_accuracy: 0.8250 - val_loss: 0.3602
# Epoch 27/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8087 - loss: 0.3932 - val_accuracy: 0.9050 - val_loss: 0.2949
# Epoch 28/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8438 - loss: 0.3271 - val_accuracy: 0.9100 - val_loss: 0.2371
# Epoch 29/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8575 - loss: 0.2841 - val_accuracy: 0.9150 - val_loss: 0.2184
# Epoch 30/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8675 - loss: 0.2627 - val_accuracy: 0.9200 - val_loss: 0.2077
# Epoch 31/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8975 - loss: 0.2214 - val_accuracy: 0.9150 - val_loss: 0.2010
# Epoch 32/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9000 - loss: 0.2051 - val_accuracy: 0.9200 - val_loss: 0.2254
# Epoch 33/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9025 - loss: 0.2025 - val_accuracy: 0.9550 - val_loss: 0.1543
# Epoch 34/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8925 - loss: 0.2450 - val_accuracy: 0.9300 - val_loss: 0.1875
# Epoch 35/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8737 - loss: 0.2577 - val_accuracy: 0.9100 - val_loss: 0.2471
# Epoch 36/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8950 - loss: 0.2258 - val_accuracy: 0.9200 - val_loss: 0.1724
# Epoch 37/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9250 - loss: 0.1845 - val_accuracy: 0.9350 - val_loss: 0.1677
# Epoch 38/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9225 - loss: 0.1648 - val_accuracy: 0.9550 - val_loss: 0.1248
# Epoch 39/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9275 - loss: 0.1550 - val_accuracy: 0.9400 - val_loss: 0.1527
# Epoch 40/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9337 - loss: 0.1546 - val_accuracy: 0.9550 - val_loss: 0.1158
# Epoch 41/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9312 - loss: 0.1366 - val_accuracy: 0.9550 - val_loss: 0.1198
# Epoch 42/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9325 - loss: 0.1599 - val_accuracy: 0.9400 - val_loss: 0.1670
# Epoch 43/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9362 - loss: 0.1396 - val_accuracy: 0.9600 - val_loss: 0.1045
# Epoch 44/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9463 - loss: 0.1122 - val_accuracy: 0.9550 - val_loss: 0.1226
# Epoch 45/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9488 - loss: 0.1093 - val_accuracy: 0.9650 - val_loss: 0.1093
# Epoch 46/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9388 - loss: 0.1256 - val_accuracy: 0.9500 - val_loss: 0.0962
# Epoch 47/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9488 - loss: 0.1096 - val_accuracy: 0.9700 - val_loss: 0.0945
# Epoch 48/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9513 - loss: 0.1018 - val_accuracy: 0.9700 - val_loss: 0.0933
# Epoch 49/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9425 - loss: 0.1370 - val_accuracy: 0.9050 - val_loss: 0.1742
# Epoch 50/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9287 - loss: 0.1465 - val_accuracy: 0.9400 - val_loss: 0.1158
# Epoch 51/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9375 - loss: 0.1455 - val_accuracy: 0.9300 - val_loss: 0.1392
# Epoch 52/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9350 - loss: 0.1548 - val_accuracy: 0.9200 - val_loss: 0.3288
# Epoch 53/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9563 - loss: 0.1193 - val_accuracy: 0.9550 - val_loss: 0.0990
# Epoch 54/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9575 - loss: 0.0886 - val_accuracy: 0.9400 - val_loss: 0.0959
# Epoch 55/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9650 - loss: 0.0840 - val_accuracy: 0.9250 - val_loss: 0.1018
# Epoch 56/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9638 - loss: 0.0784 - val_accuracy: 0.9750 - val_loss: 0.0525
# Epoch 57/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9688 - loss: 0.0702 - val_accuracy: 0.9700 - val_loss: 0.0582
# Epoch 58/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9550 - loss: 0.0822 - val_accuracy: 0.9250 - val_loss: 0.0989
# Epoch 59/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9663 - loss: 0.0653 - val_accuracy: 0.9750 - val_loss: 0.0436
# Epoch 60/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9613 - loss: 0.0907 - val_accuracy: 0.9600 - val_loss: 0.0794
# Epoch 61/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9463 - loss: 0.1217 - val_accuracy: 0.9500 - val_loss: 0.1112
# Epoch 62/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9588 - loss: 0.0963 - val_accuracy: 0.9650 - val_loss: 0.0912
# Epoch 63/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9663 - loss: 0.0965 - val_accuracy: 0.9300 - val_loss: 0.1067
# Epoch 64/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9550 - loss: 0.1024 - val_accuracy: 0.9200 - val_loss: 0.1148
# Epoch 65/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9638 - loss: 0.0932 - val_accuracy: 0.9750 - val_loss: 0.0806
# Epoch 66/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9638 - loss: 0.0794 - val_accuracy: 0.9800 - val_loss: 0.0525
# Epoch 67/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9775 - loss: 0.0636 - val_accuracy: 0.9750 - val_loss: 0.0672
# Epoch 68/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9663 - loss: 0.0715 - val_accuracy: 0.9550 - val_loss: 0.0814
# Epoch 69/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9787 - loss: 0.0576 - val_accuracy: 0.9800 - val_loss: 0.0535
# Epoch 70/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9688 - loss: 0.0678 - val_accuracy: 0.9650 - val_loss: 0.1074
# Epoch 71/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9663 - loss: 0.0867 - val_accuracy: 0.9800 - val_loss: 0.0487
# Epoch 72/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9712 - loss: 0.0649 - val_accuracy: 0.9850 - val_loss: 0.0596
# Epoch 73/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9725 - loss: 0.0624 - val_accuracy: 0.9700 - val_loss: 0.0848
# Epoch 74/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9638 - loss: 0.0891 - val_accuracy: 0.9800 - val_loss: 0.0669
# Epoch 75/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9800 - loss: 0.0513 - val_accuracy: 0.9750 - val_loss: 0.0825
# Epoch 76/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9800 - loss: 0.0588 - val_accuracy: 0.9850 - val_loss: 0.0277
# Epoch 77/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9775 - loss: 0.0561 - val_accuracy: 0.9950 - val_loss: 0.0239
# Epoch 78/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9837 - loss: 0.0501 - val_accuracy: 0.9900 - val_loss: 0.0372
# Epoch 79/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9825 - loss: 0.0716 - val_accuracy: 0.9850 - val_loss: 0.0644
# Epoch 80/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9712 - loss: 0.0637 - val_accuracy: 0.9800 - val_loss: 0.0677
# Epoch 81/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9625 - loss: 0.1277 - val_accuracy: 0.9300 - val_loss: 0.1397
# Epoch 82/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9563 - loss: 0.1112 - val_accuracy: 0.9700 - val_loss: 0.0693
# Epoch 83/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9650 - loss: 0.0955 - val_accuracy: 0.9800 - val_loss: 0.0494
# Epoch 84/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9712 - loss: 0.0656 - val_accuracy: 0.9850 - val_loss: 0.0376
# Epoch 85/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9775 - loss: 0.0592 - val_accuracy: 0.9900 - val_loss: 0.0412
# Epoch 86/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9837 - loss: 0.0404 - val_accuracy: 0.9900 - val_loss: 0.0279
# Epoch 87/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9875 - loss: 0.0335 - val_accuracy: 0.9950 - val_loss: 0.0407
# Epoch 88/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9875 - loss: 0.0332 - val_accuracy: 0.9850 - val_loss: 0.0385
# Epoch 89/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9825 - loss: 0.0444 - val_accuracy: 0.9950 - val_loss: 0.0345
# Epoch 90/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9862 - loss: 0.0384 - val_accuracy: 0.9800 - val_loss: 0.0470

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Membership Inference Attack on Target Model Data

# %%
# Predict
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

features_train = X_test[:, :, :-1]  
class_train = X_test[:, :, -1:]   
mean = features_train.mean(axis=(0, 1), keepdims=True)
std = features_train.std(axis=(0, 1), keepdims=True)
features_train = (features_train - mean) / (std + 1e-8)
X_test = np.concatenate([features_train, class_train], axis=-1)

# Predict probabilities
predictions = model.predict(X_test)

# # Convert probabilities to binary labels
predicted_labels = (predictions > 0.5).astype(int)

# Accuracy
acc = accuracy_score(y_test, predicted_labels)
print(f"Test Accuracy: {acc:.4f}")

# Confusion matrix
cm = confusion_matrix(y_test, predicted_labels)
print("Confusion Matrix:\n", cm)

# Plot
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Test Set","Training Set"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Test Accuracy: 0.9300
# Confusion Matrix:
#  [[141   9]
#  [ 12 138]]

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_auc_score,
    roc_curve,
    f1_score
)
import matplotlib.pyplot as plt
import numpy as np

# Binary predictions using threshold 0.5
predicted_labels = (predictions >= 0.5).astype(int)

# F1 Score
f1 = f1_score(y_test, predicted_labels)
print(f"F1 Score: {f1:.4f}")

# AUC Score
auc_score = roc_auc_score(y_test, predictions)
print(f"AUC Score: {auc_score:.4f}")

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, predictions)

# Plot ROC Curve
plt.figure()
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.4f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # Random chance line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# F1 Score: 0.9293
# AUC Score: 0.9781
