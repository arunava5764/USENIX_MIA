# %% [markdown]
# ## Table 8: DeiT-Base model's results on CIFAR-10 dataset trained using FL (NIID) on RTX 4500 Ada GPU

# %% [markdown]
# ### Section 1: Loading Dataset

# %%
import numpy as np
import pandas as pd

# %%
deit_base_data=[]
deit_base_data_test=[]


for i in range(1,101):
    temp1=[]
    for j in range(10):
        path='./mem_csv_deit_base_cifar10_federated_NIID/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    deit_base_data.append(temp1)

for i in range(1,31):
    temp1=[]
    for j in range(10):
        path='./mem_csv_deit_base_cifar10_federated_NIID_test/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    deit_base_data_test.append(temp1)

print(deit_base_data[0][1].columns)
print(deit_base_data_test[0][1].columns)
# Out:
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'smsp__warps_active.min.peak_sustained',
#        'smsp__warps_active.min.per_cycle_active',
#        'smsp__warps_active.sum.peak_sustained',
#        'smsp__warps_active.sum.per_cycle_active',
#        'smsp__warps_eligible.avg.per_cycle_active',
#        'smsp__warps_eligible.max.per_cycle_active',
#        'smsp__warps_eligible.min.per_cycle_active',
#        'smsp__warps_eligible.sum.per_cycle_active', 'thread_inst_executed',
#        'thread_inst_executed_true'],
#       dtype='object', length=1220)
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'smsp__warps_active.min.peak_sustained',
#        'smsp__warps_active.min.per_cycle_active',
#        'smsp__warps_active.sum.peak_sustained',
#        'smsp__warps_active.sum.per_cycle_active',
#        'smsp__warps_eligible.avg.per_cycle_active',
#        'smsp__warps_eligible.max.per_cycle_active',
#        'smsp__warps_eligible.min.per_cycle_active',
#        'smsp__warps_eligible.sum.per_cycle_active', 'thread_inst_executed',
#        'thread_inst_executed_true'],
#       dtype='object', length=1220)

# %% [markdown]
# ### Section 2: Pre-processing Dataset

# %%
for i in range(100):
    for j in range(10):
        deit_base_data[i][j]=deit_base_data[i][j].drop(['ID'], axis=1)
        if 0 in deit_base_data[i][j].index:
            deit_base_data[i][j] = deit_base_data[i][j].drop(index=0)

for i in range(30):
    for j in range(10):
        deit_base_data_test[i][j]=deit_base_data_test[i][j].drop(['ID'], axis=1)
        if 0 in deit_base_data_test[i][j].index:
            deit_base_data_test[i][j] = deit_base_data_test[i][j].drop(index=0)

# %%
deit_base_data_test[0][0]['Kernel Name'].unique
# Out:
# <bound method Series.unique of 1     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 2     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 3     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 4     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 5     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 6     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 7     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 8     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 9     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 10    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 11    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 12    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# Name: Kernel Name, dtype: object>

# %% [markdown]
# ### Section 3: Metric-based Data filtering and pre-processing

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import random

kernel_name=['fmha_cutlassF_f32_aligned_64x64_rf_sm80(AttentionKernel<bfloat16_t, Sm80, 1, 64, 64, 64, 1, 1>::Params)']
ltx_cols=[col for col in deit_base_data[0][1].columns if 
        col in ['sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_of_peak_sustained_elapsed',
                 'sm__inst_executed_pipe_cbu_pred_on_any.max.pct_of_peak_sustained_elapsed', 
                 'sm__inst_executed_pipe_cbu_pred_on_any.min.pct_of_peak_sustained_elapsed', 
                 'sm__inst_executed_pipe_cbu_pred_on_any.sum.pct_of_peak_sustained_elapsed', 
                 'smsp__inst_executed.sum', 'smsp__inst_executed_op_branch.avg', 
                 'smsp__inst_executed_op_branch.max', 'smsp__inst_executed_op_branch.min', 
                'smsp__inst_executed_op_branch.sum', 'smsp__inst_issued.avg']
                ]

for col in ltx_cols:
    for i in range(100):
        for j in range(10):
            if deit_base_data[i][j][col].dtype == 'object':  # likely string
                deit_base_data[i][j][col] = pd.to_numeric(deit_base_data[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
    for i in range(30):
        for j in range(10):
           if deit_base_data_test[i][j][col].dtype == 'object':  # likely string
                deit_base_data_test[i][j][col] = pd.to_numeric(deit_base_data_test[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
                
# Optional: update the DataFrame back
print(ltx_cols)
# Out:
# /home/t1000/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ['sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.max.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.min.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.sum.pct_of_peak_sustained_elapsed', 'smsp__inst_executed.sum', 'smsp__inst_executed_op_branch.avg', 'smsp__inst_executed_op_branch.max', 'smsp__inst_executed_op_branch.min', 'smsp__inst_executed_op_branch.sum', 'smsp__inst_issued.avg']

# %% [markdown]
# print(len(all_class_data))

# %% [markdown]
# ### Section 4: Generating classifier model's training data and validation data by considering only the filtered Metrics.

# %%
col = [col for col in deit_base_data[0][1].columns if 
        col in ['sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_of_peak_sustained_elapsed',
                 'sm__inst_executed_pipe_cbu_pred_on_any.max.pct_of_peak_sustained_elapsed', 
                 'sm__inst_executed_pipe_cbu_pred_on_any.min.pct_of_peak_sustained_elapsed', 
                 'sm__inst_executed_pipe_cbu_pred_on_any.sum.pct_of_peak_sustained_elapsed', 
                 'smsp__inst_executed.sum', 'smsp__inst_executed_op_branch.avg', 
                 'smsp__inst_executed_op_branch.max', 'smsp__inst_executed_op_branch.min', 
                'smsp__inst_executed_op_branch.sum', 'smsp__inst_issued.avg']
                ]

for i in range(100):
    for j in range(10):
        for c in col:
            deit_base_data[i][j][c]=pd.to_numeric(deit_base_data[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')
           
for i in range(30):
    for j in range(10):
        for c in col:
            deit_base_data_test[i][j][c]=pd.to_numeric(deit_base_data_test[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')




deit_base_data_df=[[[] for i in range(10)] for j in range(100)]
deit_base_data_test_df=[[[] for i in range(10)] for j in range(30)]

for i in range(len(deit_base_data)):
    for j in range(len(deit_base_data[i])):
        df2 = deit_base_data[i][j]
        # Keep only the columns that exist in the current DataFrame
        selected_cols = [c for c in col if c in df2.columns]
        deit_base_data_df[i][j] = deit_base_data[i][j][selected_cols].copy()

for i in range(len(deit_base_data_test)):
    for j in range(len(deit_base_data_test[i])):
        df2 = deit_base_data_test[i][j]
        # Keep only the columns that exist in the current DataFrame
        selected_cols = [c for c in col if c in df2.columns]
        deit_base_data_test_df[i][j] = deit_base_data_test[i][j][selected_cols].copy()

# %%
print(col)
# Out:
# ['sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.max.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.min.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.sum.pct_of_peak_sustained_elapsed', 'smsp__inst_executed.sum', 'smsp__inst_executed_op_branch.avg', 'smsp__inst_executed_op_branch.max', 'smsp__inst_executed_op_branch.min', 'smsp__inst_executed_op_branch.sum', 'smsp__inst_issued.avg']

# %% [markdown]
# ### Dataset re-arrangement and providing label for training and test samples for both shadow and target model. Also, selecting appropiate range of FMHA kernel instances for achieving maximum attack success rate.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=[]
y_train=[]
X_test=[]
y_test=[]

for i in range(100):
    for j in range(10):
        r = deit_base_data_df[i][j]  # shape: (12, 2)
        X_train.append(r)

        if i < 50:
            y_train.append(1)
        else:
            y_train.append(0)


for i in range(30):
    for j in range(10):
        r = deit_base_data_test_df[i][j]  # shape: (12, 2)
        X_test.append(r)

        if i < 15:
            y_test.append(1)
        else:
            y_test.append(0)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train[:, 0:5, :]
X_test = X_test[:, 0:5, :]
    
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1000, 5, 10) (1000,)
# (300, 5, 10) (300,)

# %%
import numpy as np
print(np.unique(y_train, return_counts=True))
print(np.unique(y_test, return_counts=True))
print(type(X_train[0][0][0]))
# Out:
# (array([0, 1]), array([500, 500]))
# (array([0, 1]), array([150, 150]))
# <class 'numpy.float32'>

# %% [markdown]
# ### Attack Classifier training

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout, BatchNormalization
import numpy as np
from sklearn.model_selection import train_test_split

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  
def reset_random_seeds():
   os.environ['PYTHONHASHSEED']=str(42)
   tf.random.set_seed(42)
   np.random.seed(42)
   random.seed(42)


reset_random_seeds()
import tensorflow as tf

# Your input data shape: (samples, sequence_length, feature_dim)
num_samples = X_train.shape[0]
sequence_length = X_train.shape[1]
feature_dim = X_train.shape[2]

# Define the model
# Stacked BiLSTM Layers
model = Sequential()
model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=(sequence_length, feature_dim)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(32, return_sequences=False)))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))


# Compile
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

mean = X_train.mean(axis=(0, 1), keepdims=True)
std = X_train.std(axis=(0, 1), keepdims=True)
X_train = (X_train - mean) / (std + 1e-8)

# Summary
model.summary()
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)
# Train
history = model.fit(
    X_train_split, y_train_split,
    epochs=90,
    batch_size=45,
    validation_data=(X_val_split, y_val_split)
)
# Out:
# 2026-08-24 10:18:44.981381: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-24 10:18:45.012047: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-24 10:18:45.968841: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-24 10:18:46.107689: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-08-24 10:18:46.107709: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# 2026-08-24 10:18:46.107712: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# 2026-08-24 10:18:46.107715: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2026-08-24 10:18:46.107717: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: vhj4ybwysf5e7ppbc5tbh6f2ez
# 2026-08-24 10:18:46.107719: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] hostname: vhj4ybwysf5e7ppbc5tbh6f2ez
# 2026-08-24 10:18:46.107817: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] libcuda reported version is: 580.95.5
# 2026-08-24 10:18:46.107831: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:194] kernel reported version is: 580.95.5
# 2026-08-24 10:18:46.107832: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:284] kernel version seems to match DSO: 580.95.5
# /home/t1000/.local/lib/python3.10/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 5, 128)         │        38,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 64)             │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 83,841 (327.50 KB)
#  Trainable params: 83,841 (327.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5113 - loss: 0.6929 - val_accuracy: 0.5750 - val_loss: 0.6866
# Epoch 2/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5612 - loss: 0.6886 - val_accuracy: 0.6050 - val_loss: 0.6811
# Epoch 3/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5562 - loss: 0.6844 - val_accuracy: 0.6050 - val_loss: 0.6748
# Epoch 4/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5688 - loss: 0.6838 - val_accuracy: 0.6200 - val_loss: 0.6723
# Epoch 5/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5638 - loss: 0.6804 - val_accuracy: 0.6150 - val_loss: 0.6727
# Epoch 6/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5638 - loss: 0.6809 - val_accuracy: 0.5850 - val_loss: 0.6719
# Epoch 7/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5950 - loss: 0.6757 - val_accuracy: 0.6100 - val_loss: 0.6717
# Epoch 8/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5725 - loss: 0.6752 - val_accuracy: 0.6050 - val_loss: 0.6712
# Epoch 9/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5738 - loss: 0.6718 - val_accuracy: 0.6000 - val_loss: 0.6719
# Epoch 10/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5850 - loss: 0.6692 - val_accuracy: 0.6000 - val_loss: 0.6704
# Epoch 11/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5675 - loss: 0.6714 - val_accuracy: 0.5900 - val_loss: 0.6717
# Epoch 12/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5850 - loss: 0.6676 - val_accuracy: 0.5950 - val_loss: 0.6693
# Epoch 13/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5713 - loss: 0.6673 - val_accuracy: 0.5600 - val_loss: 0.6699
# Epoch 14/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5800 - loss: 0.6667 - val_accuracy: 0.5550 - val_loss: 0.6741
# Epoch 15/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5638 - loss: 0.6709 - val_accuracy: 0.5500 - val_loss: 0.6698
# Epoch 16/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5675 - loss: 0.6614 - val_accuracy: 0.5250 - val_loss: 0.6687
# Epoch 17/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5800 - loss: 0.6570 - val_accuracy: 0.5550 - val_loss: 0.6714
# Epoch 18/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5913 - loss: 0.6571 - val_accuracy: 0.5550 - val_loss: 0.6720
# Epoch 19/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5875 - loss: 0.6549 - val_accuracy: 0.5500 - val_loss: 0.6668
# Epoch 20/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5987 - loss: 0.6572 - val_accuracy: 0.5300 - val_loss: 0.6697
# Epoch 21/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5788 - loss: 0.6497 - val_accuracy: 0.5650 - val_loss: 0.6696
# Epoch 22/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5788 - loss: 0.6504 - val_accuracy: 0.5350 - val_loss: 0.6681
# Epoch 23/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5962 - loss: 0.6420 - val_accuracy: 0.5500 - val_loss: 0.6665
# Epoch 24/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6050 - loss: 0.6383 - val_accuracy: 0.5350 - val_loss: 0.6674
# Epoch 25/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5950 - loss: 0.6365 - val_accuracy: 0.5200 - val_loss: 0.6675
# Epoch 26/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6125 - loss: 0.6245 - val_accuracy: 0.5400 - val_loss: 0.6656
# Epoch 27/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5788 - loss: 0.6401 - val_accuracy: 0.5000 - val_loss: 0.6762
# Epoch 28/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6050 - loss: 0.6326 - val_accuracy: 0.5150 - val_loss: 0.6617
# Epoch 29/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6012 - loss: 0.6167 - val_accuracy: 0.5600 - val_loss: 0.6510
# Epoch 30/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6225 - loss: 0.6097 - val_accuracy: 0.5100 - val_loss: 0.6557
# Epoch 31/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6200 - loss: 0.6102 - val_accuracy: 0.4900 - val_loss: 0.6493
# Epoch 32/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6313 - loss: 0.6024 - val_accuracy: 0.5050 - val_loss: 0.6451
# Epoch 33/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6237 - loss: 0.5950 - val_accuracy: 0.5150 - val_loss: 0.6400
# Epoch 34/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6413 - loss: 0.5888 - val_accuracy: 0.5050 - val_loss: 0.6364
# Epoch 35/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6112 - loss: 0.5944 - val_accuracy: 0.5650 - val_loss: 0.6301
# Epoch 36/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6625 - loss: 0.5783 - val_accuracy: 0.5550 - val_loss: 0.6397
# Epoch 37/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6500 - loss: 0.5780 - val_accuracy: 0.5700 - val_loss: 0.6335
# Epoch 38/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6637 - loss: 0.5636 - val_accuracy: 0.6400 - val_loss: 0.5898
# Epoch 39/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6875 - loss: 0.5422 - val_accuracy: 0.6150 - val_loss: 0.5921
# Epoch 40/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6750 - loss: 0.5489 - val_accuracy: 0.5800 - val_loss: 0.5977
# Epoch 41/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6888 - loss: 0.5427 - val_accuracy: 0.6200 - val_loss: 0.5711
# Epoch 42/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7013 - loss: 0.5305 - val_accuracy: 0.6300 - val_loss: 0.5656
# Epoch 43/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7225 - loss: 0.5184 - val_accuracy: 0.6800 - val_loss: 0.5424
# Epoch 44/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7100 - loss: 0.5123 - val_accuracy: 0.6750 - val_loss: 0.5427
# Epoch 45/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7337 - loss: 0.5037 - val_accuracy: 0.7150 - val_loss: 0.5102
# Epoch 46/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7500 - loss: 0.4959 - val_accuracy: 0.7150 - val_loss: 0.5139
# Epoch 47/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7450 - loss: 0.4733 - val_accuracy: 0.7650 - val_loss: 0.4787
# Epoch 48/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7862 - loss: 0.4444 - val_accuracy: 0.7600 - val_loss: 0.4861
# Epoch 49/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7875 - loss: 0.4541 - val_accuracy: 0.7400 - val_loss: 0.4730
# Epoch 50/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7750 - loss: 0.4619 - val_accuracy: 0.7350 - val_loss: 0.4701
# Epoch 51/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7912 - loss: 0.4299 - val_accuracy: 0.7050 - val_loss: 0.4913
# Epoch 52/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7987 - loss: 0.4432 - val_accuracy: 0.7450 - val_loss: 0.4936
# Epoch 53/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7912 - loss: 0.4340 - val_accuracy: 0.7600 - val_loss: 0.4767
# Epoch 54/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8150 - loss: 0.4098 - val_accuracy: 0.7550 - val_loss: 0.4631
# Epoch 55/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8100 - loss: 0.4150 - val_accuracy: 0.7550 - val_loss: 0.4467
# Epoch 56/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8025 - loss: 0.4078 - val_accuracy: 0.7350 - val_loss: 0.4929
# Epoch 57/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8075 - loss: 0.3938 - val_accuracy: 0.7900 - val_loss: 0.4165
# Epoch 58/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8238 - loss: 0.3872 - val_accuracy: 0.7300 - val_loss: 0.4568
# Epoch 59/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8250 - loss: 0.3783 - val_accuracy: 0.7700 - val_loss: 0.4536
# Epoch 60/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8250 - loss: 0.3526 - val_accuracy: 0.7750 - val_loss: 0.3876
# Epoch 61/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8388 - loss: 0.3479 - val_accuracy: 0.8100 - val_loss: 0.3817
# Epoch 62/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8575 - loss: 0.3268 - val_accuracy: 0.8450 - val_loss: 0.3324
# Epoch 63/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8500 - loss: 0.3184 - val_accuracy: 0.8050 - val_loss: 0.3698
# Epoch 64/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8487 - loss: 0.3343 - val_accuracy: 0.8350 - val_loss: 0.3281
# Epoch 65/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8325 - loss: 0.3394 - val_accuracy: 0.8000 - val_loss: 0.3860
# Epoch 66/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8637 - loss: 0.3027 - val_accuracy: 0.8250 - val_loss: 0.3655
# Epoch 67/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8525 - loss: 0.3100 - val_accuracy: 0.8550 - val_loss: 0.2861
# Epoch 68/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8450 - loss: 0.3352 - val_accuracy: 0.8250 - val_loss: 0.3730
# Epoch 69/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8662 - loss: 0.2737 - val_accuracy: 0.8750 - val_loss: 0.2774
# Epoch 70/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8813 - loss: 0.2848 - val_accuracy: 0.8050 - val_loss: 0.3826
# Epoch 71/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8700 - loss: 0.2902 - val_accuracy: 0.8200 - val_loss: 0.3480
# Epoch 72/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8562 - loss: 0.2948 - val_accuracy: 0.8750 - val_loss: 0.2676
# Epoch 73/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8875 - loss: 0.2682 - val_accuracy: 0.8450 - val_loss: 0.3301
# Epoch 74/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8662 - loss: 0.2675 - val_accuracy: 0.9000 - val_loss: 0.2415
# Epoch 75/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8775 - loss: 0.2795 - val_accuracy: 0.8650 - val_loss: 0.3055
# Epoch 76/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9000 - loss: 0.2300 - val_accuracy: 0.8700 - val_loss: 0.2306
# Epoch 77/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8913 - loss: 0.2362 - val_accuracy: 0.9100 - val_loss: 0.2247
# Epoch 78/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9125 - loss: 0.2216 - val_accuracy: 0.8850 - val_loss: 0.2411
# Epoch 79/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9062 - loss: 0.2405 - val_accuracy: 0.9300 - val_loss: 0.2039
# Epoch 80/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9162 - loss: 0.2013 - val_accuracy: 0.9000 - val_loss: 0.2185
# Epoch 81/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9200 - loss: 0.2084 - val_accuracy: 0.8450 - val_loss: 0.3480
# Epoch 82/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8913 - loss: 0.2363 - val_accuracy: 0.9100 - val_loss: 0.1912
# Epoch 83/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8925 - loss: 0.2406 - val_accuracy: 0.8250 - val_loss: 0.3557
# Epoch 84/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9025 - loss: 0.2390 - val_accuracy: 0.9300 - val_loss: 0.1809
# Epoch 85/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9125 - loss: 0.2045 - val_accuracy: 0.9150 - val_loss: 0.2088
# Epoch 86/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9212 - loss: 0.1850 - val_accuracy: 0.9000 - val_loss: 0.2152
# Epoch 87/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9212 - loss: 0.2025 - val_accuracy: 0.8900 - val_loss: 0.2744
# Epoch 88/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9137 - loss: 0.1852 - val_accuracy: 0.9150 - val_loss: 0.2110
# Epoch 89/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9125 - loss: 0.1791 - val_accuracy: 0.9450 - val_loss: 0.1507
# Epoch 90/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9212 - loss: 0.1613 - val_accuracy: 0.8800 - val_loss: 0.2314

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Membership Inference Attack on Target Model Data

# %%
# Predict
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

mean = X_test.mean(axis=(0, 1), keepdims=True)
std = X_test.std(axis=(0, 1), keepdims=True)
X_test = (X_test - mean) / (std + 1e-8)

# Predict probabilities
predictions = model.predict(X_test)

# # Convert probabilities to binary labels
predicted_labels = (predictions > 0.5).astype(int)

# Accuracy
acc = accuracy_score(y_test, predicted_labels)
print(f"Test Accuracy: {acc:.4f}")

# Confusion matrix
cm = confusion_matrix(y_test, predicted_labels)
print("Confusion Matrix:\n", cm)

# Plot
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Test Set","Training Set"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Test Accuracy: 0.9300
# Confusion Matrix:
#  [[136  14]
#  [  7 143]]

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_auc_score,
    roc_curve,
    f1_score
)
import matplotlib.pyplot as plt
import numpy as np

# Binary predictions using threshold 0.5
predicted_labels = (predictions >= 0.5).astype(int)

# F1 Score
f1 = f1_score(y_test, predicted_labels)
print(f"F1 Score: {f1:.4f}")

# AUC Score
auc_score = roc_auc_score(y_test, predictions)
print(f"AUC Score: {auc_score:.4f}")

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, predictions)

# Plot ROC Curve
plt.figure()
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.4f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # Random chance line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# F1 Score: 0.9316
# AUC Score: 0.9845
