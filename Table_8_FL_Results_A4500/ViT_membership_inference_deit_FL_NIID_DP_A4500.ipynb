# %% [markdown]
# ## Table 8: DeiT-Base model's results on CIFAR-10 dataset trained using FL (NIID) and DP RTX A4500 GPU

# %% [markdown]
# ### Section 1: Loading Dataset

# %%
import numpy as np
import pandas as pd

# %%
deit_base_data=[]
deit_base_data_test=[]


for i in range(1,101):
    temp1=[]
    for j in range(10):
        path='mem_csv_deit_base_cifar10_federated_dp_NIID/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    deit_base_data.append(temp1)

for i in range(1,31):
    temp1=[]
    for j in range(10):
        path='/home/t1000/Desktop/GPU_Traces/mem_csv_deit_base_cifar10_federated_dp_NIID_test/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    deit_base_data_test.append(temp1)

print(deit_base_data[0][1].columns)
print(deit_base_data_test[0][1].columns)
# Out:
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'smsp__warps_active.min.peak_sustained',
#        'smsp__warps_active.min.per_cycle_active',
#        'smsp__warps_active.sum.peak_sustained',
#        'smsp__warps_active.sum.per_cycle_active',
#        'smsp__warps_eligible.avg.per_cycle_active',
#        'smsp__warps_eligible.max.per_cycle_active',
#        'smsp__warps_eligible.min.per_cycle_active',
#        'smsp__warps_eligible.sum.per_cycle_active', 'thread_inst_executed',
#        'thread_inst_executed_true'],
#       dtype='object', length=1220)
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'smsp__warps_active.min.peak_sustained',
#        'smsp__warps_active.min.per_cycle_active',
#        'smsp__warps_active.sum.peak_sustained',
#        'smsp__warps_active.sum.per_cycle_active',
#        'smsp__warps_eligible.avg.per_cycle_active',
#        'smsp__warps_eligible.max.per_cycle_active',
#        'smsp__warps_eligible.min.per_cycle_active',
#        'smsp__warps_eligible.sum.per_cycle_active', 'thread_inst_executed',
#        'thread_inst_executed_true'],
#       dtype='object', length=1220)

# %% [markdown]
# ### Section 2: Pre-processing Dataset

# %%
for i in range(100):
    for j in range(10):
        deit_base_data[i][j]=deit_base_data[i][j].drop(['ID'], axis=1)
        if 0 in deit_base_data[i][j].index:
            deit_base_data[i][j] = deit_base_data[i][j].drop(index=0)

for i in range(30):
    for j in range(10):
        deit_base_data_test[i][j]=deit_base_data_test[i][j].drop(['ID'], axis=1)
        if 0 in deit_base_data_test[i][j].index:
            deit_base_data_test[i][j] = deit_base_data_test[i][j].drop(index=0)

# %%
deit_base_data_test[0][0]['Kernel Name'].unique
# Out:
# <bound method Series.unique of 1     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 2     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 3     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 4     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 5     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 6     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 7     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 8     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 9     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 10    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 11    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 12    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# Name: Kernel Name, dtype: object>

# %% [markdown]
# ### Section 3: Metric-based Data filtering and pre-processing

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import random

kernel_name=['fmha_cutlassF_f32_aligned_64x64_rf_sm80(AttentionKernel<bfloat16_t, Sm80, 1, 64, 64, 64, 1, 1>::Params)']
# ltx_cols = [col for col in deit_base_data[0][1].columns if col.startswith('smsp__branch_targets_threads_divergent')]# or col.startswith('gpu__') or col.startswith('sm__')]
ltx_cols=[col for col in deit_base_data[0][1].columns if 
            col in ['smsp__inst_executed_op_shared_atom.sum', 'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 'smsp__inst_issued.avg']]

for col in ltx_cols:
    for i in range(100):
        for j in range(10):
            if deit_base_data[i][j][col].dtype == 'object':  # likely string
                deit_base_data[i][j][col] = pd.to_numeric(deit_base_data[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
    for i in range(30):
        for j in range(10):
           if deit_base_data_test[i][j][col].dtype == 'object':  # likely string
                deit_base_data_test[i][j][col] = pd.to_numeric(deit_base_data_test[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
                
# Optional: update the DataFrame back
print(ltx_cols)
# Out:
# /home/t1000/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ['smsp__inst_executed_op_shared_atom.sum', 'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 'smsp__inst_issued.avg']

# %% [markdown]
# print(len(all_class_data))

# %%
# all_class_data[0][1]['thread_inst_executed_true']
deit_base_data_test[0][0]['thread_inst_executed']
# Out:
# 1     11356125440
# 2     11353151360
# 3     11352326016
# 4     11353756544
# 5     11353561728
# 6     11354691456
# 7     11353737472
# 8     11354312832
# 9     11354822144
# 10    11354016384
# 11    11353695616
# 12    11355349760
# Name: thread_inst_executed, dtype: object

# %% [markdown]
# ### Section 4: Generating classifier model's training data and validation data by considering only the filtered Metrics.

# %%
col = [col for col in deit_base_data[0][1].columns if 
        col in ['smsp__inst_executed_op_shared_atom.sum', 'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 'smsp__inst_issued.avg']]

for i in range(100):
    for j in range(10):
        for c in col:
            # deit_small_data[i][j][c]=pd.to_numeric(deit_small_data[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')
            deit_base_data[i][j][c]=pd.to_numeric(deit_base_data[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')
           
for i in range(30):
    for j in range(10):
        for c in col:
            deit_base_data_test[i][j][c]=pd.to_numeric(deit_base_data_test[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')




deit_base_data_df=[[[] for i in range(10)] for j in range(100)]
deit_base_data_test_df=[[[] for i in range(10)] for j in range(30)]

for i in range(len(deit_base_data)):
    for j in range(len(deit_base_data[i])):
        df2 = deit_base_data[i][j]
        # Keep only the columns that exist in the current DataFrame
        selected_cols = [c for c in col if c in df2.columns]
        deit_base_data_df[i][j] = deit_base_data[i][j][selected_cols].copy()

for i in range(len(deit_base_data_test)):
    for j in range(len(deit_base_data_test[i])):
        df2 = deit_base_data_test[i][j]
        # Keep only the columns that exist in the current DataFrame
        selected_cols = [c for c in col if c in df2.columns]
        deit_base_data_test_df[i][j] = deit_base_data_test[i][j][selected_cols].copy()

# %%
print(col)
# Out:
# ['smsp__inst_executed_op_shared_atom.sum', 'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 'smsp__inst_issued.avg']

# %%
deit_base_data_test_df[0][0].shape
# Out:
# (12, 3)

# %% [markdown]
# ### Dataset re-arrangement and providing label for training and test samples for both shadow and target model. Also, selecting appropiate range of FMHA kernel instances for achieving maximum attack success rate.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=[]
y_train=[]
X_test=[]
y_test=[]

for i in range(100):
    for j in range(10):
        r = deit_base_data_df[i][j]  # shape: (12, 2)
        j_col = np.full((r.shape[0], 1), j)  # shape: (12, 1)
        r_with_class = np.concatenate([r, j_col], axis=1)  # shape: (12, 3)
        X_train.append(r_with_class)

        if i < 50:
            y_train.append(1)
        else:
            y_train.append(0)


for i in range(30):
    for j in range(10):
        r = deit_base_data_test_df[i][j]  # shape: (12, 2)
        j_col = np.full((r.shape[0], 1), j)
        r_with_class = np.concatenate([r, j_col], axis=1)
        X_test.append(r_with_class)

        if i < 15:
            y_test.append(1)
        else:
            y_test.append(0)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train[:, 0:5, :]
X_test = X_test[:, 0:5, :]
    
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1000, 5, 4) (1000,)
# (300, 5, 4) (300,)

# %%
import numpy as np
print(np.unique(y_train, return_counts=True))
print(np.unique(y_test, return_counts=True))
print(type(X_train[0][0][0]))
# Out:
# (array([0, 1]), array([500, 500]))
# (array([0, 1]), array([150, 150]))
# <class 'numpy.float64'>

# %% [markdown]
# ### Attack Classifier training

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout, BatchNormalization
import numpy as np
# np.random.seed(42) 
from sklearn.model_selection import train_test_split

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # Disables GPU
# os.environ['PYTHONHASHSEED']=str(42)
def reset_random_seeds():
   os.environ['PYTHONHASHSEED']=str(42)
   tf.random.set_seed(42)
   np.random.seed(42)
   random.seed(42)


reset_random_seeds()
import tensorflow as tf

# Your input data shape: (samples, sequence_length, feature_dim)
num_samples = X_train.shape[0]
sequence_length = X_train.shape[1]
feature_dim = X_train.shape[2]

# Define the model
# Stacked BiLSTM Layers
model = Sequential()
model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=(sequence_length, feature_dim)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(32, return_sequences=False)))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))


# Compile
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

features_train = X_train[:, :, :-1]  
class_train = X_train[:, :, -1:]     
mean = features_train.mean(axis=(0, 1), keepdims=True)
std = features_train.std(axis=(0, 1), keepdims=True)
features_train = (features_train - mean) / (std + 1e-8)
X_train = np.concatenate([features_train, class_train], axis=-1)
# Summary
model.summary()
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)
# Train
history = model.fit(
    X_train_split, y_train_split,
    epochs=90,
    batch_size=45,
    validation_data=(X_val_split, y_val_split)
)
# Out:
# 2026-08-19 13:46:15.267595: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-19 13:46:15.296498: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-19 13:46:16.152067: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-19 13:46:16.257088: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-08-19 13:46:16.257103: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# 2026-08-19 13:46:16.257106: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# 2026-08-19 13:46:16.257108: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2026-08-19 13:46:16.257111: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: vhj4ybwysf5e7ppbc5tbh6f2ez
# 2026-08-19 13:46:16.257112: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] hostname: vhj4ybwysf5e7ppbc5tbh6f2ez
# 2026-08-19 13:46:16.257162: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] libcuda reported version is: 580.95.5
# 2026-08-19 13:46:16.257171: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:194] kernel reported version is: 580.95.5
# 2026-08-19 13:46:16.257172: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:284] kernel version seems to match DSO: 580.95.5
# /home/t1000/.local/lib/python3.10/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 5, 128)         │        35,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 64)             │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,769 (315.50 KB)
#  Trainable params: 80,769 (315.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5088 - loss: 0.6928 - val_accuracy: 0.5000 - val_loss: 0.6970
# Epoch 2/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4625 - loss: 0.6990 - val_accuracy: 0.4100 - val_loss: 0.6951
# Epoch 3/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5063 - loss: 0.6933 - val_accuracy: 0.4700 - val_loss: 0.6960
# Epoch 4/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4787 - loss: 0.6953 - val_accuracy: 0.4700 - val_loss: 0.6950
# Epoch 5/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5175 - loss: 0.6921 - val_accuracy: 0.4700 - val_loss: 0.6958
# Epoch 6/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4450 - loss: 0.6971 - val_accuracy: 0.4550 - val_loss: 0.6956
# Epoch 7/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4925 - loss: 0.6938 - val_accuracy: 0.4700 - val_loss: 0.6957
# Epoch 8/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4825 - loss: 0.6927 - val_accuracy: 0.4850 - val_loss: 0.6962
# Epoch 9/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5300 - loss: 0.6920 - val_accuracy: 0.5050 - val_loss: 0.6955
# Epoch 10/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5100 - loss: 0.6910 - val_accuracy: 0.4800 - val_loss: 0.6952
# Epoch 11/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5425 - loss: 0.6879 - val_accuracy: 0.5450 - val_loss: 0.6938
# Epoch 12/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5387 - loss: 0.6831 - val_accuracy: 0.4550 - val_loss: 0.6912
# Epoch 13/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5412 - loss: 0.6823 - val_accuracy: 0.4850 - val_loss: 0.6904
# Epoch 14/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5325 - loss: 0.6818 - val_accuracy: 0.5300 - val_loss: 0.6857
# Epoch 15/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5525 - loss: 0.6764 - val_accuracy: 0.4450 - val_loss: 0.6838
# Epoch 16/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5512 - loss: 0.6745 - val_accuracy: 0.4600 - val_loss: 0.6780
# Epoch 17/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5675 - loss: 0.6709 - val_accuracy: 0.5450 - val_loss: 0.6685
# Epoch 18/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5962 - loss: 0.6594 - val_accuracy: 0.5150 - val_loss: 0.6650
# Epoch 19/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6100 - loss: 0.6537 - val_accuracy: 0.5500 - val_loss: 0.6531
# Epoch 20/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6075 - loss: 0.6484 - val_accuracy: 0.6500 - val_loss: 0.6349
# Epoch 21/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6225 - loss: 0.6374 - val_accuracy: 0.6350 - val_loss: 0.6273
# Epoch 22/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6175 - loss: 0.6357 - val_accuracy: 0.6950 - val_loss: 0.6150
# Epoch 23/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6350 - loss: 0.6213 - val_accuracy: 0.6700 - val_loss: 0.6127
# Epoch 24/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6600 - loss: 0.6101 - val_accuracy: 0.6550 - val_loss: 0.5978
# Epoch 25/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6400 - loss: 0.6134 - val_accuracy: 0.6250 - val_loss: 0.6018
# Epoch 26/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6463 - loss: 0.5962 - val_accuracy: 0.6550 - val_loss: 0.5879
# Epoch 27/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6687 - loss: 0.5983 - val_accuracy: 0.7000 - val_loss: 0.5723
# Epoch 28/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6662 - loss: 0.5874 - val_accuracy: 0.7000 - val_loss: 0.5720
# Epoch 29/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6612 - loss: 0.5864 - val_accuracy: 0.6950 - val_loss: 0.5656
# Epoch 30/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6800 - loss: 0.5788 - val_accuracy: 0.6450 - val_loss: 0.5644
# Epoch 31/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6850 - loss: 0.5542 - val_accuracy: 0.6950 - val_loss: 0.5707
# Epoch 32/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6650 - loss: 0.5673 - val_accuracy: 0.6650 - val_loss: 0.5396
# Epoch 33/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6975 - loss: 0.5461 - val_accuracy: 0.6500 - val_loss: 0.5359
# Epoch 34/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6888 - loss: 0.5417 - val_accuracy: 0.6850 - val_loss: 0.5264
# Epoch 35/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7262 - loss: 0.5159 - val_accuracy: 0.7000 - val_loss: 0.5103
# Epoch 36/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7038 - loss: 0.5414 - val_accuracy: 0.7050 - val_loss: 0.5172
# Epoch 37/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7075 - loss: 0.5235 - val_accuracy: 0.6900 - val_loss: 0.5351
# Epoch 38/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7013 - loss: 0.5261 - val_accuracy: 0.6950 - val_loss: 0.5539
# Epoch 39/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7175 - loss: 0.5100 - val_accuracy: 0.7400 - val_loss: 0.4999
# Epoch 40/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7200 - loss: 0.4854 - val_accuracy: 0.6900 - val_loss: 0.4804
# Epoch 41/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7300 - loss: 0.4826 - val_accuracy: 0.7600 - val_loss: 0.4677
# Epoch 42/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7325 - loss: 0.4840 - val_accuracy: 0.7450 - val_loss: 0.4739
# Epoch 43/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7487 - loss: 0.4710 - val_accuracy: 0.7150 - val_loss: 0.4582
# Epoch 44/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7500 - loss: 0.4668 - val_accuracy: 0.7200 - val_loss: 0.4663
# Epoch 45/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7487 - loss: 0.4459 - val_accuracy: 0.7250 - val_loss: 0.4667
# Epoch 46/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7600 - loss: 0.4488 - val_accuracy: 0.7600 - val_loss: 0.4455
# Epoch 47/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7738 - loss: 0.4487 - val_accuracy: 0.7350 - val_loss: 0.4422
# Epoch 48/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7563 - loss: 0.4501 - val_accuracy: 0.7050 - val_loss: 0.5609
# Epoch 49/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7212 - loss: 0.5028 - val_accuracy: 0.7350 - val_loss: 0.4985
# Epoch 50/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7462 - loss: 0.4768 - val_accuracy: 0.7300 - val_loss: 0.4744
# Epoch 51/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7475 - loss: 0.4668 - val_accuracy: 0.7550 - val_loss: 0.5101
# Epoch 52/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7575 - loss: 0.4477 - val_accuracy: 0.7500 - val_loss: 0.5101
# Epoch 53/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7600 - loss: 0.4451 - val_accuracy: 0.7200 - val_loss: 0.5546
# Epoch 54/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7475 - loss: 0.5037 - val_accuracy: 0.7150 - val_loss: 0.5235
# Epoch 55/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7600 - loss: 0.4579 - val_accuracy: 0.7650 - val_loss: 0.4354
# Epoch 56/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7700 - loss: 0.4182 - val_accuracy: 0.7100 - val_loss: 0.4625
# Epoch 57/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7887 - loss: 0.4100 - val_accuracy: 0.7400 - val_loss: 0.4091
# Epoch 58/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7962 - loss: 0.3953 - val_accuracy: 0.7200 - val_loss: 0.4799
# Epoch 59/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7850 - loss: 0.4237 - val_accuracy: 0.7500 - val_loss: 0.4592
# Epoch 60/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7800 - loss: 0.4060 - val_accuracy: 0.7750 - val_loss: 0.4228
# Epoch 61/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8000 - loss: 0.3953 - val_accuracy: 0.7800 - val_loss: 0.3989
# Epoch 62/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7962 - loss: 0.3986 - val_accuracy: 0.7800 - val_loss: 0.3975
# Epoch 63/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7875 - loss: 0.3938 - val_accuracy: 0.7600 - val_loss: 0.4448
# Epoch 64/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7775 - loss: 0.4379 - val_accuracy: 0.7150 - val_loss: 0.4245
# Epoch 65/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8075 - loss: 0.3771 - val_accuracy: 0.8150 - val_loss: 0.3768
# Epoch 66/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8388 - loss: 0.3382 - val_accuracy: 0.8300 - val_loss: 0.3317
# Epoch 67/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8300 - loss: 0.3289 - val_accuracy: 0.8700 - val_loss: 0.3377
# Epoch 68/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8338 - loss: 0.3230 - val_accuracy: 0.8450 - val_loss: 0.3293
# Epoch 69/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8325 - loss: 0.3146 - val_accuracy: 0.7650 - val_loss: 0.3091
# Epoch 70/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8388 - loss: 0.3371 - val_accuracy: 0.8900 - val_loss: 0.2724
# Epoch 71/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8037 - loss: 0.3848 - val_accuracy: 0.8100 - val_loss: 0.3254
# Epoch 72/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8363 - loss: 0.3377 - val_accuracy: 0.8300 - val_loss: 0.3032
# Epoch 73/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8675 - loss: 0.2943 - val_accuracy: 0.8300 - val_loss: 0.3147
# Epoch 74/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8625 - loss: 0.2658 - val_accuracy: 0.8800 - val_loss: 0.2415
# Epoch 75/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8712 - loss: 0.2644 - val_accuracy: 0.8750 - val_loss: 0.2571
# Epoch 76/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8650 - loss: 0.2717 - val_accuracy: 0.8750 - val_loss: 0.2395
# Epoch 77/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8612 - loss: 0.2718 - val_accuracy: 0.8450 - val_loss: 0.2275
# Epoch 78/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8875 - loss: 0.2455 - val_accuracy: 0.8950 - val_loss: 0.2283
# Epoch 79/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8600 - loss: 0.2594 - val_accuracy: 0.8900 - val_loss: 0.2289
# Epoch 80/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8175 - loss: 0.3363 - val_accuracy: 0.7800 - val_loss: 0.3605
# Epoch 81/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8537 - loss: 0.2909 - val_accuracy: 0.7900 - val_loss: 0.3292
# Epoch 82/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8650 - loss: 0.2651 - val_accuracy: 0.8500 - val_loss: 0.2178
# Epoch 83/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8800 - loss: 0.2387 - val_accuracy: 0.8700 - val_loss: 0.2063
# Epoch 84/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9013 - loss: 0.2117 - val_accuracy: 0.8650 - val_loss: 0.1912
# Epoch 85/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8875 - loss: 0.2131 - val_accuracy: 0.8800 - val_loss: 0.1918
# Epoch 86/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9087 - loss: 0.1996 - val_accuracy: 0.8900 - val_loss: 0.2096
# Epoch 87/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8587 - loss: 0.3177 - val_accuracy: 0.8500 - val_loss: 0.2589
# Epoch 88/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8487 - loss: 0.3183 - val_accuracy: 0.8450 - val_loss: 0.2620
# Epoch 89/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8612 - loss: 0.2568 - val_accuracy: 0.8750 - val_loss: 0.1959
# Epoch 90/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8913 - loss: 0.2255 - val_accuracy: 0.8750 - val_loss: 0.1710

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Membership Inference Attack on Target Model Data

# %%
# Predict
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

features_train = X_test[:, :, :-1] 
class_train = X_test[:, :, -1:]    

# Compute mean and std from features only
mean = features_train.mean(axis=(0, 1), keepdims=True)
std = features_train.std(axis=(0, 1), keepdims=True)

# Normalize features
features_train = (features_train - mean) / (std + 1e-8)

# Reattach the class column
X_test = np.concatenate([features_train, class_train], axis=-1)

# Predict probabilities
predictions = model.predict(X_test)

# # Convert probabilities to binary labels
predicted_labels = (predictions > 0.5).astype(int)

# Accuracy
acc = accuracy_score(y_test, predicted_labels)
print(f"Test Accuracy: {acc:.4f}")

# Confusion matrix
cm = confusion_matrix(y_test, predicted_labels)
print("Confusion Matrix:\n", cm)

# Plot
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Test Set","Training Set"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Test Accuracy: 0.9033
# Confusion Matrix:
#  [[139  11]
#  [ 18 132]]

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_auc_score,
    roc_curve,
    f1_score
)
import matplotlib.pyplot as plt
import numpy as np

# Binary predictions using threshold 0.5
predicted_labels = (predictions >= 0.5).astype(int)

# F1 Score
f1 = f1_score(y_test, predicted_labels)
print(f"F1 Score: {f1:.4f}")

# AUC Score
auc_score = roc_auc_score(y_test, predictions)
print(f"AUC Score: {auc_score:.4f}")

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, predictions)

# Plot ROC Curve
plt.figure()
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.4f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # Random chance line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# F1 Score: 0.9010
# AUC Score: 0.9863
