# %% [markdown]
# ## DeiT-Base model's results on CIFAR-10 dataset using Proposed Mitigation on A40 GPU

# %% [markdown]
# ### Section 1: Loading Dataset

# %%
import numpy as np
import pandas as pd

# %%
deit_base_data=[]
deit_base_data_test=[]

for i in range(1,101):
    temp1=[]
    for j in range(10):
        path='./mem_csv_deit_base_mod6/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    deit_base_data.append(temp1)

for i in range(1,31):
    temp1=[]
    for j in range(10):
        path='./mem_csv_deit_base_mod6_test/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    deit_base_data_test.append(temp1)
    temp1=[]
print(deit_base_data[0][1].columns)
print(deit_base_data_test[0][1].columns)
# Out:
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'smsp__sass_thread_inst_executed_op_fadd_pred_on.sum.per_cycle_elapsed',
#        'smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed',
#        'smsp__sass_thread_inst_executed_op_fmul_pred_on.sum.per_cycle_elapsed',
#        'smsp__thread_inst_executed_per_inst_executed.ratio',
#        'smsp__thread_inst_executed_pred_on_per_inst_executed.ratio',
#        'smsp__warps_active.avg.peak_sustained',
#        'smsp__warps_active.avg.per_cycle_active',
#        'smsp__warps_eligible.avg.per_cycle_active', 'thread_inst_executed',
#        'thread_inst_executed_true'],
#       dtype='object', length=802)
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'smsp__sass_thread_inst_executed_op_fadd_pred_on.sum.per_cycle_elapsed',
#        'smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed',
#        'smsp__sass_thread_inst_executed_op_fmul_pred_on.sum.per_cycle_elapsed',
#        'smsp__thread_inst_executed_per_inst_executed.ratio',
#        'smsp__thread_inst_executed_pred_on_per_inst_executed.ratio',
#        'smsp__warps_active.avg.peak_sustained',
#        'smsp__warps_active.avg.per_cycle_active',
#        'smsp__warps_eligible.avg.per_cycle_active', 'thread_inst_executed',
#        'thread_inst_executed_true'],
#       dtype='object', length=802)

# %% [markdown]
# ### Section 2: Pre-processing Dataset

# %%
for i in range(100):
    for j in range(10):
        deit_base_data[i][j]=deit_base_data[i][j].drop(['ID'], axis=1)
        if 0 in deit_base_data[i][j].index:
            deit_base_data[i][j] = deit_base_data[i][j].drop(index=0)
        

for i in range(30):
    for j in range(10):
        deit_base_data_test[i][j]=deit_base_data_test[i][j].drop(['ID'], axis=1)
        if 0 in deit_base_data_test[i][j].index:
            deit_base_data_test[i][j] = deit_base_data_test[i][j].drop(index=0)

# %%
deit_base_data_test[0][0]['Kernel Name'].unique
# Out:
# <bound method Series.unique of 1     fmha_cutlassF_f32_aligned_64x64_rf_sm80(PyTorc...
# 2     fmha_cutlassF_f32_aligned_64x64_rf_sm80(PyTorc...
# 3     fmha_cutlassF_f32_aligned_64x64_rf_sm80(PyTorc...
# 4     fmha_cutlassF_f32_aligned_64x64_rf_sm80(PyTorc...
# 5     fmha_cutlassF_f32_aligned_64x64_rf_sm80(PyTorc...
# 6     fmha_cutlassF_f32_aligned_64x64_rf_sm80(PyTorc...
# 7     fmha_cutlassF_f32_aligned_64x64_rf_sm80(PyTorc...
# 8     fmha_cutlassF_f32_aligned_64x64_rf_sm80(PyTorc...
# 9     fmha_cutlassF_f32_aligned_64x64_rf_sm80(PyTorc...
# 10    fmha_cutlassF_f32_aligned_64x64_rf_sm80(PyTorc...
# 11    fmha_cutlassF_f32_aligned_64x64_rf_sm80(PyTorc...
# 12    fmha_cutlassF_f32_aligned_64x64_rf_sm80(PyTorc...
# Name: Kernel Name, dtype: object>

# %% [markdown]
# ### Section 3: Metric-based Data filtering and pre-processing

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import random

kernel_name=['fmha_cutlassF_f32_aligned_64x64_rf_sm80']
ltx_cols=[col for col in deit_base_data[0][1].columns if 
    col.startswith('smsp__branch_targets_threads_divergent') #
        or col.startswith('smsp__inst_executed.sum') 
        or col.startswith('smsp__inst_executed_op_branch') 
        or col.startswith('smsp__inst_executed_op_shared_atom') #
        or col.startswith('smsp__sass_inst_executed_op_shared_') 
]
for col in ltx_cols:
    for i in range(100):
        for j in range(10):
           if deit_base_data[i][j][col].dtype == 'object':  # likely string
                deit_base_data[i][j][col] = pd.to_numeric(deit_base_data[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
            
    for i in range(30):
        for j in range(10):
            if deit_base_data_test[i][j][col].dtype == 'object':  # likely string
                deit_base_data_test[i][j][col] = pd.to_numeric(deit_base_data_test[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
               
# Optional: update the DataFrame back
print(ltx_cols)
# Out:
# /home/t1000/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ['smsp__branch_targets_threads_divergent', 'smsp__inst_executed.sum', 'smsp__inst_executed_op_branch.sum', 'smsp__inst_executed_op_shared_atom.sum', 'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 'smsp__sass_inst_executed_op_shared_ld.sum', 'smsp__sass_inst_executed_op_shared_st.sum']

# %% [markdown]
# print(len(all_class_data))

# %%
deit_base_data[0][0].shape
# Out:
# (12, 801)

# %% [markdown]
# ### Section 4: Generating classifier model's training data and validation data by considering only the filtered Metrics.

# %%
col = [col for col in deit_base_data[0][1].columns if 
        col.startswith('smsp__inst_executed_op_branch') 
        or col.startswith('smsp__inst_executed_op_shared_atom') 
        or col.startswith('smsp__sass_inst_executed_op_shared_') 
]

for i in range(100):
    for j in range(10):
        for c in col:
            deit_base_data[i][j][c]=pd.to_numeric(deit_base_data[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')
            
for i in range(30):
    for j in range(10):
        for c in col:
            deit_base_data_test[i][j][c]=pd.to_numeric(deit_base_data_test[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')
           


# Loop through each DataFrame and keep only the selected columns (if they exist)
deit_base_data_df=[[[] for i in range(10)] for j in range(100)]
deit_base_data_test_df=[[[] for i in range(10)] for j in range(30)]

for i in range(len(deit_base_data)):
    for j in range(len(deit_base_data[i])):
        df2 = deit_base_data[i][j]
        # Keep only the columns that exist in the current DataFrame
        selected_cols = [c for c in col if c in df2.columns]
        deit_base_data_df[i][j] = deit_base_data[i][j][selected_cols].copy()

for i in range(len(deit_base_data_test)):
    for j in range(len(deit_base_data_test[i])):
        df2 = deit_base_data_test[i][j]
        # Keep only the columns that exist in the current DataFrame
        selected_cols = [c for c in col if c in df2.columns]
        deit_base_data_test_df[i][j] = df2[selected_cols].copy()

# %%
print(col)
# Out:
# ['smsp__inst_executed_op_branch.sum', 'smsp__inst_executed_op_shared_atom.sum', 'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 'smsp__sass_inst_executed_op_shared_ld.sum', 'smsp__sass_inst_executed_op_shared_st.sum']

# %%
deit_base_data_df[0][0].shape
# Out:
# (12, 5)

# %% [markdown]
# ### Dataset re-arrangement and providing label for training and test samples for both shadow and target model. Also, selecting appropiate range of FMHA kernel instances for achieving maximum attack success rate.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=[]
y_train=[]
X_test=[]
y_test=[]

for i in range(100):
    for j in range(10):
        r = deit_base_data_df[i][j]  # shape: (12, 2)
        X_train.append(r)

        if i < 50:
            y_train.append(1)
        else:
            y_train.append(0)

for i in range(30):
    for j in range(10):
        r = deit_base_data_test_df[i][j]  # shape: (12, 2)
        X_test.append(r)

        if i < 15:
            y_test.append(1)
        else:
            y_test.append(0)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train[:, 0:8, :]
X_test = X_test[:, 0:8, :]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1000, 8, 5) (1000,)
# (300, 8, 5) (300,)

# %%
import numpy as np
print(np.unique(y_train, return_counts=True))
print(np.unique(y_test, return_counts=True))
# Out:
# (array([0, 1]), array([500, 500]))
# (array([0, 1]), array([150, 150]))

# %%
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### Attack Classifier training

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout, BatchNormalization
import numpy as np
from sklearn.model_selection import train_test_split

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  
def reset_random_seeds():
   os.environ['PYTHONHASHSEED']=str(42)
   tf.random.set_seed(42)
   np.random.seed(42)
   random.seed(42)

reset_random_seeds()
import tensorflow as tf

# Your input data shape: (samples, sequence_length, feature_dim)
num_samples = X_train.shape[0]
sequence_length = X_train.shape[1]
feature_dim = X_train.shape[2]

# Define the model
# Stacked BiLSTM Layers
model = Sequential()
model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=(sequence_length, feature_dim)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(32, return_sequences=False)))
model.add(Dropout(0.2))

# Fully connected hidden layer
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))


# Compile
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
mean = X_train.mean(axis=(0, 1), keepdims=True)
std = X_train.std(axis=(0, 1), keepdims=True)
X_train = (X_train - mean) / (std + 1e-8)
# Summary
model.summary()
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)
# Train
history = model.fit(
    X_train_split, y_train_split,
    epochs=90,
    batch_size=45,
    validation_data=(X_val_split, y_val_split)
)
# Out:
# /home/t1000/.local/lib/python3.10/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_8 (Bidirectional) │ (None, 8, 128)         │        35,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 8, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_9 (Bidirectional) │ (None, 64)             │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81,281 (317.50 KB)
#  Trainable params: 81,281 (317.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.5025 - loss: 0.6928 - val_accuracy: 0.5250 - val_loss: 0.6922
# Epoch 2/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5188 - loss: 0.6927 - val_accuracy: 0.5050 - val_loss: 0.6919
# Epoch 3/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5475 - loss: 0.6884 - val_accuracy: 0.4950 - val_loss: 0.6906
# Epoch 4/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5512 - loss: 0.6876 - val_accuracy: 0.5250 - val_loss: 0.6868
# Epoch 5/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5913 - loss: 0.6809 - val_accuracy: 0.5650 - val_loss: 0.6794
# Epoch 6/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5863 - loss: 0.6740 - val_accuracy: 0.5700 - val_loss: 0.6750
# Epoch 7/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5813 - loss: 0.6707 - val_accuracy: 0.6050 - val_loss: 0.6710
# Epoch 8/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5788 - loss: 0.6707 - val_accuracy: 0.6100 - val_loss: 0.6754
# Epoch 9/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5725 - loss: 0.6731 - val_accuracy: 0.5550 - val_loss: 0.6752
# Epoch 10/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6150 - loss: 0.6565 - val_accuracy: 0.5800 - val_loss: 0.6726
# Epoch 11/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6275 - loss: 0.6458 - val_accuracy: 0.6150 - val_loss: 0.6812
# Epoch 12/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6325 - loss: 0.6508 - val_accuracy: 0.6450 - val_loss: 0.6692
# Epoch 13/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6275 - loss: 0.6457 - val_accuracy: 0.6200 - val_loss: 0.6507
# Epoch 14/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6513 - loss: 0.6399 - val_accuracy: 0.6050 - val_loss: 0.6537
# Epoch 15/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6388 - loss: 0.6361 - val_accuracy: 0.6100 - val_loss: 0.6555
# Epoch 16/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6587 - loss: 0.6232 - val_accuracy: 0.6700 - val_loss: 0.6445
# Epoch 17/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6550 - loss: 0.6224 - val_accuracy: 0.6750 - val_loss: 0.6341
# Epoch 18/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6800 - loss: 0.6113 - val_accuracy: 0.6650 - val_loss: 0.6313
# Epoch 19/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6900 - loss: 0.5942 - val_accuracy: 0.6900 - val_loss: 0.6201
# Epoch 20/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6888 - loss: 0.5997 - val_accuracy: 0.6500 - val_loss: 0.6581
# Epoch 21/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6950 - loss: 0.5945 - val_accuracy: 0.5900 - val_loss: 0.6909
# Epoch 22/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6562 - loss: 0.6098 - val_accuracy: 0.6850 - val_loss: 0.6121
# Epoch 23/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6837 - loss: 0.5853 - val_accuracy: 0.7100 - val_loss: 0.5749
# Epoch 24/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7337 - loss: 0.5527 - val_accuracy: 0.7050 - val_loss: 0.5894
# Epoch 25/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7113 - loss: 0.5538 - val_accuracy: 0.7000 - val_loss: 0.5725
# Epoch 26/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7163 - loss: 0.5373 - val_accuracy: 0.6850 - val_loss: 0.5788
# Epoch 27/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7250 - loss: 0.5318 - val_accuracy: 0.7350 - val_loss: 0.5459
# Epoch 28/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7513 - loss: 0.5073 - val_accuracy: 0.7100 - val_loss: 0.5305
# Epoch 29/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7550 - loss: 0.4935 - val_accuracy: 0.7200 - val_loss: 0.6057
# Epoch 30/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7200 - loss: 0.5112 - val_accuracy: 0.7200 - val_loss: 0.5656
# Epoch 31/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7337 - loss: 0.5005 - val_accuracy: 0.7350 - val_loss: 0.4820
# Epoch 32/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7900 - loss: 0.4297 - val_accuracy: 0.7850 - val_loss: 0.4419
# Epoch 33/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8075 - loss: 0.4135 - val_accuracy: 0.7700 - val_loss: 0.5025
# Epoch 34/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7875 - loss: 0.4193 - val_accuracy: 0.8000 - val_loss: 0.4088
# Epoch 35/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8125 - loss: 0.3926 - val_accuracy: 0.7850 - val_loss: 0.4321
# Epoch 36/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8138 - loss: 0.3952 - val_accuracy: 0.8400 - val_loss: 0.3748
# Epoch 37/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8025 - loss: 0.3971 - val_accuracy: 0.7150 - val_loss: 0.5181
# Epoch 38/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7663 - loss: 0.4518 - val_accuracy: 0.8100 - val_loss: 0.3965
# Epoch 39/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8100 - loss: 0.3760 - val_accuracy: 0.7450 - val_loss: 0.4388
# Epoch 40/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8238 - loss: 0.3645 - val_accuracy: 0.8100 - val_loss: 0.3673
# Epoch 41/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8500 - loss: 0.3291 - val_accuracy: 0.8400 - val_loss: 0.3583
# Epoch 42/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8575 - loss: 0.3219 - val_accuracy: 0.8350 - val_loss: 0.3065
# Epoch 43/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8650 - loss: 0.2941 - val_accuracy: 0.7950 - val_loss: 0.3288
# Epoch 44/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8825 - loss: 0.2605 - val_accuracy: 0.8650 - val_loss: 0.2946
# Epoch 45/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8838 - loss: 0.2716 - val_accuracy: 0.8350 - val_loss: 0.3024
# Epoch 46/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8763 - loss: 0.2898 - val_accuracy: 0.8950 - val_loss: 0.2539
# Epoch 47/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8838 - loss: 0.2895 - val_accuracy: 0.8750 - val_loss: 0.4207
# Epoch 48/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9000 - loss: 0.2467 - val_accuracy: 0.9150 - val_loss: 0.2062
# Epoch 49/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8975 - loss: 0.2484 - val_accuracy: 0.8400 - val_loss: 0.3326
# Epoch 50/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9312 - loss: 0.2026 - val_accuracy: 0.8850 - val_loss: 0.2988
# Epoch 51/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8750 - loss: 0.3006 - val_accuracy: 0.9300 - val_loss: 0.2009
# Epoch 52/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8950 - loss: 0.2517 - val_accuracy: 0.9200 - val_loss: 0.2628
# Epoch 53/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8975 - loss: 0.2424 - val_accuracy: 0.9100 - val_loss: 0.2241
# Epoch 54/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9375 - loss: 0.1633 - val_accuracy: 0.9300 - val_loss: 0.1804
# Epoch 55/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9450 - loss: 0.1418 - val_accuracy: 0.9700 - val_loss: 0.1217
# Epoch 56/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9600 - loss: 0.1098 - val_accuracy: 0.9700 - val_loss: 0.0899
# Epoch 57/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.1461 - val_accuracy: 0.9700 - val_loss: 0.0903
# Epoch 58/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9563 - loss: 0.1277 - val_accuracy: 0.9800 - val_loss: 0.0580
# Epoch 59/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9550 - loss: 0.1210 - val_accuracy: 0.9650 - val_loss: 0.1044
# Epoch 60/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9262 - loss: 0.2220 - val_accuracy: 0.9500 - val_loss: 0.2043
# Epoch 61/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9362 - loss: 0.1802 - val_accuracy: 0.9700 - val_loss: 0.1382
# Epoch 62/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9438 - loss: 0.1518 - val_accuracy: 0.9900 - val_loss: 0.0476
# Epoch 63/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9725 - loss: 0.0882 - val_accuracy: 1.0000 - val_loss: 0.0356
# Epoch 64/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9850 - loss: 0.0568 - val_accuracy: 0.9900 - val_loss: 0.0291
# Epoch 65/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9825 - loss: 0.0603 - val_accuracy: 1.0000 - val_loss: 0.0209
# Epoch 66/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9887 - loss: 0.0436 - val_accuracy: 0.9250 - val_loss: 0.1538
# Epoch 67/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9837 - loss: 0.0505 - val_accuracy: 1.0000 - val_loss: 0.0191
# Epoch 68/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9787 - loss: 0.0563 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 69/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9962 - loss: 0.0222 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 70/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9925 - loss: 0.0229 - val_accuracy: 0.9950 - val_loss: 0.0217
# Epoch 71/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9775 - loss: 0.0830 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 72/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9638 - loss: 0.1201 - val_accuracy: 0.9900 - val_loss: 0.0334
# Epoch 73/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9875 - loss: 0.0482 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 74/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9912 - loss: 0.0285 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 75/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9962 - loss: 0.0207 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 76/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 77/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 78/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 79/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 80/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9925 - loss: 0.0200 - val_accuracy: 0.9900 - val_loss: 0.0143
# Epoch 81/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9787 - loss: 0.0568 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 82/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9937 - loss: 0.0309 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 83/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9750 - loss: 0.0741 - val_accuracy: 0.9100 - val_loss: 0.3387
# Epoch 84/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9287 - loss: 0.2086 - val_accuracy: 0.9550 - val_loss: 0.1961
# Epoch 85/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9362 - loss: 0.1711 - val_accuracy: 0.9750 - val_loss: 0.0506
# Epoch 86/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9750 - loss: 0.0590 - val_accuracy: 0.9850 - val_loss: 0.0284
# Epoch 87/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9862 - loss: 0.0362 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 88/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9975 - loss: 0.0184 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 89/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 90/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 0.0021

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Membership Inference Attack on Target Model Data

# %%
# Predict
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

mean = X_test.mean(axis=(0, 1), keepdims=True)
std = X_test.std(axis=(0, 1), keepdims=True)
X_test = (X_test - mean) / (std + 1e-8)

# Predict probabilities
predictions = model.predict(X_test)

# # Convert probabilities to binary labels
predicted_labels = (predictions > 0.5).astype(int)

# Accuracy
acc = accuracy_score(y_test, predicted_labels)
print(f"Test Accuracy: {acc:.4f}")

# Confusion matrix
cm = confusion_matrix(y_test, predicted_labels)
print("Confusion Matrix:\n", cm)

# Plot
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Test Set", "Training Set"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Test Accuracy: 0.7033
# Confusion Matrix:
#  [[102  48]
#  [ 41 109]]

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_auc_score,
    roc_curve,
    f1_score
)
import matplotlib.pyplot as plt
import numpy as np

# Binary predictions using threshold 0.5
predicted_labels = (predictions >= 0.5).astype(int)

# F1 Score
f1 = f1_score(y_test, predicted_labels)
print(f"F1 Score: {f1:.4f}")

# AUC Score
auc_score = roc_auc_score(y_test, predictions)
print(f"AUC Score: {auc_score:.4f}")

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, predictions)

# Plot ROC Curve
plt.figure()
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.4f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # Random chance line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# F1 Score: 0.7101
# AUC Score: 0.7613
