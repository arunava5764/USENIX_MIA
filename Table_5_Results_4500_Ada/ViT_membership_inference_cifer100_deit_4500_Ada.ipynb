# %% [markdown]
# ## Table 4: DeiT-Base model's results on CIFAR-100 dataset using RTX 4500 Ada GPU

# %% [markdown]
# ### Section 1: Loading Dataset

# %%
import numpy as np
import pandas as pd

# %%
deit_base_data=[]
deit_base_data_test=[]

for i in range(1,101):
    temp1=[]
    for j in range(10):
        path='./mem_csv_deit_base_cifar-100_2/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    deit_base_data.append(temp1)


for i in range(1,31):
    temp1=[]
    for j in range(10):
        path='./mem_csv_deit_base_cifar-100_test_2/report'+str(j)+'_'+str(i)+'.csv'
        data=pd.read_csv(path)
        temp1.append(data)
    deit_base_data_test.append(temp1)

print(deit_base_data[0][1].columns)
print(deit_base_data_test[0][1].columns)
# Out:
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'smsp__warps_active.min.peak_sustained',
#        'smsp__warps_active.min.per_cycle_active',
#        'smsp__warps_active.sum.peak_sustained',
#        'smsp__warps_active.sum.per_cycle_active',
#        'smsp__warps_eligible.avg.per_cycle_active',
#        'smsp__warps_eligible.max.per_cycle_active',
#        'smsp__warps_eligible.min.per_cycle_active',
#        'smsp__warps_eligible.sum.per_cycle_active', 'thread_inst_executed',
#        'thread_inst_executed_true'],
#       dtype='object', length=1220)
# Index(['ID', 'Process ID', 'Process Name', 'Host Name', 'Kernel Name',
#        'Context', 'Stream', 'Block Size', 'Grid Size', 'Device',
#        ...
#        'smsp__warps_active.min.peak_sustained',
#        'smsp__warps_active.min.per_cycle_active',
#        'smsp__warps_active.sum.peak_sustained',
#        'smsp__warps_active.sum.per_cycle_active',
#        'smsp__warps_eligible.avg.per_cycle_active',
#        'smsp__warps_eligible.max.per_cycle_active',
#        'smsp__warps_eligible.min.per_cycle_active',
#        'smsp__warps_eligible.sum.per_cycle_active', 'thread_inst_executed',
#        'thread_inst_executed_true'],
#       dtype='object', length=1220)

# %% [markdown]
# ### Section 2: Pre-processing Dataset

# %%
for i in range(100):
    for j in range(10):
        deit_base_data[i][j]=deit_base_data[i][j].drop(['ID'], axis=1)
        if 0 in deit_base_data[i][j].index:
            deit_base_data[i][j] = deit_base_data[i][j].drop(index=0)

for i in range(30):
    for j in range(10):
        deit_base_data_test[i][j]=deit_base_data_test[i][j].drop(['ID'], axis=1)
        if 0 in deit_base_data_test[i][j].index:
            deit_base_data_test[i][j] = deit_base_data_test[i][j].drop(index=0)

# %%
deit_base_data_test[0][0]['Kernel Name'].unique
# Out:
# <bound method Series.unique of 1     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 2     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 3     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 4     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 5     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 6     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 7     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 8     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 9     fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 10    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 11    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# 12    fmha_cutlassF_f32_aligned_64x64_rf_sm80(Attent...
# Name: Kernel Name, dtype: object>

# %% [markdown]
# ### Section 3: Metric-based Data filtering and pre-processing

# %%
# Import additional libraries for visualization and random sampling
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import random
kernel_name=['fmha_cutlassF_f32_aligned_64x64_rf_sm80']
ltx_cols=[col for col in deit_base_data[0][1].columns if 
          col in ['l1tex__data_pipe_lsu_wavefronts_mem_shared.sum', 
                  'l1tex__data_pipe_lsu_wavefronts_mem_shared.sum.pct_of_peak_sustained_elapsed', 
                  'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_atom.sum', 
                  'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_atom.sum.pct_of_peak_sustained_elapsed', 
                  'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_ld.sum', 
                  'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_ld.sum.pct_of_peak_sustained_elapsed', 
                  'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_st.sum', 
                  'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_st.sum.pct_of_peak_sustained_elapsed', 
                  'sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_of_peak_sustained_elapsed', 
                  'sm__inst_executed_pipe_cbu_pred_on_any.max.pct_of_peak_sustained_elapsed', 
                  'sm__inst_executed_pipe_cbu_pred_on_any.min.pct_of_peak_sustained_elapsed', 
                  'sm__inst_executed_pipe_cbu_pred_on_any.sum.pct_of_peak_sustained_elapsed', 
                  'sm__mio_pq_read_cycles_active.sum.pct_of_peak_sustained_elapsed', 
                  'smsp__branch_targets_threads_divergent', 
                  'smsp__inst_executed.sum', 
                  'smsp__inst_executed_op_shared_atom.sum', 
                  'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 
                  'smsp__sass_inst_executed_op_shared_ld.sum', 
                  'smsp__sass_inst_executed_op_shared_st.sum']
                  or col.startswith('smsp__average_warps_issue_stalled_branch_resolving_per_issue_active')
                  or col.startswith('smsp__inst_executed_op_branch')
]
for col in ltx_cols:
    for i in range(100):
        for j in range(10):
            if deit_base_data[i][j][col].dtype == 'object': 
                deit_base_data[i][j][col] = pd.to_numeric(deit_base_data[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
    for i in range(30):
        for j in range(10):
            if deit_base_data_test[i][j][col].dtype == 'object':  
                deit_base_data_test[i][j][col] = pd.to_numeric(deit_base_data_test[i][j][col].astype(str).str.replace(',', '').str.strip(), errors='coerce')
                

print(ltx_cols)
# Out:
# ['l1tex__data_pipe_lsu_wavefronts_mem_shared.sum', 'l1tex__data_pipe_lsu_wavefronts_mem_shared.sum.pct_of_peak_sustained_elapsed', 'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_atom.sum', 'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_atom.sum.pct_of_peak_sustained_elapsed', 'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_ld.sum', 'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_ld.sum.pct_of_peak_sustained_elapsed', 'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_st.sum', 'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_st.sum.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.max.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.min.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.sum.pct_of_peak_sustained_elapsed', 'sm__mio_pq_read_cycles_active.sum.pct_of_peak_sustained_elapsed', 'smsp__average_warps_issue_stalled_branch_resolving_per_issue_active.ratio', 'smsp__branch_targets_threads_divergent', 'smsp__inst_executed.sum', 'smsp__inst_executed_op_branch.avg', 'smsp__inst_executed_op_branch.max', 'smsp__inst_executed_op_branch.min', 'smsp__inst_executed_op_branch.sum', 'smsp__inst_executed_op_shared_atom.sum', 'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 'smsp__sass_inst_executed_op_shared_ld.sum', 'smsp__sass_inst_executed_op_shared_st.sum']

# %% [markdown]
# print(len(all_class_data))

# %%
deit_base_data[0][0].shape
# Out:
# (12, 1219)

# %% [markdown]
# ### Section 4: Generating classifier model's training data and validation data by considering only the filtered Metrics.

# %%
col = [col for col in deit_base_data[0][1].columns if 
    col in ['l1tex__data_pipe_lsu_wavefronts_mem_shared.sum', 
                  'l1tex__data_pipe_lsu_wavefronts_mem_shared.sum.pct_of_peak_sustained_elapsed', 
                  'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_atom.sum', 
                  'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_atom.sum.pct_of_peak_sustained_elapsed', 
                  'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_ld.sum', 
                  'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_ld.sum.pct_of_peak_sustained_elapsed',  
                  'sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_of_peak_sustained_elapsed', 
                  'sm__inst_executed_pipe_cbu_pred_on_any.max.pct_of_peak_sustained_elapsed', 
                  'sm__inst_executed_pipe_cbu_pred_on_any.min.pct_of_peak_sustained_elapsed', 
                  'sm__inst_executed_pipe_cbu_pred_on_any.sum.pct_of_peak_sustained_elapsed', 
                  'sm__mio_pq_read_cycles_active.sum.pct_of_peak_sustained_elapsed', 
                  'smsp__branch_targets_threads_divergent', 
                  'smsp__inst_executed.sum', 
                  'smsp__inst_executed_op_shared_atom.sum', 
                  'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 
                  'smsp__sass_inst_executed_op_shared_ld.sum', 
                  'smsp__sass_inst_executed_op_shared_st.sum'
                  ]
                  or col.startswith('smsp__average_warps_issue_stalled_branch_resolving_per_issue_active')
                  or col.startswith('smsp__inst_executed_op_branch')
]

for i in range(10):
    for j in range(10):
        for c in col:
            deit_base_data[i][j][c]=pd.to_numeric(deit_base_data[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')
            
for i in range(30):
    for j in range(10):
        for c in col:
            deit_base_data_test[i][j][c]=pd.to_numeric(deit_base_data_test[i][j][c].astype(str).str.replace(',', '').str.strip(), errors='coerce').astype('float32')


deit_base_data_df=[[[] for i in range(10)] for j in range(100)]
deit_base_data_test_df=[[[] for i in range(10)] for j in range(30)]
for i in range(len(deit_base_data)):
    for j in range(len(deit_base_data[i])):
        df2 = deit_base_data[i][j]
        selected_cols = [c for c in col if c in df2.columns]
        deit_base_data_df[i][j] = deit_base_data[i][j][selected_cols].copy()

for i in range(len(deit_base_data_test)):
    for j in range(len(deit_base_data_test[i])):
        df2 = deit_base_data_test[i][j]
        selected_cols = [c for c in col if c in df2.columns]
        deit_base_data_test_df[i][j] = deit_base_data_test[i][j][selected_cols].copy()

# %%
print(col)
# Out:
# ['l1tex__data_pipe_lsu_wavefronts_mem_shared.sum', 'l1tex__data_pipe_lsu_wavefronts_mem_shared.sum.pct_of_peak_sustained_elapsed', 'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_atom.sum', 'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_atom.sum.pct_of_peak_sustained_elapsed', 'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_ld.sum', 'l1tex__data_pipe_lsu_wavefronts_mem_shared_op_ld.sum.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.max.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.min.pct_of_peak_sustained_elapsed', 'sm__inst_executed_pipe_cbu_pred_on_any.sum.pct_of_peak_sustained_elapsed', 'sm__mio_pq_read_cycles_active.sum.pct_of_peak_sustained_elapsed', 'smsp__average_warps_issue_stalled_branch_resolving_per_issue_active.ratio', 'smsp__branch_targets_threads_divergent', 'smsp__inst_executed.sum', 'smsp__inst_executed_op_branch.avg', 'smsp__inst_executed_op_branch.max', 'smsp__inst_executed_op_branch.min', 'smsp__inst_executed_op_branch.sum', 'smsp__inst_executed_op_shared_atom.sum', 'smsp__inst_executed_op_shared_atom.sum.pct_of_peak_sustained_elapsed', 'smsp__sass_inst_executed_op_shared_ld.sum', 'smsp__sass_inst_executed_op_shared_st.sum']

# %%
deit_base_data_test_df[0][0].shape
# Out:
# (12, 22)

# %% [markdown]
# ### Dataset re-arrangement and providing label for training and test samples for both shadow and target model. Also, selecting appropiate range of FMHA kernel instances for achieving maximum attack success rate.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=[]
y_train=[]
X_test=[]
y_test=[]

for i in range(100):
    for j in range(10):
        r = deit_base_data_df[i][j]  # shape: (12, 2)
        X_train.append(r)

        if i < 50:
            y_train.append(1)
        else:
            y_train.append(0)
for i in range(30):
    for j in range(10):
        r = deit_base_data_test_df[i][j]  # shape: (12, 2)
        X_test.append(r)

        if i < 15:
            y_test.append(1)
        else:
            y_test.append(0)


X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train[:,0:2, :]
X_test = X_test[:, 0:2, :]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1000, 2, 22) (1000,)
# (300, 2, 22) (300,)

# %%
print(X_train.dtype)
print(X_train[0, 0, :10])
# Out:
# float64
# [4.74888960e+07 1.78172951e+01 1.80412700e+06 6.76887989e-01
#  3.33393160e+07 1.25085325e+01 7.69645989e-01 7.87491024e-01
#  7.51022995e-01 7.69645989e-01]

# %%
# Ensure all elements are float32
X_train = X_train.astype(np.float32)

# %%
import numpy as np
print(np.unique(y_train, return_counts=True))
print(np.unique(y_test, return_counts=True))
# Out:
# (array([0, 1]), array([500, 500]))
# (array([0, 1]), array([150, 150]))

# %% [markdown]
# ### Attack Classifier training

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout, BatchNormalization
import numpy as np
from sklearn.model_selection import train_test_split

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  
def reset_random_seeds():
   os.environ['PYTHONHASHSEED']=str(42)
   tf.random.set_seed(42)
   np.random.seed(42)
   random.seed(42)

reset_random_seeds()
import tensorflow as tf

# Your input data shape: (samples, sequence_length, feature_dim)
num_samples = X_train.shape[0]
sequence_length = X_train.shape[1]
feature_dim = X_train.shape[2]

# Define the model
# Stacked BiLSTM Layers
model = Sequential()
model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=(sequence_length, feature_dim)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(32, return_sequences=False)))
model.add(Dropout(0.2))

# Fully connected hidden layer
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='sigmoid'))


# Compile
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
mean = X_train.mean(axis=(0, 1), keepdims=True)
std = X_train.std(axis=(0, 1), keepdims=True)
X_train = (X_train - mean) / (std + 1e-8)

# Summary
model.summary()
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)
# Train
history = model.fit(
    X_train_split, y_train_split,
    epochs=300,
    batch_size=45,
    validation_data=(X_val_split, y_val_split)
)
# Out:
# 2026-08-25 16:02:10.867503: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-25 16:02:10.875797: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1787653930.885400 3799030 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1787653930.888436 3799030 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1787653930.896439 3799030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1787653930.896448 3799030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1787653930.896450 3799030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1787653930.896450 3799030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-08-25 16:02:10.898644: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-25 16:02:11.792886: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-08-25 16:02:11.792900: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES="-1"
# 2026-08-25 16:02:11.792903: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# 2026-08-25 16:02:11.792906: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2026-08-25 16:02:11.792908: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: rtx3060-MS-7D90
# 2026-08-25 16:02:11.792909: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: rtx3060-MS-7D90
# 2026-08-25 16:02:11.792998: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 580.173.2
# 2026-08-25 16:02:11.793009: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 580.173.2
# 2026-08-25 16:02:11.793010: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 580.173.2
# /home/rtx3060/.local/lib/python3.10/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 2, 128)         │        44,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 64)             │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 89,985 (351.50 KB)
#  Trainable params: 89,985 (351.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.5201 - loss: 0.6895 - val_accuracy: 0.5350 - val_loss: 0.6870
# Epoch 2/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5326 - loss: 0.6813 - val_accuracy: 0.6050 - val_loss: 0.6794
# Epoch 3/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6265 - loss: 0.6721 - val_accuracy: 0.5950 - val_loss: 0.6676
# Epoch 4/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5913 - loss: 0.6598 - val_accuracy: 0.6750 - val_loss: 0.6498
# Epoch 5/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6420 - loss: 0.6469 - val_accuracy: 0.6700 - val_loss: 0.6245
# Epoch 6/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6462 - loss: 0.6245 - val_accuracy: 0.6700 - val_loss: 0.6087
# Epoch 7/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6465 - loss: 0.6111 - val_accuracy: 0.6450 - val_loss: 0.5985
# Epoch 8/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6540 - loss: 0.5969 - val_accuracy: 0.6500 - val_loss: 0.5880
# Epoch 9/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6701 - loss: 0.5950 - val_accuracy: 0.6750 - val_loss: 0.5725
# Epoch 10/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6734 - loss: 0.5797 - val_accuracy: 0.6800 - val_loss: 0.5678
# Epoch 11/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6971 - loss: 0.5711 - val_accuracy: 0.6950 - val_loss: 0.5571
# Epoch 12/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6856 - loss: 0.5558 - val_accuracy: 0.6750 - val_loss: 0.5560
# Epoch 13/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6862 - loss: 0.5540 - val_accuracy: 0.6700 - val_loss: 0.5489
# Epoch 14/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6750 - loss: 0.5592 - val_accuracy: 0.6950 - val_loss: 0.5481
# Epoch 15/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7031 - loss: 0.5462 - val_accuracy: 0.7100 - val_loss: 0.5348
# Epoch 16/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7234 - loss: 0.5266 - val_accuracy: 0.7150 - val_loss: 0.5165
# Epoch 17/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7099 - loss: 0.5237 - val_accuracy: 0.6950 - val_loss: 0.5227
# Epoch 18/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7175 - loss: 0.5252 - val_accuracy: 0.7100 - val_loss: 0.5213
# Epoch 19/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7552 - loss: 0.4930 - val_accuracy: 0.6850 - val_loss: 0.5411
# Epoch 20/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7305 - loss: 0.5094 - val_accuracy: 0.7100 - val_loss: 0.5088
# Epoch 21/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7375 - loss: 0.4974 - val_accuracy: 0.7300 - val_loss: 0.4849
# Epoch 22/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7642 - loss: 0.4627 - val_accuracy: 0.7400 - val_loss: 0.4646
# Epoch 23/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7790 - loss: 0.4628 - val_accuracy: 0.7500 - val_loss: 0.4658
# Epoch 24/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7797 - loss: 0.4360 - val_accuracy: 0.7450 - val_loss: 0.4722
# Epoch 25/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7871 - loss: 0.4501 - val_accuracy: 0.7450 - val_loss: 0.4718
# Epoch 26/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7922 - loss: 0.4259 - val_accuracy: 0.7600 - val_loss: 0.4722
# Epoch 27/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9945 - loss: 0.0138 - val_accuracy: 0.9750 - val_loss: 0.0912
# Epoch 200/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9983 - loss: 0.0085 - val_accuracy: 0.9850 - val_loss: 0.1149
# Epoch 201/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9979 - loss: 0.0063 - val_accuracy: 0.9850 - val_loss: 0.0870
# Epoch 202/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9985 - loss: 0.0040 - val_accuracy: 0.9800 - val_loss: 0.1060
# Epoch 203/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9979 - loss: 0.0081 - val_accuracy: 0.9850 - val_loss: 0.1082
# Epoch 204/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9999 - loss: 0.0030 - val_accuracy: 0.9850 - val_loss: 0.1011
# Epoch 205/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9928 - loss: 0.0152 - val_accuracy: 0.9850 - val_loss: 0.0931
# Epoch 206/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9974 - loss: 0.0057 - val_accuracy: 0.9800 - val_loss: 0.0677
# Epoch 207/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9800 - val_loss: 0.1230
# Epoch 208/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9982 - loss: 0.0102 - val_accuracy: 0.9750 - val_loss: 0.0366
# Epoch 209/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9985 - loss: 0.0044 - val_accuracy: 0.9800 - val_loss: 0.0397
# Epoch 210/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9800 - val_loss: 0.0623
# Epoch 211/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9800 - val_loss: 0.0608
# Epoch 212/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9989 - loss: 0.0020 - val_accuracy: 0.9800 - val_loss: 0.0596
# Epoch 213/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9800 - val_loss: 0.0636
# Epoch 214/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 0.9850 - val_loss: 0.1072
# Epoch 215/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9990 - loss: 0.0036 - val_accuracy: 0.9850 - val_loss: 0.1225
# Epoch 216/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9970 - loss: 0.0048 - val_accuracy: 0.9750 - val_loss: 0.1526
# Epoch 217/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9934 - loss: 0.0121 - val_accuracy: 0.9800 - val_loss: 0.1008
# Epoch 218/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.9850 - val_loss: 0.1061
# Epoch 219/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9800 - val_loss: 0.1200
# Epoch 220/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9800 - val_loss: 0.1261
# Epoch 221/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 9.1419e-04 - val_accuracy: 0.9800 - val_loss: 0.1113
# Epoch 222/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9800 - val_loss: 0.0971
# Epoch 223/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9996 - loss: 0.0010 - val_accuracy: 0.9800 - val_loss: 0.0943
# Epoch 224/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9850 - val_loss: 0.0985
# Epoch 225/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9998 - loss: 0.0017 - val_accuracy: 0.9800 - val_loss: 0.1050
# Epoch 226/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9996 - loss: 0.0044 - val_accuracy: 0.9750 - val_loss: 0.1238
# Epoch 227/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9940 - loss: 0.0138 - val_accuracy: 0.9750 - val_loss: 0.1845
# Epoch 228/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9923 - loss: 0.0252 - val_accuracy: 0.9650 - val_loss: 0.1470
# Epoch 229/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9930 - loss: 0.0234 - val_accuracy: 0.9750 - val_loss: 0.1430
# Epoch 230/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9851 - loss: 0.0522 - val_accuracy: 0.9800 - val_loss: 0.1120
# Epoch 231/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9927 - loss: 0.0176 - val_accuracy: 0.9750 - val_loss: 0.1081
# Epoch 232/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9980 - loss: 0.0123 - val_accuracy: 0.9750 - val_loss: 0.1372
# Epoch 233/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0097 - val_accuracy: 0.9750 - val_loss: 0.1350
# Epoch 234/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9978 - loss: 0.0051 - val_accuracy: 0.9750 - val_loss: 0.1674
# Epoch 235/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9911 - loss: 0.0270 - val_accuracy: 0.9750 - val_loss: 0.1432
# Epoch 236/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9958 - loss: 0.0141 - val_accuracy: 0.9800 - val_loss: 0.0887
# Epoch 237/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9950 - loss: 0.0223 - val_accuracy: 0.9800 - val_loss: 0.0880
# Epoch 238/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9967 - loss: 0.0122 - val_accuracy: 0.9500 - val_loss: 0.2200
# Epoch 239/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9924 - loss: 0.0238 - val_accuracy: 0.9800 - val_loss: 0.0968
# Epoch 240/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9949 - loss: 0.0089 - val_accuracy: 0.9850 - val_loss: 0.1153
# Epoch 241/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9996 - loss: 0.0055 - val_accuracy: 0.9850 - val_loss: 0.1062
# Epoch 242/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9850 - val_loss: 0.1110
# Epoch 243/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9955 - loss: 0.0053 - val_accuracy: 0.9900 - val_loss: 0.1069
# Epoch 244/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9997 - loss: 0.0017 - val_accuracy: 0.9800 - val_loss: 0.0966
# Epoch 245/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9970 - loss: 0.0040 - val_accuracy: 0.9850 - val_loss: 0.0844
# Epoch 246/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9850 - val_loss: 0.0927
# Epoch 247/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9850 - val_loss: 0.1116
# Epoch 248/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 9.3171e-04 - val_accuracy: 0.9850 - val_loss: 0.0971
# Epoch 249/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0031 - val_accuracy: 0.9900 - val_loss: 0.0978
# Epoch 250/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9958 - loss: 0.0070 - val_accuracy: 0.9850 - val_loss: 0.0880
# Epoch 251/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.8881e-04 - val_accuracy: 0.9850 - val_loss: 0.0864
# Epoch 252/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9996 - loss: 8.9802e-04 - val_accuracy: 0.9850 - val_loss: 0.1165
# Epoch 253/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9850 - val_loss: 0.1311
# Epoch 254/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9850 - val_loss: 0.1407
# Epoch 255/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9850 - val_loss: 0.1490
# Epoch 256/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.2772e-04 - val_accuracy: 0.9850 - val_loss: 0.1378
# Epoch 257/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.7963e-04 - val_accuracy: 0.9850 - val_loss: 0.1301
# Epoch 258/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9850 - val_loss: 0.1339
# Epoch 259/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9850 - val_loss: 0.0429
# Epoch 260/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9861 - loss: 0.0352 - val_accuracy: 0.9350 - val_loss: 0.3918
# Epoch 261/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9895 - loss: 0.0479 - val_accuracy: 0.9650 - val_loss: 0.0757
# Epoch 262/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9953 - loss: 0.0120 - val_accuracy: 0.9850 - val_loss: 0.0775
# Epoch 263/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9980 - loss: 0.0056 - val_accuracy: 0.9850 - val_loss: 0.0353
# Epoch 264/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9976 - loss: 0.0046 - val_accuracy: 0.9900 - val_loss: 0.0366
# Epoch 265/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9966 - loss: 0.0089 - val_accuracy: 0.9800 - val_loss: 0.1106
# Epoch 266/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9850 - val_loss: 0.1219
# Epoch 267/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9983 - loss: 0.0045 - val_accuracy: 0.9850 - val_loss: 0.0681
# Epoch 268/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0043 - val_accuracy: 0.9850 - val_loss: 0.0620
# Epoch 269/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9850 - val_loss: 0.0647
# Epoch 270/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 9.9272e-04 - val_accuracy: 0.9850 - val_loss: 0.0747
# Epoch 271/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9850 - val_loss: 0.0882
# Epoch 272/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9999 - loss: 0.0023 - val_accuracy: 0.9850 - val_loss: 0.0951
# Epoch 273/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9850 - val_loss: 0.1000
# Epoch 274/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.4592e-04 - val_accuracy: 0.9850 - val_loss: 0.1117
# Epoch 275/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9989 - loss: 0.0018 - val_accuracy: 0.9850 - val_loss: 0.1018
# Epoch 276/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9850 - val_loss: 0.1143
# Epoch 277/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0015 - val_accuracy: 0.9850 - val_loss: 0.0825
# Epoch 278/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0030 - val_accuracy: 0.9700 - val_loss: 0.1428
# Epoch 279/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9947 - loss: 0.0112 - val_accuracy: 0.9750 - val_loss: 0.1329
# Epoch 280/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9920 - loss: 0.0154 - val_accuracy: 0.9800 - val_loss: 0.0909
# Epoch 281/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9968 - loss: 0.0086 - val_accuracy: 0.9900 - val_loss: 0.0555
# Epoch 282/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9965 - loss: 0.0086 - val_accuracy: 0.9850 - val_loss: 0.0971
# Epoch 283/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9992 - loss: 0.0051 - val_accuracy: 0.9850 - val_loss: 0.0511
# Epoch 284/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9989 - loss: 0.0056 - val_accuracy: 0.9900 - val_loss: 0.0386
# Epoch 285/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9966 - loss: 0.0043 - val_accuracy: 0.9900 - val_loss: 0.0533
# Epoch 286/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0115 - val_accuracy: 0.9850 - val_loss: 0.0482
# Epoch 287/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9931 - loss: 0.0235 - val_accuracy: 0.9850 - val_loss: 0.0645
# Epoch 288/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9944 - loss: 0.0144 - val_accuracy: 0.9750 - val_loss: 0.1199
# Epoch 289/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9972 - loss: 0.0067 - val_accuracy: 0.9800 - val_loss: 0.1186
# Epoch 290/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9984 - loss: 0.0122 - val_accuracy: 0.9650 - val_loss: 0.1156
# Epoch 291/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9946 - loss: 0.0137 - val_accuracy: 0.9850 - val_loss: 0.0338
# Epoch 292/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9980 - loss: 0.0224 - val_accuracy: 0.9900 - val_loss: 0.0493
# Epoch 293/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 7.4135e-04 - val_accuracy: 0.9900 - val_loss: 0.0606
# Epoch 294/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9900 - val_loss: 0.0754
# Epoch 295/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 3.6269e-04 - val_accuracy: 0.9900 - val_loss: 0.0792
# Epoch 296/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9993 - loss: 0.0050 - val_accuracy: 0.9850 - val_loss: 0.0684
# Epoch 297/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9974 - loss: 0.0216 - val_accuracy: 0.9800 - val_loss: 0.0468
# Epoch 298/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9996 - loss: 0.0048 - val_accuracy: 0.9850 - val_loss: 0.0870
# Epoch 299/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9984 - loss: 0.0023 - val_accuracy: 0.9850 - val_loss: 0.0999
# Epoch 300/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9993 - loss: 0.0026 - val_accuracy: 0.9850 - val_loss: 0.1014

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Membership Inference Attack on Target Model Data

# %%
# Predict
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt


mean = X_test.mean(axis=(0, 1), keepdims=True)
std = X_test.std(axis=(0, 1), keepdims=True)
X_test = (X_test - mean) / (std + 1e-8)

# Predict probabilities
predictions = model.predict(X_test)

# # Convert probabilities to binary labels
predicted_labels = (predictions > 0.5).astype(int)

# Accuracy
acc = accuracy_score(y_test, predicted_labels)
print(f"Test Accuracy: {acc:.4f}")

# Confusion matrix
cm = confusion_matrix(y_test, predicted_labels)
print("Confusion Matrix:\n", cm)

# Plot
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Test Set","Training Set"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Test Accuracy: 0.9100
# Confusion Matrix:
#  [[135  15]
#  [ 12 138]]

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_auc_score,
    roc_curve,
    f1_score
)
import matplotlib.pyplot as plt
import numpy as np

# Binary predictions using threshold 0.5
predicted_labels = (predictions >= 0.5).astype(int)

# F1 Score
f1 = f1_score(y_test, predicted_labels)
print(f"F1 Score: {f1:.4f}")

# AUC Score
auc_score = roc_auc_score(y_test, predictions)
print(f"AUC Score: {auc_score:.4f}")

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, predictions)

# Plot ROC Curve
plt.figure()
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.4f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # Random chance line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# F1 Score: 0.9109
# AUC Score: 0.9458
